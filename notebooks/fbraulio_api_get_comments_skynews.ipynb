# %%
import requests
import os
import json
import pandas as pd
import numpy as np
import csv
import datetime
import dateutil.parser
import unicodedata
import time
import random
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
def split(a, n):
    k, m = divmod(len(a), n)
    return (a[i*k+min(i, m):(i+1)*k+min(i+1, m)] for i in range(n))

def auth():
    #return os.getenv('BEARER_TOKEN')
    return "AAAAAAAAAAAAAAAAAAAAAEsNOQEAAAAAYbrutZaFDjSRzoCCwQ6WyOzFxR4%3D1Prt5DCx5O8TUiaUzq56oIAjycSQtH5NsbjSliOs3sStkyNkel"

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def append_tweet_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet and Conversation ID
        tweet_id = tweet['id']
        conversation_id = tweet['conversation_id']
        in_reply_to_user_id = tweet['in_reply_to_user_id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [tweet_id, conversation_id, author_id, in_reply_to_user_id, created_at, geo, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter)
    
def append_user_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for user in json_response['includes']['users']:

        # 1. Author ID, Username and DisplayName
        author_id = user['id']
        username = user['username']
        display_name = user['name']

        # 2. Description
        description = user['description']
        
        # 3. Verified
        verified = user['verified']
        
        # 4. Time user created
        created_at = dateutil.parser.parse(user['created_at'])

        # 5. User metrics
        followers_count = user['public_metrics']['followers_count']
        following_count = user['public_metrics']['following_count']
        tweet_count = user['public_metrics']['tweet_count']
        listed_count = user['public_metrics']['listed_count']
        
        # Assemble all data in a list
        res = [author_id, username, display_name, description, verified, created_at, followers_count, following_count, tweet_count, listed_count]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Users added from this response: ", counter) 
    
def append_place_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for place in json_response['includes']['places']:

        # Features
        geo = place['id']
        full_name = place['full_name']
        place_type = place['place_type']
        name = place['name']
        country_code = place['country_code']
        
        # Assemble all data in a list
        res = [geo, full_name, place_type, name, country_code]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Places added from this response: ", counter)

# %%
# Get selected conversations
df = pd.read_parquet('./../data/raw/tmp/news_tweets_skynews.parquet')
df = df[df.replyCount>0]
conversations = list(df.conversationId.unique())
random.shuffle(conversations)
batches = list(split(conversations, int(len(conversations)/24)))

# Create tweet file and write header
csvFile = open("./../data/processed/tmp/tweets_replies_skynews.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['tweet_id', 'conversation_id', 'author_id', 'in_reply_to_user_id', 'created_at', 'geo', 'lang', 'like_count', 'quote_count', 'reply_count', 'retweet_count', 'source', 'text'])
csvFile.close()

# Create user file and write header
csvFile = open("./../data/processed/tmp/users_replies_skynews.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['author_id', 'username', 'display_name', 'description', 'verified', 'created_at', 'followers_count', 'following_count', 'tweet_count', 'listed_count'])
csvFile.close()

# Create place file and write header
csvFile = open("./../data/processed/tmp/places_replies_skynews.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['geo', 'full_name', 'place_type', 'name', 'country_code'])
csvFile.close()

# Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
start_date = '2020-01-01T00:00:00.000Z'
end_date = '2021-05-14T23:59:59.000Z'
max_results = 500

# Loop Inputs
total_tweets = 0
count = 0 # Counting tweets per time period
max_count = 10000000 # Max tweets per time period
flag = True
next_token = None
n_requests = 0
n_batches = 0
valid = False
errCount = 0

# %%
# Check if flag is true
start_time = time.time()

for batch in batches:
    
    search = "conversation_id:" + " OR conversation_id:".join( [str(s) for s in batch]) + " to:7587032 lang:en is:reply -is:retweet"
    print("--------------------------------------")
    print("Batch #: ", n_batches)
    total_loop_tweets = 0
    flag = True
    while flag:
        # Check if max_count reached
        if count >= max_count:
            break
        print("Request #: ", n_requests+1, " | Time cap: ", int(time.time() - start_time))
        print("Token: ", next_token)
        while not valid:
            try:
                url = create_url(search, start_date,end_date, max_results)
                json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
                result_count = json_response['meta']['result_count']
                n_requests += 1
                valid = True; errCount = 0
            except:
                errCount += 1
                time.sleep(2^errCount)
                print("-------------------------------------- Request error #", errCount)
        valid = False

        # Save the token to use for next call
        if 'next_token' in json_response['meta']:
            next_token = json_response['meta']['next_token']
            print("Next Token: ", next_token)
            if result_count is not None and result_count > 0 and next_token is not None:
                append_tweet_to_csv(json_response, "./../data/processed/tmp/tweets_replies_skynews.csv")
                append_user_to_csv(json_response, "./../data/processed/tmp/users_replies_skynews.csv")
                if 'places' in json_response['includes'].keys():
                    append_place_to_csv(json_response, "./../data/processed/tmp/places_replies_skynews.csv")
                count += result_count
                total_loop_tweets += result_count
                print("Cumulative # of Tweets in this batch: ", total_loop_tweets)
                print("-------------------")
                time.sleep(1)                
        # If no next token exists
        else:
            if result_count is not None and result_count > 0:
                append_tweet_to_csv(json_response, "./../data/processed/tmp/tweets_replies_skynews.csv")
                append_user_to_csv(json_response, "./../data/processed/tmp/users_replies_skynews.csv")
                if 'places' in json_response['includes'].keys():
                    append_place_to_csv(json_response, "./../data/processed/tmp/places_replies_skynews.csv")
                count += result_count
                total_loop_tweets += result_count
                print("Cumulative # of Tweets in this batch: ", total_loop_tweets)
                time.sleep(1)
            #Since this is the final request, turn flag to false to move to the next time period.
            flag = False
            next_token = None
        time.sleep(1)
        # If reachs requests cap, stop it
        t = time.time()-start_time
        if n_requests==300:
            if t<900:
                time.sleep(900 - t)
            start_time=time.time()
            n_requests = 0
    n_batches += 1
    total_tweets += total_loop_tweets
    print("Total number of batch results: ", total_loop_tweets)
    print("Total # of Tweets added: ", total_tweets)
print("Total number of results: ", total_tweets)
# Out:
# --------------------------------------
# Batch #:  0
# Request #:  1  | Time cap:  0
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbski485qg2rp6cj1oxksab32bnh
# # of Tweets added from this response:  470
# # of Users added from this response:  406
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  470
# -------------------
# Request #:  2  | Time cap:  4
# Token:  b26v89c19zqg8o3fosbski485qg2rp6cj1oxksab32bnh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbskfziazzn58n3c3i5i2y1djbst
# # of Tweets added from this response:  456
# # of Users added from this response:  344
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  926
# -------------------
# Request #:  3  | Time cap:  7
# Token:  b26v89c19zqg8o3fosbskfziazzn58n3c3i5i2y1djbst
# Endpoint Response Code: 200
# # of Tweets added from this response:  285
# # of Users added from this response:  187
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  1211
# Total number of batch results:  1211
# Total # of Tweets added:  1211
# --------------------------------------
# Batch #:  1
# Request #:  4  | Time cap:  11
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5t06vlkr3xzwdb5al7sse8r4jul
# # of Tweets added from this response:  469
# # of Users added from this response:  325
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  469
# -------------------
# Request #:  5  | Time cap:  15
# Token:  b26v89c19zqg8o3fos5t06vlkr3xzwdb5al7sse8r4jul
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gb6tgfg88z66eledkwbpx858ql
# # of Tweets added from this response:  466
# # of Users added from this response:  374
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  935
# -------------------
# Request #:  6  | Time cap:  20
# Token:  b26v89c19zqg8o3fo77gb6tgfg88z66eledkwbpx858ql
# Endpoint Response Code: 200
# # of Tweets added from this response:  312
# # of Users added from this response:  272
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  1247
# Total number of batch results:  1247
# Total # of Tweets added:  2458
# --------------------------------------
# Batch #:  2
# Request #:  7  | Time cap:  23
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbski3mqxjs6fo680hy7a0ia41a5
# # of Tweets added from this response:  470
# # of Users added from this response:  284
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  470
# -------------------
# Request #:  8  | Time cap:  27
# Token:  b26v89c19zqg8o3fosbski3mqxjs6fo680hy7a0ia41a5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ddqyamqww7smel7nu5zqlbuydfh
# # of Tweets added from this response:  485
# # of Users added from this response:  323
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  955
# -------------------
# Request #:  9  | Time cap:  31
# Token:  b26v89c19zqg8o3fo7ddqyamqww7smel7nu5zqlbuydfh
# Endpoint Response Code: 200
# # of Tweets added from this response:  175
# # of Users added from this response:  149
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  1130
# Total number of batch results:  1130
# Total # of Tweets added:  3588
# --------------------------------------
# Batch #:  3
# Request #:  10  | Time cap:  35
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5t06vlnss6v9opi9h5nv5iid119
# # of Tweets added from this response:  475
# # of Users added from this response:  282
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  475
# -------------------
# Request #:  11  | Time cap:  39
# Token:  b26v89c19zqg8o3fos5t06vlnss6v9opi9h5nv5iid119
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7aeeknfhrtzd6jsc3bbfifs6nxx9
# # of Tweets added from this response:  470
# # of Users added from this response:  381
# # of Places added from this response:  11
# Cumulative # of Tweets in this batch:  945
# -------------------
# Request #:  12  | Time cap:  43
# Token:  b26v89c19zqg8o3fo7aeeknfhrtzd6jsc3bbfifs6nxx9
# Endpoint Response Code: 200
# # of Tweets added from this response:  457
# # of Users added from this response:  367
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  1402
# Total number of batch results:  1402
# Total # of Tweets added:  4990
# --------------------------------------
# Batch #:  4
# Request #:  13  | Time cap:  47
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbvi6hc4nofea8w167iwaeli1i0t
# # of Tweets added from this response:  474
# # of Users added from this response:  362
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  474
# -------------------
# Request #:  14  | Time cap:  51
# Token:  b26v89c19zqg8o3fosbvi6hc4nofea8w167iwaeli1i0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbvi28hkws1owwvmdkxnonub29od
# # of Tweets added from this response:  479
# # of Users added from this response:  410
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  953
# -------------------
# Request #:  15  | Time cap:  55
# Token:  b26v89c19zqg8o3fosbvi28hkws1owwvmdkxnonub29od
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbvi286si1lg5mcy7eslbdfu1n5p
# # of Tweets added from this response:  481
# # of Users added from this response:  408
# # of Places added from this response:  14
# Cumulative # of Tweets in this batch:  1434
# -------------------
# Request #:  16  | Time cap:  60
# Token:  b26v89c19zqg8o3fosbvi286si1lg5mcy7eslbdfu1n5p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5v4138b0ab8o3y6ioyjaazczaf1
# # of Tweets added from this response:  478
# # of Users added from this response:  376
# # of Places added from this response:  11
# Cumulative # of Tweets in this batch:  1912
# -------------------
# Request #:  17  | Time cap:  64
# Token:  b26v89c19zqg8o3fos5v4138b0ab8o3y6ioyjaazczaf1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5v410ubpuk5g81r4kl6lhk4q35p
# # of Tweets added from this response:  474
# # of Users added from this response:  356
# # of Places added from this response:  13
# Cumulative # of Tweets in this batch:  2386
# -------------------
# Request #:  18  | Time cap:  68
# Token:  b26v89c19zqg8o3fos5v410ubpuk5g81r4kl6lhk4q35p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7jcvxjfl7nx59bhsbqd1csdzpg8t
# # of Tweets added from this response:  488
# # of Users added from this response:  363
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  2874
# -------------------
# Request #:  19  | Time cap:  72
# Token:  b26v89c19zqg8o3fo7jcvxjfl7nx59bhsbqd1csdzpg8t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7aeekobthufnb0tp1zgjlg235bwd
# # of Tweets added from this response:  478
# # of Users added from this response:  224
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  3352
# -------------------
# Request #:  20  | Time cap:  76
# Token:  b26v89c19zqg8o3fo7aeekobthufnb0tp1zgjlg235bwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77ds0lp02bkvjtspxnz7c017sc59
# # of Tweets added from this response:  472
# # of Users added from this response:  341
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  3824
# -------------------
# Request #:  21  | Time cap:  80
# Token:  b26v89c19zqg8o3fo77ds0lp02bkvjtspxnz7c017sc59
# Endpoint Response Code: 200
# # of Tweets added from this response:  55
# # of Users added from this response:  48
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  3879
# Total number of batch results:  3879
# Total # of Tweets added:  8869
# --------------------------------------
# Batch #:  5
# Request #:  22  | Time cap:  83
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7af8h0c463b049py93eutq3rpw8t
# # of Tweets added from this response:  433
# # of Users added from this response:  278
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  433
# -------------------
# Request #:  23  | Time cap:  87
# Token:  b26v89c19zqg8o3fo7af8h0c463b049py93eutq3rpw8t
# Endpoint Response Code: 200
# # of Tweets added from this response:  441
# # of Users added from this response:  327
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  874
# Total number of batch results:  874
# Total # of Tweets added:  9743
# --------------------------------------
# Batch #:  6
# Request #:  24  | Time cap:  91
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7df0h9hctmq2g2vs706sgodie4cd
# # of Tweets added from this response:  396
# # of Users added from this response:  329
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  396
# -------------------
# Request #:  25  | Time cap:  95
# Token:  b26v89c19zqg8o3fo7df0h9hctmq2g2vs706sgodie4cd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7df0cytrxeo2p4ybytppkfcc2u0t
# # of Tweets added from this response:  490
# # of Users added from this response:  405
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  886
# -------------------
# Request #:  26  | Time cap:  99
# Token:  b26v89c19zqg8o3fo7df0cytrxeo2p4ybytppkfcc2u0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7delqltrbv7nkgx82403uo435abh
# # of Tweets added from this response:  481
# # of Users added from this response:  371
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  1367
# -------------------
# Request #:  27  | Time cap:  103
# Token:  b26v89c19zqg8o3fo7delqltrbv7nkgx82403uo435abh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7aeemtd3ffr8tpu3iczy0kgi8y9p
# # of Tweets added from this response:  479
# # of Users added from this response:  417
# # of Places added from this response:  13
# Cumulative # of Tweets in this batch:  1846
# -------------------
# Request #:  28  | Time cap:  107
# Token:  b26v89c19zqg8o3fo7aeemtd3ffr8tpu3iczy0kgi8y9p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7aeeknqbozcdans8pqykpt2t3nul
# # of Tweets added from this response:  480
# # of Users added from this response:  416
# # of Places added from this response:  11
# Cumulative # of Tweets in this batch:  2326
# -------------------
# Request #:  29  | Time cap:  111
# Token:  b26v89c19zqg8o3fo7aeeknqbozcdans8pqykpt2t3nul
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7aeeiksyfvz8tustdjumy1aqgozh
# # of Tweets added from this response:  486
# # of Users added from this response:  434
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  2812
# -------------------
# Request #:  30  | Time cap:  115
# Token:  b26v89c19zqg8o3fo7aeeiksyfvz8tustdjumy1aqgozh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7adkdqhwgmu779aekfbc8x82kqrh
# # of Tweets added from this response:  478
# # of Users added from this response:  430
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  3290
# -------------------
# Request #:  31  | Time cap:  119
# Token:  b26v89c19zqg8o3fo7adkdqhwgmu779aekfbc8x82kqrh
# Endpoint Response Code: 200
# # of Tweets added from this response:  320
# # of Users added from this response:  208
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  3610
# Total number of batch results:  3610
# Total # of Tweets added:  13353
# --------------------------------------
# Batch #:  7
# Request #:  32  | Time cap:  123
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6red5l260i9winalszc8pyx6l
# # of Tweets added from this response:  464
# # of Users added from this response:  243
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  464
# -------------------
# Request #:  33  | Time cap:  127
# Token:  b26v89c19zqg8o3fosnu6red5l260i9winalszc8pyx6l
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnu6rckf0t9cp1q3n1xwjhghlp4t
# # of Tweets added from this response:  477
# # of Users added from this response:  302
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  941
# -------------------
# Request #:  34  | Time cap:  131
# Token:  b26v89c19zqg8o3fosnu6rckf0t9cp1q3n1xwjhghlp4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos8tmt2d1qddica925f18dfkmy9a5
# # of Tweets added from this response:  472
# # of Users added from this response:  366
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  1413
# -------------------
# Request #:  35  | Time cap:  135
# Token:  b26v89c19zqg8o3fos8tmt2d1qddica925f18dfkmy9a5
# Endpoint Response Code: 200
# # of Tweets added from this response:  356
# # of Users added from this response:  300
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  1769
# Total number of batch results:  1769
# Total # of Tweets added:  15122
# --------------------------------------
# Batch #:  8
# Request #:  36  | Time cap:  139
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5uoxjx9dpzhvyk9zyr2hxmdlyt9
# # of Tweets added from this response:  465
# # of Users added from this response:  315
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  465
# -------------------
# Request #:  37  | Time cap:  143
# Token:  b26v89c19zqg8o3fos5uoxjx9dpzhvyk9zyr2hxmdlyt9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5ua6urpsd9pp2w8hoyp5vsje9a5
# # of Tweets added from this response:  454
# # of Users added from this response:  316
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  919
# -------------------
# Request #:  38  | Time cap:  147
# Token:  b26v89c19zqg8o3fos5ua6urpsd9pp2w8hoyp5vsje9a5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7delk65g8zqigrtkyk5xymxz5w1p
# # of Tweets added from this response:  467
# # of Users added from this response:  351
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  1386
# -------------------
# Request #:  39  | Time cap:  151
# Token:  b26v89c19zqg8o3fo7delk65g8zqigrtkyk5xymxz5w1p
# Endpoint Response Code: 200
# # of Tweets added from this response:  284
# # of Users added from this response:  213
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  1670
# Total number of batch results:  1670
# Total # of Tweets added:  16792
# --------------------------------------
# Batch #:  9
# Request #:  40  | Time cap:  155
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77e7eqjjy5asqfvvhquvuteuwd4t
# # of Tweets added from this response:  459
# # of Users added from this response:  382
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  459
# -------------------
# Request #:  41  | Time cap:  159
# Token:  b26v89c19zqg8o3fo77e7eqjjy5asqfvvhquvuteuwd4t
# Endpoint Response Code: 200
# # of Tweets added from this response:  342
# # of Users added from this response:  293
# # of Places added from this response:  13
# Cumulative # of Tweets in this batch:  801
# Total number of batch results:  801
# Total # of Tweets added:  17593
# --------------------------------------
# Batch #:  10
# Request #:  42  | Time cap:  163
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gf7ivpu91kqdzksh3aarvmtmr25
# # of Tweets added from this response:  467
# # of Users added from this response:  397
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  467
# -------------------
# Request #:  43  | Time cap:  167
# Token:  b26v89c19zqg8o3fo7gf7ivpu91kqdzksh3aarvmtmr25
# Endpoint Response Code: 200
# # of Tweets added from this response:  368
# # of Users added from this response:  296
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  835
# Total number of batch results:  835
# Total # of Tweets added:  18428
# --------------------------------------
# Batch #:  11
# Request #:  44  | Time cap:  171
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos8u1uek4t0tmup0vec7vnebk9s3h
# # of Tweets added from this response:  476
# # of Users added from this response:  365
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  476
# -------------------
# Request #:  45  | Time cap:  175
# Token:  b26v89c19zqg8o3fos8u1uek4t0tmup0vec7vnebk9s3h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77h5mbot047hsq5ln82x6laxle9p
# # of Tweets added from this response:  483
# # of Users added from this response:  433
# # of Places added from this response:  13
# Cumulative # of Tweets in this batch:  959
# -------------------
# Request #:  46  | Time cap:  179
# Token:  b26v89c19zqg8o3fo77h5mbot047hsq5ln82x6laxle9p
# Endpoint Response Code: 200
# # of Tweets added from this response:  189
# # of Users added from this response:  163
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  1148
# Total number of batch results:  1148
# Total # of Tweets added:  19576
# --------------------------------------
# Batch #:  12
# Request #:  47  | Time cap:  183
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshtsdgghw015bvk1t14il21obdrx
# # of Tweets added from this response:  477
# # of Users added from this response:  328
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  477
# -------------------
# Request #:  48  | Time cap:  187
# Token:  b26v89c19zqg8o3foshtsdgghw015bvk1t14il21obdrx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7jdq2c8s4kmbmqcupuk50jymwvp9
# # of Tweets added from this response:  471
# # of Users added from this response:  379
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  948
# -------------------
# Request #:  49  | Time cap:  191
# Token:  b26v89c19zqg8o3fo7jdq2c8s4kmbmqcupuk50jymwvp9
# Endpoint Response Code: 200
# # of Tweets added from this response:  454
# # of Users added from this response:  354
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  1402
# Total number of batch results:  1402
# Total # of Tweets added:  20978
# --------------------------------------
# Batch #:  13
# Request #:  50  | Time cap:  195
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos8vq8b44n8ammrpyiq2f0x03ft6l
# # of Tweets added from this response:  448
# # of Users added from this response:  348
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  448
# -------------------
# Request #:  51  | Time cap:  199
# Token:  b26v89c19zqg8o3fos8vq8b44n8ammrpyiq2f0x03ft6l
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gesnx400m8w311l7c9r7mv3k4fx
# # of Tweets added from this response:  471
# # of Users added from this response:  391
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  919
# -------------------
# Request #:  52  | Time cap:  203
# Token:  b26v89c19zqg8o3fo7gesnx400m8w311l7c9r7mv3k4fx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77fgzupz2ttnpai9znxbrqvu4cql
# # of Tweets added from this response:  481
# # of Users added from this response:  331
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  1400
# -------------------
# Request #:  53  | Time cap:  207
# Token:  b26v89c19zqg8o3fo77fgzupz2ttnpai9znxbrqvu4cql
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77fgtgu6xtguxee4wkdwq13iso71
# # of Tweets added from this response:  493
# # of Users added from this response:  425
# # of Places added from this response:  14
# Cumulative # of Tweets in this batch:  1893
# -------------------
# Request #:  54  | Time cap:  211
# Token:  b26v89c19zqg8o3fo77fgtgu6xtguxee4wkdwq13iso71
# Endpoint Response Code: 200
# # of Tweets added from this response:  56
# # of Users added from this response:  47
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  1949
# Total number of batch results:  1949
# Total # of Tweets added:  22927
# --------------------------------------
# Batch #:  14
# Request #:  55  | Time cap:  214
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7merf7kce36m7vv3fme5l92gs519
# # of Tweets added from this response:  442
# # of Users added from this response:  343
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  442
# -------------------
# Request #:  56  | Time cap:  218
# Token:  b26v89c19zqg8o3fo7merf7kce36m7vv3fme5l92gs519
# Endpoint Response Code: 200
# # of Tweets added from this response:  355
# # of Users added from this response:  328
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  797
# Total number of batch results:  797
# Total # of Tweets added:  23724
# --------------------------------------
# Batch #:  15
# Request #:  57  | Time cap:  222
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbvi6hn66sc35mqdnef9phwerji5
# # of Tweets added from this response:  464
# # of Users added from this response:  293
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  464
# -------------------
# Request #:  58  | Time cap:  226
# Token:  b26v89c19zqg8o3fosbvi6hn66sc35mqdnef9phwerji5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ad4zm90f3f6g4f3eatt3m3i16rh
# # of Tweets added from this response:  477
# # of Users added from this response:  326
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  941
# -------------------
# Request #:  59  | Time cap:  230
# Token:  b26v89c19zqg8o3fo7ad4zm90f3f6g4f3eatt3m3i16rh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ad4xf4i5ic9bpe9v1yu238lpjel
# # of Tweets added from this response:  483
# # of Users added from this response:  452
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  1424
# -------------------
# Request #:  60  | Time cap:  234
# Token:  b26v89c19zqg8o3fo7ad4xf4i5ic9bpe9v1yu238lpjel
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ad4vazxp5p7q8rylyhuoo4qqf7h
# # of Tweets added from this response:  487
# # of Users added from this response:  450
# # of Places added from this response:  16
# Cumulative # of Tweets in this batch:  1911
# -------------------
# Request #:  61  | Time cap:  238
# Token:  b26v89c19zqg8o3fo7ad4vazxp5p7q8rylyhuoo4qqf7h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ad4t7ry1ou908iccndsek5r8tbx
# # of Tweets added from this response:  478
# # of Users added from this response:  430
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  2389
# -------------------
# Request #:  62  | Time cap:  242
# Token:  b26v89c19zqg8o3fo7ad4t7ry1ou908iccndsek5r8tbx
# Endpoint Response Code: 200
# # of Tweets added from this response:  169
# # of Users added from this response:  122
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  2558
# Total number of batch results:  2558
# Total # of Tweets added:  26282
# --------------------------------------
# Batch #:  16
# Request #:  63  | Time cap:  245
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5wdws1wmqgi108yhdxmdsn8enp9
# # of Tweets added from this response:  467
# # of Users added from this response:  315
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  467
# -------------------
# Request #:  64  | Time cap:  250
# Token:  b26v89c19zqg8o3fos5wdws1wmqgi108yhdxmdsn8enp9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5v49m52emlsqlp61darpg2a3cl9
# # of Tweets added from this response:  487
# # of Users added from this response:  413
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  954
# -------------------
# Request #:  65  | Time cap:  254
# Token:  b26v89c19zqg8o3fos5v49m52emlsqlp61darpg2a3cl9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7de63vo1l1aox1d65ddfj3xi9kzh
# # of Tweets added from this response:  494
# # of Users added from this response:  294
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  1448
# -------------------
# Request #:  66  | Time cap:  258
# Token:  b26v89c19zqg8o3fo7de63vo1l1aox1d65ddfj3xi9kzh
# Endpoint Response Code: 200
# # of Tweets added from this response:  136
# # of Users added from this response:  123
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  1584
# Total number of batch results:  1584
# Total # of Tweets added:  27866
# --------------------------------------
# Batch #:  17
# Request #:  67  | Time cap:  261
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbszhbe6h1dwm6w91rcz64f48wot
# # of Tweets added from this response:  479
# # of Users added from this response:  381
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  479
# -------------------
# Request #:  68  | Time cap:  265
# Token:  b26v89c19zqg8o3fosbszhbe6h1dwm6w91rcz64f48wot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7mer8vhatbpcedvpenfoy2z8xwu5
# # of Tweets added from this response:  477
# # of Users added from this response:  398
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  956
# -------------------
# Request #:  69  | Time cap:  269
# Token:  b26v89c19zqg8o3fo7mer8vhatbpcedvpenfoy2z8xwu5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gedg6g57zdzjmsx77eaxd0lfc71
# # of Tweets added from this response:  475
# # of Users added from this response:  366
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  1431
# -------------------
# Request #:  70  | Time cap:  273
# Token:  b26v89c19zqg8o3fo7gedg6g57zdzjmsx77eaxd0lfc71
# Endpoint Response Code: 200
# # of Tweets added from this response:  304
# # of Users added from this response:  245
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  1735
# Total number of batch results:  1735
# Total # of Tweets added:  29601
# --------------------------------------
# Batch #:  18
# Request #:  71  | Time cap:  277
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5uovge9rh1vg1qd7eim1a64w8sd
# # of Tweets added from this response:  464
# # of Users added from this response:  307
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  464
# -------------------
# Request #:  72  | Time cap:  281
# Token:  b26v89c19zqg8o3fos5uovge9rh1vg1qd7eim1a64w8sd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ad4r2qu8adk1vc3iujaun0y6v0d
# # of Tweets added from this response:  475
# # of Users added from this response:  401
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  939
# -------------------
# Request #:  73  | Time cap:  285
# Token:  b26v89c19zqg8o3fo7ad4r2qu8adk1vc3iujaun0y6v0d
# Endpoint Response Code: 200
# # of Tweets added from this response:  138
# # of Users added from this response:  113
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  1077
# Total number of batch results:  1077
# Total # of Tweets added:  30678
# --------------------------------------
# Batch #:  19
# Request #:  74  | Time cap:  288
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5v4dthyn02gq8jpl8ghu5ichbb1
# # of Tweets added from this response:  475
# # of Users added from this response:  412
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  475
# -------------------
# Request #:  75  | Time cap:  292
# Token:  b26v89c19zqg8o3fos5v4dthyn02gq8jpl8ghu5ichbb1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5v4bpd3isja29nuovjv5mwqau0t
# # of Tweets added from this response:  493
# # of Users added from this response:  472
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  968
# -------------------
# Request #:  76  | Time cap:  297
# Token:  b26v89c19zqg8o3fos5v4bpd3isja29nuovjv5mwqau0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5v4boh2fcx2q9dbpkvvae6h61kt
# # of Tweets added from this response:  487
# # of Users added from this response:  430
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  1455
# -------------------
# Request #:  77  | Time cap:  301
# Token:  b26v89c19zqg8o3fos5v4boh2fcx2q9dbpkvvae6h61kt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77e7cnx3ng6hoiojqhzfcntry0l9
# # of Tweets added from this response:  479
# # of Users added from this response:  430
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  1934
# -------------------
# Request #:  78  | Time cap:  305
# Token:  b26v89c19zqg8o3fo77e7cnx3ng6hoiojqhzfcntry0l9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77e7aiadh3sqih26t9npeq1gk7lp
# # of Tweets added from this response:  487
# # of Users added from this response:  467
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  2421
# -------------------
# Request #:  79  | Time cap:  309
# Token:  b26v89c19zqg8o3fo77e7aiadh3sqih26t9npeq1gk7lp
# Endpoint Response Code: 200
# # of Tweets added from this response:  486
# # of Users added from this response:  451
# # of Places added from this response:  14
# Cumulative # of Tweets in this batch:  2907
# Total number of batch results:  2907
# Total # of Tweets added:  33585
# --------------------------------------
# Batch #:  20
# Request #:  80  | Time cap:  312
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5tfn5rqbp542dfxytg87p2qk1h9
# # of Tweets added from this response:  467
# # of Users added from this response:  361
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  467
# -------------------
# Request #:  81  | Time cap:  316
# Token:  b26v89c19zqg8o3fos5tfn5rqbp542dfxytg87p2qk1h9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5t0nym0544s2nlm4q50koa5jvjx
# # of Tweets added from this response:  491
# # of Users added from this response:  383
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  958
# -------------------
# Request #:  82  | Time cap:  321
# Token:  b26v89c19zqg8o3fos5t0nym0544s2nlm4q50koa5jvjx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7dfg1tpmz4k7ewfoecarh0ty6zr1
# # of Tweets added from this response:  472
# # of Users added from this response:  368
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  1430
# -------------------
# Request #:  83  | Time cap:  325
# Token:  b26v89c19zqg8o3fo7dfg1tpmz4k7ewfoecarh0ty6zr1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77fw7ksc1bexbksytrhba9ltwxod
# # of Tweets added from this response:  480
# # of Users added from this response:  298
# # of Places added from this response:  11
# Cumulative # of Tweets in this batch:  1910
# -------------------
# Request #:  84  | Time cap:  329
# Token:  b26v89c19zqg8o3fo77fw7ksc1bexbksytrhba9ltwxod
# Endpoint Response Code: 200
# # of Tweets added from this response:  63
# # of Users added from this response:  41
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  1973
# Total number of batch results:  1973
# Total # of Tweets added:  35558
# --------------------------------------
# Batch #:  21
# Request #:  85  | Time cap:  332
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7de61tcaq6cxqwwdmu9cyj5860l9
# # of Tweets added from this response:  469
# # of Users added from this response:  355
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  469
# -------------------
# Request #:  86  | Time cap:  336
# Token:  b26v89c19zqg8o3fo7de61tcaq6cxqwwdmu9cyj5860l9
# Endpoint Response Code: 200
# # of Tweets added from this response:  424
# # of Users added from this response:  355
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  893
# Total number of batch results:  893
# Total # of Tweets added:  36451
# --------------------------------------
# Batch #:  22
# Request #:  87  | Time cap:  340
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbttwsqcs0e2ozxceeuxiypv2vzx
# # of Tweets added from this response:  458
# # of Users added from this response:  315
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  458
# -------------------
# Request #:  88  | Time cap:  344
# Token:  b26v89c19zqg8o3fosbttwsqcs0e2ozxceeuxiypv2vzx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7adzjbubo2axhsjvxyscgnczcqrh
# # of Tweets added from this response:  469
# # of Users added from this response:  364
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  927
# -------------------
# Request #:  89  | Time cap:  348
# Token:  b26v89c19zqg8o3fo7adzjbubo2axhsjvxyscgnczcqrh
# Endpoint Response Code: 200
# # of Tweets added from this response:  300
# # of Users added from this response:  216
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  1227
# Total number of batch results:  1227
# Total # of Tweets added:  37678
# --------------------------------------
# Batch #:  23
# Request #:  90  | Time cap:  352
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbtegl99kvqqggoia9ttnannlyt9
# # of Tweets added from this response:  463
# # of Users added from this response:  318
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  463
# -------------------
# Request #:  91  | Time cap:  356
# Token:  b26v89c19zqg8o3fosbtegl99kvqqggoia9ttnannlyt9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77h5m9w8gndm96mvl61o8nn3a1z1
# # of Tweets added from this response:  477
# # of Users added from this response:  333
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  940
# -------------------
# Request #:  92  | Time cap:  360
# Token:  b26v89c19zqg8o3fo77h5m9w8gndm96mvl61o8nn3a1z1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gbd7bwzqps2e32llj97jt900ot
# # of Tweets added from this response:  487
# # of Users added from this response:  371
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  1427
# -------------------
# Request #:  93  | Time cap:  364
# Token:  b26v89c19zqg8o3fo77gbd7bwzqps2e32llj97jt900ot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gbb3ichqo3wwmzs2m277oqwprx
# # of Tweets added from this response:  481
# # of Users added from this response:  445
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  1908
# -------------------
# Request #:  94  | Time cap:  368
# Token:  b26v89c19zqg8o3fo77gbb3ichqo3wwmzs2m277oqwprx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gb8ys45t4nt6arw4ygv4yqs67x
# # of Tweets added from this response:  484
# # of Users added from this response:  441
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  2392
# -------------------
# Request #:  95  | Time cap:  372
# Token:  b26v89c19zqg8o3fo77gb8ys45t4nt6arw4ygv4yqs67x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gb8y6d7i7e80xvxm52cc3bnblp
# # of Tweets added from this response:  487
# # of Users added from this response:  382
# # of Places added from this response:  11
# Cumulative # of Tweets in this batch:  2879
# -------------------
# Request #:  96  | Time cap:  377
# Token:  b26v89c19zqg8o3fo77gb8y6d7i7e80xvxm52cc3bnblp
# Endpoint Response Code: 200
# # of Tweets added from this response:  248
# # of Users added from this response:  219
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  3127
# Total number of batch results:  3127
# Total # of Tweets added:  40805
# --------------------------------------
# Batch #:  24
# Request #:  97  | Time cap:  380
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7merpuw94yk86dt1wfrzoxw7tu9p
# # of Tweets added from this response:  450
# # of Users added from this response:  355
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  450
# -------------------
# Request #:  98  | Time cap:  384
# Token:  b26v89c19zqg8o3fo7merpuw94yk86dt1wfrzoxw7tu9p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77h5mahh6f5t23l844dqe2ee86f1
# # of Tweets added from this response:  446
# # of Users added from this response:  368
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  896
# -------------------
# Request #:  99  | Time cap:  388
# Token:  b26v89c19zqg8o3fo77h5mahh6f5t23l844dqe2ee86f1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77h5k6nzrd9nnxyp0t4xo5tdpgfx
# # of Tweets added from this response:  477
# # of Users added from this response:  421
# # of Places added from this response:  14
# Cumulative # of Tweets in this batch:  1373
# -------------------
# Request #:  100  | Time cap:  392
# Token:  b26v89c19zqg8o3fo77h5k6nzrd9nnxyp0t4xo5tdpgfx
# Endpoint Response Code: 200
# # of Tweets added from this response:  251
# # of Users added from this response:  230
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  1624
# Total number of batch results:  1624
# Total # of Tweets added:  42429
# --------------------------------------
# Batch #:  25
# Request #:  101  | Time cap:  396
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7delk58veei9f8pt3netj7piht31
# # of Tweets added from this response:  475
# # of Users added from this response:  386
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  475
# -------------------
# Request #:  102  | Time cap:  400
# Token:  b26v89c19zqg8o3fo7delk58veei9f8pt3netj7piht31
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77ds70h6ylbzhue2uy4lc4orvrst
# # of Tweets added from this response:  486
# # of Users added from this response:  351
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  961
# -------------------
# Request #:  103  | Time cap:  405
# Token:  b26v89c19zqg8o3fo77ds70h6ylbzhue2uy4lc4orvrst
# Endpoint Response Code: 200
# # of Tweets added from this response:  69
# # of Users added from this response:  61
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  1030
# Total number of batch results:  1030
# Total # of Tweets added:  43459
# --------------------------------------
# Batch #:  26
# Request #:  104  | Time cap:  408
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbs564pdjqn2xw0vs7ifggw2spdp
# # of Tweets added from this response:  416
# # of Users added from this response:  297
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  416
# -------------------
# Request #:  105  | Time cap:  412
# Token:  b26v89c19zqg8o3fosbs564pdjqn2xw0vs7ifggw2spdp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77h57eb3rlm5t03a8tfweux6tdh9
# # of Tweets added from this response:  488
# # of Users added from this response:  371
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  904
# -------------------
# Request #:  106  | Time cap:  416
# Token:  b26v89c19zqg8o3fo77h57eb3rlm5t03a8tfweux6tdh9
# Endpoint Response Code: 200
# # of Tweets added from this response:  341
# # of Users added from this response:  278
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  1245
# Total number of batch results:  1245
# Total # of Tweets added:  44704
# --------------------------------------
# Batch #:  27
# Request #:  107  | Time cap:  420
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosnsidgaqv7k4bfc4qp44mt446rnh
# # of Tweets added from this response:  480
# # of Users added from this response:  335
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  480
# -------------------
# Request #:  108  | Time cap:  424
# Token:  b26v89c19zqg8o3fosnsidgaqv7k4bfc4qp44mt446rnh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7delbmn3zwuem2518ypfvfaq2hdp
# # of Tweets added from this response:  478
# # of Users added from this response:  300
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  958
# -------------------
# Request #:  109  | Time cap:  428
# Token:  b26v89c19zqg8o3fo7delbmn3zwuem2518ypfvfaq2hdp
# Endpoint Response Code: 200
# # of Tweets added from this response:  372
# # of Users added from this response:  286
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  1330
# Total number of batch results:  1330
# Total # of Tweets added:  46034
# --------------------------------------
# Batch #:  28
# Request #:  110  | Time cap:  432
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gb6s8z4l3ifg8qw5z29r2wp3lp
# # of Tweets added from this response:  454
# # of Users added from this response:  391
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  454
# -------------------
# Request #:  111  | Time cap:  436
# Token:  b26v89c19zqg8o3fo77gb6s8z4l3ifg8qw5z29r2wp3lp
# Endpoint Response Code: 200
# # of Tweets added from this response:  449
# # of Users added from this response:  360
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  903
# Total number of batch results:  903
# Total # of Tweets added:  46937
# --------------------------------------
# Batch #:  29
# Request #:  112  | Time cap:  440
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos8uw3gihta48zfb8htht2b0ygc59
# # of Tweets added from this response:  452
# # of Users added from this response:  313
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  452
# -------------------
# Request #:  113  | Time cap:  444
# Token:  b26v89c19zqg8o3fos8uw3gihta48zfb8htht2b0ygc59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77f1jlfz83zgsy2sy2hhppfyg1h9
# # of Tweets added from this response:  480
# # of Users added from this response:  318
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  932
# -------------------
# Request #:  114  | Time cap:  448
# Token:  b26v89c19zqg8o3fo77f1jlfz83zgsy2sy2hhppfyg1h9
# Endpoint Response Code: 200
# # of Tweets added from this response:  247
# # of Users added from this response:  173
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  1179
# Total number of batch results:  1179
# Total # of Tweets added:  48116
# --------------------------------------
# Batch #:  30
# Request #:  115  | Time cap:  452
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gdj2wj834v5u4prqtek660vjeyl
# # of Tweets added from this response:  470
# # of Users added from this response:  302
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  470
# -------------------
# Request #:  116  | Time cap:  456
# Token:  b26v89c19zqg8o3fo7gdj2wj834v5u4prqtek660vjeyl
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo71f2lyb3f34xnim0ztk5ackib059
# # of Tweets added from this response:  485
# # of Users added from this response:  362
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  955
# -------------------
# Request #:  117  | Time cap:  460
# Token:  b26v89c19zqg8o3fo71f2lyb3f34xnim0ztk5ackib059
# Endpoint Response Code: 200
# # of Tweets added from this response:  77
# # of Users added from this response:  66
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  1032
# Total number of batch results:  1032
# Total # of Tweets added:  49148
# --------------------------------------
# Batch #:  31
# Request #:  118  | Time cap:  463
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufracitxz7seyhypr7i25y5lz1
# # of Tweets added from this response:  464
# # of Users added from this response:  365
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  464
# -------------------
# Request #:  119  | Time cap:  467
# Token:  b26v89c19zqg8o3foseufracitxz7seyhypr7i25y5lz1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77fgztj0wyacz1kyp0vkecr11ful
# # of Tweets added from this response:  473
# # of Users added from this response:  365
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  937
# -------------------
# Request #:  120  | Time cap:  471
# Token:  b26v89c19zqg8o3fo77fgztj0wyacz1kyp0vkecr11ful
# Endpoint Response Code: 200
# # of Tweets added from this response:  240
# # of Users added from this response:  225
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  1177
# Total number of batch results:  1177
# Total # of Tweets added:  50325
# --------------------------------------
# Batch #:  32
# Request #:  121  | Time cap:  475
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ged7pxno3xdr59xh7mao58es1a5
# # of Tweets added from this response:  473
# # of Users added from this response:  377
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  473
# -------------------
# Request #:  122  | Time cap:  479
# Token:  b26v89c19zqg8o3fo7ged7pxno3xdr59xh7mao58es1a5
# Endpoint Response Code: 200
# # of Tweets added from this response:  145
# # of Users added from this response:  120
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  618
# Total number of batch results:  618
# Total # of Tweets added:  50943
# --------------------------------------
# Batch #:  33
# Request #:  123  | Time cap:  482
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshtde7htk9k1wdqvhq964nd0hh19
# # of Tweets added from this response:  451
# # of Users added from this response:  348
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  451
# -------------------
# Request #:  124  | Time cap:  487
# Token:  b26v89c19zqg8o3foshtde7htk9k1wdqvhq964nd0hh19
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosbunzh3xp0vqe77e9mn5facxad19
# # of Tweets added from this response:  461
# # of Users added from this response:  321
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  912
# -------------------
# Request #:  125  | Time cap:  490
# Token:  b26v89c19zqg8o3fosbunzh3xp0vqe77e9mn5facxad19
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7agietkqjabix6qx0l7fwcmao03h
# # of Tweets added from this response:  477
# # of Users added from this response:  392
# # of Places added from this response:  17
# Cumulative # of Tweets in this batch:  1389
# -------------------
# Request #:  126  | Time cap:  495
# Token:  b26v89c19zqg8o3fo7agietkqjabix6qx0l7fwcmao03h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77f1fbecrw823q3h9r5nbz7scvwd
# # of Tweets added from this response:  489
# # of Users added from this response:  434
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  1878
# -------------------
# Request #:  127  | Time cap:  499
# Token:  b26v89c19zqg8o3fo77f1fbecrw823q3h9r5nbz7scvwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77emswvvvptuje1p9ynso30e34ot
# # of Tweets added from this response:  493
# # of Users added from this response:  476
# # of Places added from this response:  18
# Cumulative # of Tweets in this batch:  2371
# -------------------
# Request #:  128  | Time cap:  503
# Token:  b26v89c19zqg8o3fo77emswvvvptuje1p9ynso30e34ot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77e7n959t5qflscg5e5bmxz6zqf1
# # of Tweets added from this response:  489
# # of Users added from this response:  455
# # of Places added from this response:  19
# Cumulative # of Tweets in this batch:  2860
# -------------------
# Request #:  129  | Time cap:  507
# Token:  b26v89c19zqg8o3fo77e7n959t5qflscg5e5bmxz6zqf1
# Endpoint Response Code: 200
# # of Tweets added from this response:  88
# # of Users added from this response:  68
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  2948
# Total number of batch results:  2948
# Total # of Tweets added:  53891
# --------------------------------------
# Batch #:  34
# Request #:  130  | Time cap:  510
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7dga6lb5zx3d43rjbgizrgbk860t
# # of Tweets added from this response:  474
# # of Users added from this response:  383
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  474
# -------------------
# Request #:  131  | Time cap:  514
# Token:  b26v89c19zqg8o3fo7dga6lb5zx3d43rjbgizrgbk860t
# Endpoint Response Code: 200
# # of Tweets added from this response:  431
# # of Users added from this response:  326
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  905
# Total number of batch results:  905
# Total # of Tweets added:  54796
# --------------------------------------
# Batch #:  35
# Request #:  132  | Time cap:  518
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosksbbt5q36hh45cwayl4xtsnvybh
# # of Tweets added from this response:  448
# # of Users added from this response:  324
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  448
# ...
# # of Tweets added from this response:  437
# # of Users added from this response:  347
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  437
# -------------------
# Request #:  131  | Time cap:  502
# Token:  b26v89c19zqg8o3fosbszf6d5pj38h50pf5zd46l2zb0d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gf7voon8bsv0pz58ewfq3oh7o8t
# # of Tweets added from this response:  482
# # of Users added from this response:  383
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  919
# -------------------
# Request #:  132  | Time cap:  506
# Token:  b26v89c19zqg8o3fo7gf7voon8bsv0pz58ewfq3oh7o8t
# Endpoint Response Code: 200
# # of Tweets added from this response:  305
# # of Users added from this response:  226
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  1224
# Total number of batch results:  1224
# Total # of Tweets added:  1893438
# --------------------------------------
# Batch #:  1200
# Request #:  133  | Time cap:  510
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7jdq09x5rnhi8a9p33s7b6s60jnh
# # of Tweets added from this response:  454
# # of Users added from this response:  322
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  454
# -------------------
# Request #:  134  | Time cap:  514
# Token:  b26v89c19zqg8o3fo7jdq09x5rnhi8a9p33s7b6s60jnh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7gdxxs57mcqf70eoj6665r162l4t
# # of Tweets added from this response:  482
# # of Users added from this response:  453
# # of Places added from this response:  12
# Cumulative # of Tweets in this batch:  936
# -------------------
# Request #:  135  | Time cap:  518
# Token:  b26v89c19zqg8o3fo7gdxxs57mcqf70eoj6665r162l4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ad55y19k22o77oh1ikz7e1u2xdp
# # of Tweets added from this response:  488
# # of Users added from this response:  342
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  1424
# -------------------
# Request #:  136  | Time cap:  522
# Token:  b26v89c19zqg8o3fo7ad55y19k22o77oh1ikz7e1u2xdp
# Endpoint Response Code: 200
# # of Tweets added from this response:  64
# # of Users added from this response:  49
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  1488
# Total number of batch results:  1488
# Total # of Tweets added:  1894926
# --------------------------------------
# Batch #:  1201
# Request #:  137  | Time cap:  525
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5wdyx2sx5hugw1j6z6ocqyw7z3x
# # of Tweets added from this response:  463
# # of Users added from this response:  247
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  463
# -------------------
# Request #:  138  | Time cap:  528
# Token:  b26v89c19zqg8o3fos5wdyx2sx5hugw1j6z6ocqyw7z3x
# Endpoint Response Code: 200
# # of Tweets added from this response:  406
# # of Users added from this response:  319
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  869
# Total number of batch results:  869
# Total # of Tweets added:  1895795
# --------------------------------------
# Batch #:  1202
# Request #:  139  | Time cap:  532
# Token:  None
# Endpoint Response Code: 200
# # of Tweets added from this response:  434
# # of Users added from this response:  370
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  434
# Total number of batch results:  434
# Total # of Tweets added:  1896229
# --------------------------------------
# Batch #:  1203
# Request #:  140  | Time cap:  536
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foskt53wlxapn35w248onpyzke194t
# # of Tweets added from this response:  486
# # of Users added from this response:  297
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  486
# -------------------
# Request #:  141  | Time cap:  540
# Token:  b26v89c19zqg8o3foskt53wlxapn35w248onpyzke194t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77ds4v565b8tm5q99eyneitdkuil
# # of Tweets added from this response:  419
# # of Users added from this response:  330
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  905
# -------------------
# Request #:  142  | Time cap:  544
# Token:  b26v89c19zqg8o3fo77ds4v565b8tm5q99eyneitdkuil
# Endpoint Response Code: 200
# # of Tweets added from this response:  339
# # of Users added from this response:  306
# # of Places added from this response:  14
# Cumulative # of Tweets in this batch:  1244
# Total number of batch results:  1244
# Total # of Tweets added:  1897473
# --------------------------------------
# Batch #:  1204
# Request #:  143  | Time cap:  548
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7dffvebv8jf6pzofm7zan844faf1
# # of Tweets added from this response:  468
# # of Users added from this response:  312
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  468
# -------------------
# Request #:  144  | Time cap:  552
# Token:  b26v89c19zqg8o3fo7dffvebv8jf6pzofm7zan844faf1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7dffr566wfm4lmkzjhop3zjek2nx
# # of Tweets added from this response:  473
# # of Users added from this response:  339
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  941
# -------------------
# Request #:  145  | Time cap:  556
# Token:  b26v89c19zqg8o3fo7dffr566wfm4lmkzjhop3zjek2nx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7af8j2yngyxl054sqq9pyesznp8d
# # of Tweets added from this response:  465
# # of Users added from this response:  353
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  1406
# -------------------
# Request #:  146  | Time cap:  559
# Token:  b26v89c19zqg8o3fo7af8j2yngyxl054sqq9pyesznp8d
# Endpoint Response Code: 200
# # of Tweets added from this response:  155
# # of Users added from this response:  120
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  1561
# Total number of batch results:  1561
# Total # of Tweets added:  1899034
# --------------------------------------
# Batch #:  1205
# Request #:  147  | Time cap:  563
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshtssdj5imndwnxxoemiy8vymfzx
# # of Tweets added from this response:  459
# # of Users added from this response:  331
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  459
# -------------------
# Request #:  148  | Time cap:  567
# Token:  b26v89c19zqg8o3foshtssdj5imndwnxxoemiy8vymfzx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos8sczfaafx41zwhaumleq4kvsarh
# # of Tweets added from this response:  461
# # of Users added from this response:  325
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  920
# -------------------
# Request #:  149  | Time cap:  571
# Token:  b26v89c19zqg8o3fos8sczfaafx41zwhaumleq4kvsarh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5wdywrptpny80a8bcsx1gcd4bjx
# # of Tweets added from this response:  466
# # of Users added from this response:  344
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  1386
# -------------------
# Request #:  150  | Time cap:  575
# Token:  b26v89c19zqg8o3fos5wdywrptpny80a8bcsx1gcd4bjx
# Endpoint Response Code: 200
# # of Tweets added from this response:  412
# # of Users added from this response:  315
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  1798
# Total number of batch results:  1798
# Total # of Tweets added:  1900832
# --------------------------------------
# Batch #:  1206
# Request #:  151  | Time cap:  579
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5vjha3uviazkjjvgls09u2pidml
# # of Tweets added from this response:  480
# # of Users added from this response:  359
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  480
# -------------------
# Request #:  152  | Time cap:  583
# Token:  b26v89c19zqg8o3fos5vjha3uviazkjjvgls09u2pidml
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7mf6n0c5d7mzq74ywt7bcpngi16l
# # of Tweets added from this response:  482
# # of Users added from this response:  371
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  962
# -------------------
# Request #:  153  | Time cap:  587
# Token:  b26v89c19zqg8o3fo7mf6n0c5d7mzq74ywt7bcpngi16l
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gb4o4nstanyaet4rzn0i7asigt
# # of Tweets added from this response:  488
# # of Users added from this response:  399
# # of Places added from this response:  11
# Cumulative # of Tweets in this batch:  1450
# -------------------
# Request #:  154  | Time cap:  591
# Token:  b26v89c19zqg8o3fo77gb4o4nstanyaet4rzn0i7asigt
# Endpoint Response Code: 200
# # of Tweets added from this response:  207
# # of Users added from this response:  162
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  1657
# Total number of batch results:  1657
# Total # of Tweets added:  1902489
# --------------------------------------
# Batch #:  1207
# Request #:  155  | Time cap:  594
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufvilzvut08sdkw91qqx2ownst
# # of Tweets added from this response:  470
# # of Users added from this response:  285
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  470
# -------------------
# Request #:  156  | Time cap:  598
# Token:  b26v89c19zqg8o3foseufvilzvut08sdkw91qqx2ownst
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufte6n0yy2x99ah4i31dl1jqf1
# # of Tweets added from this response:  447
# # of Users added from this response:  267
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  917
# -------------------
# Request #:  157  | Time cap:  602
# Token:  b26v89c19zqg8o3foseufte6n0yy2x99ah4i31dl1jqf1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufray3mzfdnj1rh8dsizxsf43h
# # of Tweets added from this response:  484
# # of Users added from this response:  329
# # of Places added from this response:  10
# Cumulative # of Tweets in this batch:  1401
# -------------------
# Request #:  158  | Time cap:  606
# Token:  b26v89c19zqg8o3foseufray3mzfdnj1rh8dsizxsf43h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufra1rvwwcmf2vtat4awuzg48t
# # of Tweets added from this response:  466
# # of Users added from this response:  369
# # of Places added from this response:  8
# Cumulative # of Tweets in this batch:  1867
# -------------------
# Request #:  159  | Time cap:  610
# Token:  b26v89c19zqg8o3foseufra1rvwwcmf2vtat4awuzg48t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufr9genjzx6peaw28qoy1phugt
# # of Tweets added from this response:  467
# # of Users added from this response:  312
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  2334
# -------------------
# Request #:  160  | Time cap:  614
# Token:  b26v89c19zqg8o3foseufr9genjzx6peaw28qoy1phugt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufr95kprnh75csj7pthjqoqpod
# # of Tweets added from this response:  474
# # of Users added from this response:  352
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  2808
# -------------------
# Request #:  161  | Time cap:  618
# Token:  b26v89c19zqg8o3foseufr95kprnh75csj7pthjqoqpod
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos5t0q1u5vi3dn1sdsjrjzyzp324d
# # of Tweets added from this response:  447
# # of Users added from this response:  387
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  3255
# -------------------
# Request #:  162  | Time cap:  622
# Token:  b26v89c19zqg8o3fos5t0q1u5vi3dn1sdsjrjzyzp324d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77f1u9dsxuzf4pne979kydata5q5
# # of Tweets added from this response:  485
# # of Users added from this response:  294
# # of Places added from this response:  4
# Cumulative # of Tweets in this batch:  3740
# -------------------
# Request #:  163  | Time cap:  626
# Token:  b26v89c19zqg8o3fo77f1u9dsxuzf4pne979kydata5q5
# Endpoint Response Code: 200
# # of Tweets added from this response:  69
# # of Users added from this response:  28
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  3809
# Total number of batch results:  3809
# Total # of Tweets added:  1906298
# --------------------------------------
# Batch #:  1208
# Request #:  164  | Time cap:  629
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshv295k7ohskphstf8g15rgwtbwd
# # of Tweets added from this response:  460
# # of Users added from this response:  369
# # of Places added from this response:  3
# Cumulative # of Tweets in this batch:  460
# -------------------
# Request #:  165  | Time cap:  633
# Token:  b26v89c19zqg8o3foshv295k7ohskphstf8g15rgwtbwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ddc3dtinkst5ra3jogwgu2ksry5
# # of Tweets added from this response:  461
# # of Users added from this response:  359
# # of Places added from this response:  6
# Cumulative # of Tweets in this batch:  921
# -------------------
# Request #:  166  | Time cap:  637
# Token:  b26v89c19zqg8o3fo7ddc3dtinkst5ra3jogwgu2ksry5
# Endpoint Response Code: 200
# # of Tweets added from this response:  351
# # of Users added from this response:  273
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  1272
# Total number of batch results:  1272
# Total # of Tweets added:  1907570
# --------------------------------------
# Batch #:  1209
# Request #:  167  | Time cap:  640
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo7ddr6sxjudgkggqzyrhd6cqeeqgt
# # of Tweets added from this response:  472
# # of Users added from this response:  399
# # of Places added from this response:  9
# Cumulative # of Tweets in this batch:  472
# -------------------
# Request #:  168  | Time cap:  644
# Token:  b26v89c19zqg8o3fo7ddr6sxjudgkggqzyrhd6cqeeqgt
# Endpoint Response Code: 200
# # of Tweets added from this response:  275
# # of Users added from this response:  215
# # of Places added from this response:  5
# Cumulative # of Tweets in this batch:  747
# Total number of batch results:  747
# Total # of Tweets added:  1908317
# --------------------------------------
# Batch #:  1210
# Request #:  169  | Time cap:  648
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fosevahe4a1iejj66uwq6ldnd127b1
# # of Tweets added from this response:  430
# # of Users added from this response:  333
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  430
# -------------------
# Request #:  170  | Time cap:  652
# Token:  b26v89c19zqg8o3fosevahe4a1iejj66uwq6ldnd127b1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fo77gqcf3azyw7ehzkcg18imefgrct
# # of Tweets added from this response:  463
# # of Users added from this response:  331
# # of Places added from this response:  7
# Cumulative # of Tweets in this batch:  893
# -------------------
# Request #:  171  | Time cap:  656
# Token:  b26v89c19zqg8o3fo77gqcf3azyw7ehzkcg18imefgrct
# Endpoint Response Code: 200
# # of Tweets added from this response:  365
# # of Users added from this response:  295
# # of Places added from this response:  13
# Cumulative # of Tweets in this batch:  1258
# Total number of batch results:  1258
# Total # of Tweets added:  1909575
# --------------------------------------
# Batch #:  1211
# Request #:  172  | Time cap:  660
# Token:  None
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3fos8sd1jek9x737kh2mrvbbi4ylmyl
# # of Tweets added from this response:  458
# # of Users added from this response:  381
# # of Places added from this response:  1
# Cumulative # of Tweets in this batch:  458
# -------------------
# Request #:  173  | Time cap:  664
# Token:  b26v89c19zqg8o3fos8sd1jek9x737kh2mrvbbi4ylmyl
# Endpoint Response Code: 200
# # of Tweets added from this response:  270
# # of Users added from this response:  213
# # of Places added from this response:  2
# Cumulative # of Tweets in this batch:  728
# Total number of batch results:  728
# Total # of Tweets added:  1910303
# Total number of results:  1910303

# %% [markdown]
# # Fix the data format

# %%
legacy_tweets = pd.read_parquet("./../data/raw/comments.parquet")
tweets = pd.read_csv("./../data/processed/tmp/tweets_replies_skynews.csv")
places = pd.read_csv("./../data/processed/tmp/places_replies_skynews.csv")
skynews_tweets = tweets[(tweets.in_reply_to_user_id==7587032) & (tweets.lang=='en')].drop_duplicates('tweet_id').merge(places[['geo', 'full_name']].drop_duplicates(), how='left')
skynews_tweets['latitude'] = np.nan; skynews_tweets['longitude'] = np.nan
skynews_tweets = skynews_tweets.iloc[:,[0,1,2,4,12,6,11,9,10,7,8,15,14,13]]
skynews_tweets.columns = legacy_tweets.columns

legacy_users = pd.read_parquet("./../data/raw/users.parquet")
users = pd.read_csv("./../data/processed/tmp/users_replies_skynews.csv")
users['favouritesCount'] = users['mediaCount'] = users['location'] = users['protected'] = users['linkUrl'] = users['linkTcourl'] = users['profileImageUrl'] = users['profileBannerUrl'] = None
users = users.iloc[:,[1,2,0,3,3,4,5,6,7,8,10,9,11,12,13,14,15,16,17]]
skynews_users = users.drop_duplicates('author_id')
skynews_users.columns = legacy_users.columns

# %%
df
# Out:
#                    tweetId       conversationId   userId  \
# 0      1387908717480448004  1387908717480448004  7587032
# 1      1387905838241697797  1387905838241697797  7587032
# 2      1387878104136396803  1387878104136396803  7587032
# 3      1387875659448475651  1387875659448475651  7587032
# 4      1387862127793352713  1387862127793352713  7587032
# ...                    ...                  ...      ...
# 29711  1214975841790300160  1214975841790300160  7587032
# 29712  1214870102308511744  1214870102308511744  7587032
# 29713  1214750469039497216  1214750469039497216  7587032
# 29714  1214066701458968577  1214066701458968577  7587032
# 29715  1213916642641612800  1213916642641612800  7587032
#
#                            date  \
# 0     2021-04-29 23:16:39+00:00
# 1     2021-04-29 23:05:12+00:00
# 2     2021-04-29 21:15:00+00:00
# 3     2021-04-29 21:05:17+00:00
# 4     2021-04-29 20:11:31+00:00
# ...                         ...
# 29711 2020-01-08 18:23:08+00:00
# 29712 2020-01-08 11:22:58+00:00
# 29713 2020-01-08 03:27:35+00:00
# 29714 2020-01-06 06:10:32+00:00
# 29715 2020-01-05 20:14:15+00:00
#
#                                                  content lang  \
# 0      All over-40s in England can now book COVID vac...   en
# 1      COVID-19: Which coronavirus variants have been...   en
# 2      Vaccine minister Nadhim Zahawi says he hopes t...   en
# 3      Three stories tonight:\n\n🔴 Ireland announces ...   en
# 4      Some lockdown restrictions in Ireland are to b...   en
# ...                                                  ...  ...
# 29711  Measles has killed nearly three times as many ...   en
# 29712  Measles has killed nearly three times as many ...   en
# 29713  Measles outbreak: Death toll in Democratic Rep...   en
# 29714  Healthcare workers in the Wuhan region are sti...   en
# 29715  Healthcare workers in the Wuhan region are sti...   en
#
#                    sourceLabel  replyCount  retweetCount  likeCount  \
# 0      SkyNews Alerts - Latest          21            52        155
# 1      SkyNews Alerts - Latest          40            11         40
# 2         Twitter Media Studio          36             8         57
# 3              Twitter Web App           8             4         24
# 4                   SocialFlow           7             7         29
# ...                        ...         ...           ...        ...
# 29711               SocialFlow           1            36         45
# 29712               SocialFlow           6            42         47
# 29713  SkyNews Alerts - Latest           9            28         28
# 29714               SocialFlow           5            24         32
# 29715               SocialFlow           8            27         37
#
#        quoteCount  longitude  latitude place
# 0              13        NaN       NaN  None
# 1               0        NaN       NaN  None
# 2               3        NaN       NaN  None
# 3               0        NaN       NaN  None
# 4               2        NaN       NaN  None
# ...           ...        ...       ...   ...
# 29711           9        NaN       NaN  None
# 29712           3        NaN       NaN  None
# 29713           2        NaN       NaN  None
# 29714           9        NaN       NaN  None
# 29715           1        NaN       NaN  None
#
# [29580 rows x 14 columns]

# %%
skynews_tweets
# Out:
#                      tweetId       conversationId               userId  \
# 0        1383659647609884672  1383334925483446274           2780851836
# 1        1383431071019143180  1383334925483446274            171898033
# 2        1383399358050181123  1383334925483446274           1369513495
# 3        1383394492338696201  1383334925483446274            329634252
# 4        1383392021553893386  1383334925483446274              8283902
# ...                      ...                  ...                  ...
# 1015514  1223007718186856449  1223007243311951873  1081613910514511874
# 1015515  1223007683659419649  1223007243311951873            467589704
# 1015516  1223007637740183553  1223007243311951873            244541073
# 1015517  1223007627724148737  1223007243311951873             61525109
# 1015518  1223007445351616515  1223007243311951873           2246377714
#
#                               date  \
# 0        2021-04-18 05:52:21+00:00
# 1        2021-04-17 14:44:04+00:00
# 2        2021-04-17 12:38:03+00:00
# 3        2021-04-17 12:18:43+00:00
# 4        2021-04-17 12:08:54+00:00
# ...                            ...
# 1015514  2020-01-30 22:18:57+00:00
# 1015515  2020-01-30 22:18:48+00:00
# 1015516  2020-01-30 22:18:37+00:00
# 1015517  2020-01-30 22:18:35+00:00
# 1015518  2020-01-30 22:17:52+00:00
#
#                                                    content lang  \
# 0        @SkyNews No it’s not, better than housing in h...   en
# 1        @SkyNews The virus wasn't the problem it was t...   en
# 2        @SkyNews @Mariebe10098426 It certainly was the...   en
# 3        @SkyNews Yes and who do you think brought it i...   en
# 4        @SkyNews https://t.co/LQId1yjlWB\n\nPatel has ...   en
# ...                                                    ...  ...
# 1015514                       @SkyNews Pray for short pipo   en
# 1015515  @SkyNews We need to stop people coming in and ...   en
# 1015516                    @SkyNews The Winchester anyone?   en
# 1015517  @SkyNews Yeh fair enough, but do you have any ...   en
# 1015518  @SkyNews That’s what happens when u eat deep f...   en
#
#                  sourceLabel  replyCount  retweetCount  likeCount  quoteCount  \
# 0         Twitter for iPhone           0             0          0           0
# 1        Twitter for Android           0             0          1           0
# 2           Twitter for iPad           0             1          3           0
# 3         Twitter for iPhone           0             0          1           0
# 4        Twitter for Android           0             1          2           0
# ...                      ...         ...           ...        ...         ...
# 1015514      Twitter Web App           0             0          0           0
# 1015515  Twitter for Android           1             0          1           0
# 1015516  Twitter for Android           0             0         13           0
# 1015517   Twitter for iPhone           1             0          3           0
# 1015518   Twitter for iPhone           4             0         14           0
#
#          longitude  latitude place
# 0              NaN       NaN   NaN
# 1              NaN       NaN   NaN
# 2              NaN       NaN   NaN
# 3              NaN       NaN   NaN
# 4              NaN       NaN   NaN
# ...            ...       ...   ...
# 1015514        NaN       NaN   NaN
# 1015515        NaN       NaN   NaN
# 1015516        NaN       NaN   NaN
# 1015517        NaN       NaN   NaN
# 1015518        NaN       NaN   NaN
#
# [1015519 rows x 14 columns]

# %%
skynews_tweets.to_parquet('./../data/processed/tmp/comments_skynews.parquet')
skynews_users.to_parquet('./../data/processed/tmp/users_skynews.parquet')
