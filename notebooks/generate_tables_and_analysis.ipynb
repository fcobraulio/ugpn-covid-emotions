# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from wordcloud import WordCloud
import geopandas
pd.options.display.max_columns = 100
plt.style.use(['default'])

# %% [markdown]
# # Constants

# %%
themes = [
    'Authorities & Politics', 'Cases and deaths', 'Economic impact', 'Educational impact', 'People stories',
       'Preventive measures', 'Vaccines and vaccination', 'Virus spreading'
]

subthemes = [
    'subtheme11', 'subtheme12', 'subtheme21', 'subtheme22', 'subtheme41', 'subtheme42', 'subtheme43', 
    'subtheme44', 'subtheme51', 'subtheme52', 'subtheme53', 'subtheme61', 'subtheme62', 'subtheme63', 
    'subtheme64', 'subtheme65', 'subtheme66', 'subtheme71', 'subtheme72', 'subtheme73', 'subtheme74'
]

emotions = [
    'anger', 'sadness', 'optimism', 'joy'
]

keywords = [
    'remote working', 'homeschooling', 'panic buying', 'sars-cov-2', 'wearing masks', 'ncov', 'wuhan', 
    'social distancing', 'vaccination', 'quarantine', 'outbreak', 'vaccine', 'lockdown', 'pandemic', 
    'coronavirus', 'covid'
]
keywords2 = [w.replace(' ', '_').replace('-', '_') for w in keywords]

# %% [markdown]
# # Functions

# %%
def millions(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x * 1e-6)

def thousands(x, pos):
    'The two args are the value and tick position'
    return '%1.fm' % (x * 1e-3)

# %% [markdown]
# # Load and process lookup tables

# %%
# Load lookup tables
media_list = pd.read_csv('./../data/external/MediaList.csv', sep=";")
theme_desc = pd.read_csv('./../data/external/theme_desc.csv')
subtheme_desc = pd.read_csv('./../data/external/subtheme_desc.csv')
#topics = pd.read_parquet('./news_tweets_topics.parquet')
topics = pd.read_parquet('./../data/processed/news_tweets_topics_v4.parquet')
news_accounts = pd.read_parquet('./../data/raw/news_accounts.parquet')
users = pd.read_parquet('./../data/raw/users.parquet')

# Process lookup tables
topics['tweetId'] = topics.tweetId.astype('float64')
news_accounts = news_accounts.merge(media_list)
news_accounts['userId'] = news_accounts.userId.astype('float64')

# %% [markdown]
# # Load and process News Tweets

# %%
# Load news tweets
news_tweets = pd.read_parquet('./../data/raw/news_tweets_with_em_scores.parquet')

# Define prevalent emotion and emotion score
news_tweets['emotion_score'] = news_tweets[['anger','joy','optimism','sadness']].max(axis=1)
news_tweets['prevalent_emotion'] = news_tweets[['anger','joy','optimism','sadness']].idxmax(axis=1)
news_tweets['prevalent_emotion'] = np.where(news_tweets.emotion_score>0.5, news_tweets.prevalent_emotion, 'undefined')

# Include country information and filter valid news accountsw
news_tweets = news_tweets.merge(news_accounts[['userId','country']])
news_tweets = news_tweets[~news_tweets[emotions].isnull().any(axis=1)]
news_tweets = news_tweets.sort_values('date').drop_duplicates('conversationId', keep='first')
news_tweets = news_tweets[news_tweets.lang=='en']
print('Number of valid news tweets:', news_tweets.shape[0])

# Include theme and subtheme
news_tweets = news_tweets[~news_tweets.conversationId.isnull()].merge(topics[['theme'] + subthemes + ['tweetId']], how='left', on='tweetId')
news_tweets['subtheme'] = news_tweets[subthemes].idxmax(axis=1)
news_tweets['subtheme'] = news_tweets.subtheme.apply(lambda x: int(x[-2:]))
news_tweets['aux'] = news_tweets[subthemes].sum(axis=1)
news_tweets.loc[news_tweets.aux==0,'subtheme'] = news_tweets.loc[news_tweets.aux==0,'theme']*10
news_tweets = news_tweets.drop(subthemes + ['aux'], axis=1)

# Include date and week features
news_tweets['ds'] = news_tweets.date.dt.date
news_tweets['dsw'] = (news_tweets['date'] + pd.offsets.Week(weekday=6)).dt.date
# Out:
# Number of valid news tweets: 1678217

# %% [markdown]
# # Load and process Comments

# %%
# Load valid comments
plain_comments = pd.read_parquet('./../data/raw/comments.parquet')
comments = pd.read_parquet('./../data/raw/user_tweets_with_em_scores.parquet')
comments = comments[comments.tweetId.isin(plain_comments.tweetId)]; del plain_comments
comments = comments[comments.conversationId.isin(news_tweets.conversationId)]
comments = comments[~comments[emotions].isnull().any(axis=1)]
comments = comments[comments.lang=='en']
print('Number of valid comments:', comments.shape[0])

# Include news tweet data
comments = comments.merge(news_tweets.rename(columns={
    'date':'news_date', 'userId':'news_id', 'prevalent_emotion':'news_prevalent_emotion', 'emotion_score':'news_emotion_score',
    'anger':'news_anger', 'sadness':'news_sadness', 'optimism':'news_optimism', 'joy':'news_joy'
})[[
    'conversationId', 'news_date', 'news_id', 'news_prevalent_emotion', 'news_emotion_score', 
    'news_anger', 'news_sadness', 'news_optimism', 'news_joy', 'theme', 'subtheme', 'country'
]], how='left')

# Define prevalent emotion and emotion score
comments['emotion_score'] = comments[['anger','joy','optimism','sadness']].max(axis=1)
comments['prevalent_emotion'] = comments[['anger','joy','optimism','sadness']].idxmax(axis=1)
comments['prevalent_emotion'] = np.where(comments.emotion_score>0.5, comments.prevalent_emotion, 'undefined')

# Define continent information
comments = comments.merge(pd.DataFrame({
    'country':['AU', 'UK', 'US', 'CA', 'NZ', 'ZA', 'KE', 'NG', 'IN', 'PH', 'MY','IE'],
    'continent':['Oceania', 'Europe', 'America', 'America', 'Oceania', 'Africa', 'Africa', 'Africa', 'Asia', 'Asia', 'Asia', 'Europe']
}))

# Include date, week and month features
comments['ds'] = comments.news_date.dt.date
comments['dsw'] = (comments['news_date'] + pd.offsets.Week(weekday=6)).dt.date
comments['dsm'] = pd.to_datetime(comments.news_date.dt.year.astype(str) + '-' + comments.news_date.dt.month.astype(str) + '-1')
# Out:
# Number of valid comments: 17620904

# %%
news_tweets.userId.nunique()
# Out:
# 275

# %% [markdown]
# # Tables

# %% [markdown]
# ### General emotion mean

# %%
g = comments[emotions].mean()

# %% [markdown]
# ### Table: News Tweets Engagement

# %%
np.round(news_tweets.groupby('prevalent_emotion')[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].mean(),1)
# Out:
#                    replyCount  retweetCount  likeCount  quoteCount
# prevalent_emotion
# anger                    20.7          36.8      113.2        11.0
# joy                       8.0          22.5       97.7         7.5
# optimism                 11.0          22.6       87.8         6.7
# sadness                   9.5          24.9       66.7         6.6
# undefined                10.6          22.4       73.0         7.2

# %% [markdown]
# ### Table: Emotion over Themes

# %%
eot = comments.groupby(['theme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    eot['lift_' + col] = np.round(eot[col] / g[col], 2)
    
eot = eot[['theme'] + ['lift_' + col for col in emotions]]
eot
# Out:
#    theme  lift_anger  lift_sadness  lift_optimism  lift_joy
# 0      1        0.94          1.19           1.02      0.94
# 1      2        1.01          0.95           1.03      1.00
# 2      3        0.95          1.07           1.06      1.06
# 3      4        0.93          1.20           0.97      1.02
# 4      5        1.07          0.89           0.93      0.96
# 5      6        0.99          1.00           0.98      1.07
# 6      7        1.01          1.01           1.00      0.93
# 7      8        0.93          0.98           1.21      1.09

# %% [markdown]
# ### Table: Top News Accounts per Emotion over Themes

# %%
accounts_emotions = comments.groupby(['continent', 'country', 'news_id']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    accounts_emotions['lift_' + col] = accounts_emotions[col] / g[col]

accounts_emotions[['lift_'+col for col in emotions]].max()

engaged_news = news_tweets.groupby('userId').tweetId.count()
engaged_news = list(engaged_news[engaged_news > 484].index)

accounts_emotions = accounts_emotions[
    (accounts_emotions.news_id.isin(engaged_news)) & (accounts_emotions.tweetId > 484)
].merge(news_accounts.drop('country',axis=1), left_on='news_id', right_on='userId', how='left')

# %%
top_news = pd.DataFrame(columns=accounts_emotions.columns)
for emotion in emotions:
    tmp = accounts_emotions[~accounts_emotions.news_id.isin(top_news.news_id.values)].sort_values(emotion).tail(5)
    tmp['main_emotion'] = emotion
    tmp['rank_emotion'] = range(1,6)
    tmp['score_emotion'] = tmp[emotion].values
    top_news = pd.concat([top_news, tmp])

# %%
account_emotions_themes = news_tweets[
    news_tweets.userId.isin(top_news.userId.values)
].groupby('userId').theme.value_counts(normalize=True).rename('prop').reset_index().merge(theme_desc)

account_emotions_themes = account_emotions_themes.pivot('userId', 'theme_desc', 'prop').reset_index()

account_emotions_themes = account_emotions_themes.merge(
    news_accounts[['userId', 'displayname', 'description', 'country', 'followersCount']]
).merge(
    top_news[['userId', 'main_emotion', 'rank_emotion', 'score_emotion']]
)[['displayname', 'country', 'followersCount', 'description', 'main_emotion', 'rank_emotion', 'score_emotion'] + themes]

account_emotions_themes.iloc[:,-9:] = np.round(account_emotions_themes.iloc[:,-9:].values * 100,1)
account_emotions_themes.to_csv('./../data/processed/account_emotions_themes.csv', index=False, sep=';')
account_emotions_themes
# Out:
#                displayname country  followersCount  \
# 0                 Fox News      US        20185319
# 1                    MSNBC      US         4219331
# 2            Business Line      IN           81101
# 3             CNN Politics      US         4136271
# 4     Manila Bulletin News      PH          858950
# 5               BellaNaija      NG         1787670
# 6           BusinessMirror      PH           36128
# 7            Oneindia News      IN           64578
# 8              BBC Radio 4      UK          530100
# 9                  Mid Day      IN          670388
# 10              Herald Sun      AU          331964
# 11        The Manila Times      PH           99957
# 12  The New Indian Express      IN          468124
# 13               Firstpost      IN         2085726
# 14      Free Press Journal      IN           23101
# 15     The Hindu-Hyderabad      IN           56519
# 16          Breitbart News      US         1471106
# 17    All India Radio News      IN         2743864
# 18                 DD News      IN         3233823
# 19        Phil News Agency      PH           27594
#
#                                           description main_emotion  \
# 0   Follow America's #1 cable news network, delive...        anger
# 1   The place for in-depth analysis, political com...        anger
# 2   Business Daily from The Hindu group of newspap...     optimism
# 3   Political news, campaign stories and Washingto...        anger
# 4   Breaking news and stories from different sides...     optimism
# 5   We LOVE Everything Fab & African - Fashion, Mu...          joy
# 6                  A broader look at today’s business     optimism
# 7   oneindia.com is a gamut of online resources. F...      sadness
# 8   Your friendly lockdown companion - documentari...          joy
# 9   All things #MadeinMumbai \nNews | Entertainmen...          joy
# 10  Join the conversation on all the news from Mel...        anger
# 11  The Manila Times is one of the leading nationa...     optimism
# 12  All the tweets for breaking news & views.\nFac...      sadness
# 13  Incisive opinions, in-depth analysis and views...      sadness
# 14  The voice of #Mumbai. The Free Press Journal i...      sadness
# 15  The official account of The Hindu's reporters ...      sadness
# 16  News, commentary, and destruction of the polit...        anger
# 17  Official account of News Services Division, Al...          joy
# 18  Official Twitter account of DD News, the Publi...          joy
# 19  The official Twitter account of Philippine New...     optimism
#
#     rank_emotion  score_emotion  Authorities & Politics  Cases and deaths  \
# 0            4.0           61.8                    30.4               4.3
# 1            2.0           60.5                    28.5               7.8
# 2            2.0           30.8                    15.2              10.7
# 3            5.0           61.8                    33.3               4.4
# 4            1.0           27.0                    11.4              15.0
# 5            3.0           27.1                    20.9               4.6
# 6            5.0           39.6                     7.0               5.3
# 7            2.0           27.4                    25.1              13.8
# 8            5.0           38.2                    30.1               2.1
# 9            4.0           33.7                    23.1               9.1
# 10           1.0           60.3                    28.1               9.0
# 11           4.0           34.5                     6.0               6.5
# 12           4.0           32.5                    17.1               8.6
# 13           5.0           34.0                    15.4              13.6
# 14           3.0           28.6                    25.2              14.6
# 15           1.0           26.1                    24.7              15.0
# 16           3.0           61.1                    21.8               5.2
# 17           1.0           22.2                    25.4              22.7
# 18           2.0           23.3                    30.8              18.7
# 19           3.0           32.9                     8.1               9.7
#
#     Economic impact  Educational impact  People stories  Preventive measures  \
# 0              21.2                 4.0             9.5                 14.7
# 1              24.5                 5.0             7.8                 10.9
# 2              35.6                 2.0             5.1                 13.4
# 3              29.0                 2.9             7.2                 11.3
# 4              23.9                 2.9            10.6                 22.0
# 5              39.0                 7.0             4.3                 16.0
# 6              39.9                 4.0             3.8                 27.0
# 7              15.3                 2.0             9.5                 20.8
# 8              24.5                 5.1             9.1                 18.0
# 9              18.8                 3.8             9.2                 26.7
# 10             22.3                 3.9             5.1                 20.6
# 11             30.8                 3.6             5.6                 36.2
# 12             22.7                 4.2            10.4                 23.8
# 13             26.9                 3.0             7.7                 21.3
# 14             16.2                 3.1            10.5                 19.5
# 15             16.4                 2.7            15.1                 17.7
# 16             26.6                 3.7             8.5                 20.3
# 17             15.3                 1.7             7.6                 15.1
# 18             16.6                 1.8             5.9                 14.0
# 19             26.8                 3.0             5.9                 34.5
#
#     Vaccines and vaccination  Virus spreading
# 0                        9.2              6.7
# 1                        6.6              8.7
# 2                        8.4              9.7
# 3                        3.7              8.0
# 4                        8.2              6.2
# 5                        1.9              6.4
# 6                        6.0              7.1
# 7                        7.7              5.8
# 8                        4.1              7.0
# 9                        4.5              4.8
# 10                       3.4              7.6
# 11                       3.9              7.5
# 12                       4.7              8.5
# 13                       5.1              7.0
# 14                       6.5              4.4
# 15                       3.6              4.9
# 16                       2.7             11.1
# 17                       7.5              4.6
# 18                       7.7              4.6
# 19                       7.8              4.2

# %%
grouped_account_emotions_themes = pd.DataFrame()
for emotion in emotions:
    tmp = news_tweets[
        news_tweets.userId.isin(top_news[top_news.main_emotion==emotion].userId.values)
    ].theme.value_counts(normalize=True).reset_index()
    tmp.columns = ['theme', 'prop']
    tmp = tmp.merge(theme_desc)
    tmp['main_emotion'] = emotion
    grouped_account_emotions_themes = pd.concat([grouped_account_emotions_themes, tmp])
grouped_account_emotions_themes = grouped_account_emotions_themes.pivot('main_emotion', 'theme_desc', 'prop').reset_index()
grouped_account_emotions_themes.iloc[:,-8:] = np.round(grouped_account_emotions_themes.iloc[:,-8:]*100,1)
grouped_account_emotions_themes
# Out:
# theme_desc main_emotion  Authorities & Politics  Cases and deaths  \
# 0                 anger                    29.0               6.8
# 1                   joy                    25.8              18.0
# 2              optimism                    10.1              11.0
# 3               sadness                    22.7              13.4
#
# theme_desc  Economic impact  Educational impact  People stories  \
# 0                      25.4                 4.1             7.3
# 1                      17.4                 2.5             7.6
# 2                      29.0                 3.0             7.3
# 3                      18.3                 2.8             9.8
#
# theme_desc  Preventive measures  Vaccines and vaccination  Virus spreading
# 0                          13.8                       5.0              8.5
# 1                          17.4                       6.6              4.8
# 2                          25.7                       7.3              6.6
# 3                          20.7                       6.4              5.8

# %%
global_emotions_themes = news_tweets.theme.value_counts(normalize=True).reset_index()
global_emotions_themes.columns = ['theme', 'prop']
global_emotions_themes = global_emotions_themes.merge(theme_desc).drop(columns='theme')
global_emotions_themes = global_emotions_themes.set_index('theme_desc').transpose()
np.round(global_emotions_themes[themes] * 100, 2)
# Out:
# theme_desc  Authorities & Politics  Cases and deaths  Economic impact  \
# prop                         17.49             11.58            24.14
#
# theme_desc  Educational impact  People stories  Preventive measures  \
# prop                      3.65            8.65                20.01
#
# theme_desc  Vaccines and vaccination  Virus spreading
# prop                            6.02             8.46

# %% [markdown]
# ### Table: Subthemes per Top News Accounts

# %%
global_subtheme = news_tweets.subtheme.value_counts(normalize=True).reset_index()
global_subtheme.columns = ['subtheme', 'global']
global_subtheme['global'] = np.round(global_subtheme['global'] * 100, 2)
global_subtheme = global_subtheme.merge(subtheme_desc).sort_values('subtheme')

subtheme_top_accounts = pd.DataFrame()
for emotion in emotions:
    tmp = news_tweets[
        news_tweets.userId.isin(top_news[top_news.main_emotion==emotion].userId.values)
    ].subtheme.value_counts(normalize=True).reset_index()
    tmp.columns = ['subtheme', 'prop']
    tmp = tmp.merge(subtheme_desc)
    tmp['main_emotion'] = emotion
    subtheme_top_accounts = pd.concat([subtheme_top_accounts, tmp])
subtheme_top_accounts = subtheme_top_accounts.pivot('subtheme_desc', 'main_emotion', 'prop').reset_index()
subtheme_top_accounts.iloc[:,-4:] = np.round(subtheme_top_accounts.iloc[:,-4:]*100,2)
subtheme_top_accounts = subtheme_top_accounts.merge(global_subtheme[['subtheme_desc', 'global']])
subtheme_top_accounts.to_csv('./../data/processed/subthemes_top_news.csv', index=False, sep=';')
subtheme_top_accounts
# Out:
#                                         subtheme_desc  anger    joy  optimism  \
# 0                    Authorities & Politics (default)  13.54  18.20      7.52
# 1                          Cases and deaths (default)   3.89  11.34      7.28
# 2                         Cases and deaths decreasing   0.51   0.47      0.40
# 3                         Cases and deaths increasing   2.43   6.15      3.34
# 4                                 Easing restrictions   0.06   0.04      0.13
# 5                           Economic impact (default)  12.85  10.18     13.89
# 6   Economic impact over national economies and bi...   6.90   4.03      6.10
# 7    Economic plans to support jobs and food programs   5.62   3.22      9.00
# 8                        Educational impact (default)   4.13   2.46      2.98
# 9                                           Elections   0.48   0.12      0.11
# 10                                     Family stories   0.38   0.25      0.19
# 11                           Festivities and holidays   0.12   0.04      0.10
# 12                                 Health authorities   2.11   1.13      0.25
# 13                                     Heatlh workers   0.08   0.03      0.05
# 14                               Jail system and cops   0.10   0.07      0.19
# 15                               Mental health impact   0.01   0.01      0.01
# 16                              Mobility restrictions   3.75   9.58      7.61
# 17                             New waves and variants   0.39   0.20      0.38
# 18                       Non-pharmacological measures   0.20   0.14      0.15
# 19                  Nursing homes and elderly victims   0.24   0.04      0.01
# 20                      Outbreak and pandemic origins   2.02   1.05      1.21
# 21      People against restrictions or breaking rules   0.32   0.04      0.21
# 22                           People stories (default)   6.54   7.21      6.95
# 23                              Political authorities  12.91   6.35      2.22
# 24                      Preventive measures (default)   8.64   7.22     16.63
# 25                             Research and treatment   1.00   0.55      1.13
# 26                               Travelling protocols   0.76   0.36      0.87
# 27                 Vaccines and vaccination (default)   4.97   6.58      7.30
# 28                          Virus spreading (default)   5.05   2.95      3.83
#
#     sadness  global
# 0     16.75   12.81
# 1      7.42    7.24
# 2      0.63    0.49
# 3      5.38    3.85
# 4      0.06    0.08
# 5     10.64   14.15
# 6      3.60    4.64
# 7      4.07    5.35
# 8      2.84    3.65
# 9      0.23    0.19
# 10     0.43    0.43
# 11     0.04    0.14
# 12     0.61    0.74
# 13     0.03    0.07
# 14     0.24    0.17
# 15     0.00    0.00
# 16    10.57    7.69
# 17     0.35    0.56
# 18     0.16    0.21
# 19     0.01    0.12
# 20     1.45    1.90
# 21     0.20    0.24
# 22     9.15    7.93
# 23     5.08    3.75
# 24     9.11   10.89
# 25     0.94    1.22
# 26     0.58    0.76
# 27     6.41    6.02
# 28     3.03    4.71

# %% [markdown]
# # Tweets examples

# %%
news_tweets.sample(25, random_state=99).merge(news_accounts, on='userId')
# Out:
#          tweetId  conversationId        userId                      date  \
# 0   1.241270e+18    1.241270e+18  3.632741e+07 2020-03-21 07:45:28+00:00
# 1   1.239467e+18    1.239467e+18  3.471336e+07 2020-03-16 08:23:58+00:00
# 2   1.318492e+18    1.318492e+18  7.117605e+17 2020-10-20 10:00:00+00:00
# 20  PHOTOS: Crowds at NIMC offices for #NIN regist...   en
# 21  Woman Sues Ex-Employer Alleging She Was Wrongf...   en
# 22  London's BFI Southbank cinema is closing amid ...   en
# 23  Number of Covid vaccine first doses administer...   en
# 24  Hope amid coronavirus outbreak: Tagle appeals ...   en
#
#                        sourceLabel  replyCount  retweetCount  likeCount  \
# 0                        TweetDeck         1.0           3.0       31.0
# 1                       SocialFlow         3.0          41.0       60.0
# 2             Twitter Media Studio         1.0           3.0       21.0
# 3                        TweetDeck         0.0           4.0       30.0
# 4                        TweetDeck        47.0          79.0      229.0
# 5                       SocialFlow        79.0         118.0      498.0
# 6                       SocialFlow        25.0          49.0       77.0
# 7   Twitter Media Studio - LiveCut         3.0           2.0       26.0
# 8                          dlvr.it         0.0           1.0        4.0
# 9                        TweetDeck         3.0           1.0        9.0
# 10                  Hootsuite Inc.         8.0          16.0       21.0
# 11                       TweetDeck         0.0           2.0        7.0
# 12                       TweetDeck         0.0           2.0        4.0
# 13                       TweetDeck         2.0          21.0      145.0
# 14                         Echobox         7.0           3.0        6.0
# 15                         dlvr.it         2.0           8.0       17.0
# 16                 Twitter Web App         1.0          12.0       30.0
# 17                       TweetDeck         2.0           4.0       27.0
# 18              ht-twitter-handler         0.0           0.0        1.0
# 19                         Echobox         0.0           4.0        6.0
# 20                 Twitter Web App        24.0          97.0      177.0
# 21                      SocialFlow         1.0           1.0        6.0
# 22                      SocialFlow         0.0           8.0       38.0
# 23                        Sendible         1.0           2.0        3.0
# 24                       TweetDeck         1.0           4.0       55.0
#
#     quoteCount  longitude  latitude place  anger    joy  optimism  sadness  \
# 0          0.0        NaN       NaN  None  0.089  0.015     0.027    0.868
# 1          5.0        NaN       NaN  None  0.351  0.032     0.113    0.503
# 2          1.0        NaN       NaN  None  0.058  0.027     0.295    0.620
# 3          0.0        NaN       NaN  None  0.184  0.083     0.091    0.642
# 4         21.0        NaN       NaN  None  0.243  0.008     0.043    0.705
# 5          8.0        NaN       NaN  None  0.098  0.150     0.601    0.151
# 6          2.0        NaN       NaN  None  0.744  0.022     0.076    0.158
# 7          1.0        NaN       NaN  None  0.155  0.095     0.528    0.222
# 8          1.0        NaN       NaN  None  0.102  0.013     0.067    0.819
# 9          1.0        NaN       NaN  None  0.023  0.006     0.012    0.959
# 10         8.0        NaN       NaN  None  0.186  0.011     0.021    0.781
# 11         0.0        NaN       NaN  None  0.078  0.464     0.188    0.271
# 12         0.0        NaN       NaN  None  0.269  0.027     0.150    0.554
# 13         3.0        NaN       NaN  None  0.062  0.674     0.195    0.068
# 14         1.0        NaN       NaN  None  0.109  0.125     0.243    0.523
# 15         1.0        NaN       NaN  None  0.476  0.036     0.098    0.389
# 16         0.0        NaN       NaN  None  0.183  0.261     0.350    0.207
# 17         2.0        NaN       NaN  None  0.140  0.076     0.346    0.439
# 18         0.0        NaN       NaN  None  0.754  0.008     0.025    0.213
# 19         0.0        NaN       NaN  None  0.121  0.028     0.037    0.814
# 20        11.0        NaN       NaN  None  0.094  0.534     0.240    0.132
# 21         0.0        NaN       NaN  None  0.859  0.008     0.024    0.110
# 22         1.0        NaN       NaN  None  0.083  0.010     0.019    0.888
# 23         1.0        NaN       NaN  None  0.060  0.696     0.153    0.092
# 24         0.0        NaN       NaN  None  0.048  0.044     0.395    0.514
#
#     emotion_score prevalent_emotion country_x  theme  subtheme          ds  \
# 0           0.868           sadness        IN      1        11  2020-03-21
# 1           0.503           sadness        US      7        71  2020-03-16
# 2           0.620           sadness        IN      7        72  2020-10-20
# 3           0.642           sadness        IN      6        60  2020-07-26
# 4           0.705           sadness        US      2        22  2020-02-17
# 5           0.601          optimism        US      5        51  2020-10-19
# 6           0.744             anger        US      4        40  2020-03-13
# 7           0.528          optimism        IN      8        80  2021-04-18
# 8           0.819           sadness        IE      2        20  2020-07-23
# 9           0.959           sadness        UK      4        40  2021-03-23
# 10          0.781           sadness        ZA      4        40  2020-02-11
# 11          0.464         undefined        IN      6        60  2021-03-23
# 12          0.554           sadness        UK      2        20  2020-04-18
# 13          0.674               joy        IN      8        80  2021-01-12
# 14          0.523           sadness        CA      8        80  2021-02-02
# 15          0.476         undefined        NG      2        20  2020-04-03
# 16          0.350         undefined        CA      5        50  2021-02-09
# 17          0.439         undefined        PH      2        21  2020-04-14
# 18          0.754             anger        IN      6        61  2020-09-24
# 19          0.814           sadness        UK      2        20  2020-03-21
# 20          0.534               joy        NG      7        73  2020-12-21
# 21          0.859             anger        US      5        50  2020-11-16
# 22          0.888           sadness        US      3        30  2020-03-17
# 23          0.696               joy        IE      4        40  2021-01-22
# 24          0.514           sadness        PH      2        20  2020-03-14
#
#            dsw         username             displayname  \
# 0   2020-03-22         htTweets         Hindustan Times
# 1   2020-03-22         business               Bloomberg
# 2   2020-10-25          WIONews                    WION
# 3   2020-08-02          WIONews                    WION
# 4   2020-02-23              CNN                     CNN
# 5   2020-10-25      CNNPolitics            CNN Politics
# 6   2020-03-15      CNNPolitics            CNN Politics
# 7   2021-04-25         TimesNow               TIMES NOW
# 8   2020-07-26    irishexaminer          Irish Examiner
# 9   2021-03-28      DailyMirror              The Mirror
# 10  2020-02-16           News24                  News24
# 11  2021-03-28              dna                     DNA
# 12  2020-04-19    Daily_Express           Daily Express
# 13  2021-01-17     timesofindia      The Times Of India
# 14  2021-02-07     nationalpost           National Post
# 15  2020-04-05  vanguardngrnews     Vanguard Newspapers
# 16  2021-02-14        CBCAlerts         CBC News Alerts
# 17  2020-04-19   cnnphilippines         CNN Philippines
# 18  2020-09-27   HindustanTimes         Hindustan Times
# 19  2020-03-22      Independent         The Independent
# 20  2020-12-27       thecableng                TheCable
# 21  2020-11-22            NBCLA         NBC Los Angeles
# 22  2020-03-22              THR  The Hollywood Reporter
# 23  2021-01-24   breakingnewsie         breakingnews.ie
# 24  2020-03-15        ANCALERTS    ABS-CBN News Channel
#
#                                           description  \
# 0   One of India's largest media companies. Latest...
# 1                    The first word in business news.
# 2   #WION: World Is One | Welcome to India’s first...
# 3   #WION: World Is One | Welcome to India’s first...
# 4   It’s our job to #GoThere & tell the most diffi...
# 5   Political news, campaign stories and Washingto...
# 6   Political news, campaign stories and Washingto...
# 7   TIMES NOW is India’s most watched English news...
# 8   Trusted coverage from irishexaminer.com | Shar...
# 9   The official Mirror Twitter account \n(Daily M...
# 10  South Africa's premier online news resource. F...
# 11  Follow us for news, photos, videos and the lat...
# 12  Express.co.uk - Home of the Daily and Sunday E...
# 13  News. Views. Analysis. Conversations. India’s ...
# 14  News, analysis and commentary by the National ...
# 15  Latest news from Nigeria.\r\nPolitics, busines...
# 16  Breaking national and international news alert...
# 17             News you can trust • Free TV channel 9
# 18  One of India's largest media companies. Latest...
# 19  News, comment and features from The Independen...
# 20             Nigeria's independent online newspaper
# 21  Welcome to @NBCLA, the place for news, weather...
# 22  The Hollywood Reporter is the premier destinat...
# 23  Ireland's premier breaking news website provid...
# 24  News updates & breaking news from the Philippi...
#
#                                        rawDescription  verified  \
# 0   One of India's largest media companies. Latest...      True
# 1                    The first word in business news.      True
# 2   #WION: World Is One | Welcome to India’s first...      True
# 3   #WION: World Is One | Welcome to India’s first...      True
# 4   It’s our job to #GoThere & tell the most diffi...      True
# 5   Political news, campaign stories and Washingto...      True
# 6   Political news, campaign stories and Washingto...      True
# 7   TIMES NOW is India’s most watched English news...      True
# 8   Trusted coverage from https://t.co/KisLhDt4hz ...      True
# 9   The official Mirror Twitter account \n(Daily M...      True
# 10  South Africa's premier online news resource. F...      True
# 11  Follow us for news, photos, videos and the lat...      True
# 12  http://t.co/xNo7rgb8JJ - Home of the Daily and...      True
# 13  News. Views. Analysis. Conversations. India’s ...      True
# 14  News, analysis and commentary by the National ...      True
# 15  Latest news from Nigeria.\r\nPolitics, busines...      True
# 16  Breaking national and international news alert...      True
# 17             News you can trust • Free TV channel 9      True
# 18  One of India's largest media companies. Latest...      True
# 19  News, comment and features from The Independen...      True
# 20             Nigeria's independent online newspaper      True
# 21  Welcome to @NBCLA, the place for news, weather...      True
# 22  The Hollywood Reporter is the premier destinat...      True
# 23  Ireland's premier breaking news website provid...      True
# 24  News updates & breaking news from the Philippi...      True
#
#                      created  followersCount  friendsCount  statusesCount  \
# 0  2009-04-29 10:11:34+00:00         8078225           132         899060
# 1  2009-04-23 20:05:17+00:00         7324238          1321         680486
# 2  2016-03-21 03:44:54+00:00          341172            96         176490
# 3  2016-03-21 03:44:54+00:00          341172            96         176490
# 4  2007-02-09 00:35:02+00:00        53851246          1101         340498
# 5  2008-02-23 03:12:49+00:00         4136271           344         200996
# 6  2008-02-23 03:12:49+00:00         4136271           344         200996
# 7  2011-01-20 12:17:23+00:00        10059534           377         674240
# 8  2009-02-02 12:01:29+00:00          218041           598         398735
# 9  2008-10-21 14:58:45+00:00         1258436          4144         774917
# 10 2008-05-08 07:45:58+00:00         3973461           683         359785
# 11 2008-11-28 15:39:38+00:00         2242480           349         617306
# 12 2008-12-05 12:05:48+00:00          883127           718         897032
# 13 2010-04-19 10:50:15+00:00        13672720           470         665993
# 14 2008-03-25 16:25:25+00:00          896457           157         353781
# 0          Hindustan Times      Newspaper
# 1                Bloomberg        Website
# 2                Zee Media      Newspaper
# 3                Zee Media      Newspaper
# 4                      CNN     Television
# 5                      CNN     Television
# 6                      CNN     Television
# 7                TIMES NOW     Television
# 8           Irish Examiner      Newspaper
# 9             Daily Mirror      Newspaper
# 10                  News24        Website
# 11               Zee Media      Newspaper
# 12            Daily Mirror      Newspaper
# 13      The Times Of India      Newspaper
# 14           National Post      Newspaper
# 15     Vanguard Newspapers      Newspaper
# 16                     CBC     Television
# 17                     CNN     Television
# 18         Hindustan Times      Newspaper
# 19         The Independent      Newspaper
# 20                TheCable        Website
# 21                     NBC     Television
# 22  The Hollywood Reporter        Website
# 23            BreakingNews        Website
# 24                 ABS-CBN     Television

# %%
news_tweets.columns
# Out:
# Index(['tweetId', 'conversationId', 'userId', 'date', 'content', 'lang',
#        'sourceLabel', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'longitude', 'latitude', 'place', 'anger', 'joy', 'optimism', 'sadness',
#        'emotion_score', 'prevalent_emotion', 'country', 'theme', 'subtheme',
#        'ds', 'dsw'],
#       dtype='object')

# %%
news_tweets.sample(25, random_state=99).merge(news_accounts, on=('userId','country')).iloc[[4,5,8,18]]
# Out:
#          tweetId  conversationId        userId                      date  \
# 4   1.229537e+18    1.229537e+18  7.592510e+05 2020-02-17 22:45:01+00:00
# 5   1.318225e+18    1.318225e+18  1.385042e+07 2020-10-19 16:20:05+00:00
# 8   1.286285e+18    1.286285e+18  1.990336e+07 2020-07-23 13:00:32+00:00
# 18  1.309171e+18    1.309171e+18  1.066973e+18 2020-09-24 16:39:54+00:00
#
#                                               content lang  \
# 4   Apple has warned investors that the ongoing co...   en
# 5   Dr. Anthony Fauci said he is "absolutely not" ...   en
# 8   Data collection in new Covid-19 app ‘troubling...   en
# 18  No refund on lockdown flights originating outs...   en
#
#            sourceLabel  replyCount  retweetCount  likeCount  quoteCount  \
# 4            TweetDeck        47.0          79.0      229.0        21.0
# 5           SocialFlow        79.0         118.0      498.0         8.0
# 8              dlvr.it         0.0           1.0        4.0         1.0
# 18  ht-twitter-handler         0.0           0.0        1.0         0.0
#
#     longitude  latitude place  anger    joy  optimism  sadness  emotion_score  \
# 4         NaN       NaN  None  0.243  0.008     0.043    0.705          0.705
# 5         NaN       NaN  None  0.098  0.150     0.601    0.151          0.601
# 8         NaN       NaN  None  0.102  0.013     0.067    0.819          0.819
# 18        NaN       NaN  None  0.754  0.008     0.025    0.213          0.754
#
#    prevalent_emotion country  theme  subtheme          ds         dsw  \
# 4            sadness      US      2        22  2020-02-17  2020-02-23
# 5           optimism      US      5        51  2020-10-19  2020-10-25
# 8            sadness      IE      2        20  2020-07-23  2020-07-26
# 18             anger      IN      6        61  2020-09-24  2020-09-27
#
#           username      displayname  \
# 4              CNN              CNN
# 5      CNNPolitics     CNN Politics
# 8    irishexaminer   Irish Examiner
# 18  HindustanTimes  Hindustan Times
#
#                                           description  \
# 4   It’s our job to #GoThere & tell the most diffi...
# 5   Political news, campaign stories and Washingto...
# 8   Trusted coverage from irishexaminer.com | Shar...
# 18  One of India's largest media companies. Latest...
#
#                                        rawDescription  verified  \
# 4   It’s our job to #GoThere & tell the most diffi...      True
# 5   Political news, campaign stories and Washingto...      True
# 8   Trusted coverage from https://t.co/KisLhDt4hz ...      True
# 18  One of India's largest media companies. Latest...      True
#
#                      created  followersCount  friendsCount  statusesCount  \
# 4  2007-02-09 00:35:02+00:00        53851246          1101         340498
# 5  2008-02-23 03:12:49+00:00         4136271           344         200996
# 8  2009-02-02 12:01:29+00:00          218041           598         398735
# 18 2018-11-26 08:30:58+00:00           42987            12         339368
#
#     favouritesCount  listedCount  mediaCount          location  protected  \
# 4              1410       148471      170412                        False
# 5                 4        20943      152532    Washington, DC      False
# 8               587         1678      242594           Ireland      False
# 18                9          220         228  New Delhi, India      False
#
#                             linkUrl               linkTcourl  \
# 4                http://www.cnn.com   http://t.co/IaghNW8Xm2
# 5           http://cnn.com/politics  https://t.co/KWFMkrEjdY
# 8      http://www.irishexaminer.com  https://t.co/i7c8FvXflv
# 18  https://www.hindustantimes.com/  https://t.co/WtJj2BvIpU
#
#                                       profileImageUrl  \
# 4   https://pbs.twimg.com/profile_images/127825916...
# 5   https://pbs.twimg.com/profile_images/918899077...
# 8   https://pbs.twimg.com/profile_images/127760298...
# 18  https://pbs.twimg.com/profile_images/130014548...
#
#                                      profileBannerUrl     media_outlet  \
# 4   https://pbs.twimg.com/profile_banners/759251/1...              CNN
# 5   https://pbs.twimg.com/profile_banners/13850422...              CNN
# 8   https://pbs.twimg.com/profile_banners/19903360...   Irish Examiner
# 18                                               None  Hindustan Times
#
#    media_category
# 4      Television
# 5      Television
# 8       Newspaper
# 18      Newspaper

# %%
n = news_tweets.sample(25, random_state=99).merge(news_accounts, on=('userId','country'))
n['engagement'] = n[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].sum(axis=1)
n.iloc[[4,5,8,18]][['content', 'theme', 'subtheme', 'country']]
# Out:
#                                               content  theme  subtheme country
# 4   Apple has warned investors that the ongoing co...      2        22      US
# 5   Dr. Anthony Fauci said he is "absolutely not" ...      5        51      US
# 8   Data collection in new Covid-19 app ‘troubling...      2        20      IE
# 18  No refund on lockdown flights originating outs...      6        61      IN

# %%
list(news_tweets.sample(25, random_state=99).merge(news_accounts, on='userId').content)
# Out:
# ['#Coronavirus #CoronaCrisis |  State-wise breakup of Covid-19 cases in India, total climbs to 258\n\nhttps://t.co/VU03kvmnAt https://t.co/GNP1eXQrIt',
#  'Philippine President Rodrigo Duterte widens a lockdown to the entire Luzon island to contain an outbreak of the novel coronavirus https://t.co/SDyko6Lr0M',
#  'Doctors &amp; researchers around the world are trying to study the dangerous link between diabetes &amp; COVID-19. Many experts believe that COVID-19 can trigger the onset of diabetes even in some adults &amp; children who do not have traditional risk factors. @Shobhit10Mittal tells you more https://t.co/TXi9BW27rF',
#  'This is the first time that the country has acknowledged that the virus may have crossed into the country\n\n#NorthKorea #Coronavirus\n\nhttps://t.co/GaBtrm1jmZ',
#  'Hope amid coronavirus outbreak: Tagle appeals for prayers, fasting https://t.co/RTSpAVMwcJ #coronavirus #COVID19']

# %%
theme_desc
# Out:
#    theme                theme_desc
# 0      1          Cases and deaths
# 1      2           Economic impact
# 2      3        Educational impact
# 3      4            People stories
# 4      5    Authorities & Politics
# 5      6       Preventive measures
# 6      7           Virus spreading
# 7      8  Vaccines and vaccination

# %%
list(news_tweets.sample(25, random_state=73).merge(news_accounts, on='userId').content)
# Out:
# ['https://t.co/By0KBr5HQV | Hairdressers lose court bid to return to work during lockdown https://t.co/Hq5A45ndaD https://t.co/AZoPZrN9Dj',
#  'Just weeks after becoming the first man to walk on the moon, NASA astronaut Neil Armstrong celebrated his 39th birthday in quarantine https://t.co/5RsBHGXczl',
#  'HAPPENING NOW: The WHO gives a media briefing on the COVID-19 pandemic. https://t.co/Pyl256QAJy',
#  'In their line of work, they might be the last pockets of people that are still unaware of coronavirus. https://t.co/pSErtUkaxo',
#  'Ontario long-term care home identifies teen staff member who died of COVID-19 https://t.co/KeB0ZLhEKL https://t.co/Awwg2SURJO',
#  "EU agency insists it has the 'most appropriate' vaccine regulation process after UK approves Pfizer jab https://t.co/fttXsv6ptZ",
#  'PRC expects approval this week of saliva-based testing for COVID-19\nhttps://t.co/xy7tU2r1jN',
#  "Coronavirus restrictions need to be lifted 'sooner rather than later' - senior FF TD https://t.co/IB8DknLTRw https://t.co/fV4YexTsik",
#  'Officials step out to enforce lockdown in erstwhile Medak district https://t.co/CR9yQBjSOF',
#  'Catholic school board and Calgary charity help families facing food insecurity during the pandemic #yyc \nhttps://t.co/9VfsehzKQv',
#  'Streaming service provider DAZN Group will reportedly not pay rights fees for games suspended or cancelled by COVID-19. According to Reuters, DAZN will also not pay for future seasons until a clear timeline on when they will resume is given, as it is focused on reducing costs. https://t.co/sfL9oK4eE6',
#  'Hundreds of thousands of seasonal workers are unable to help with fruit and vegetable harvests in Germany due to travel restrictions stemming from the #coronavirus pandemic. https://t.co/Xid6ROqy3T',
#  'Joe Biden has made a stunning comment about Covid-19, with many saying the admission stands in stark contrast to his pre-election pledge. https://t.co/LOW4IuT8W7 https://t.co/bWqPHxHkuf',
#  'The health system in Papua New Guinea is on the brink of collapse due to the COVID-19 surge, leaving patients dying in car parks.\nhttps://t.co/w52q0eKZVC',
#  'Assam | As a part of this, health workers will visit homes to identify flu-like cases/respiratory symptoms.\n#Coronavirus\n\nhttps://t.co/0CVyh73J77',
#  'More than 6,600 cases of UK Covid variant in Ireland - HPSC https://t.co/bKJYXCrYqp',
#  'One of India’s foremost virologists Shahid Jameel, says if the ICMR serological survey results, made public on June 11, are correct, then it follows that India has 140-150 million coronavirus infected people today. | Interview with Karan Thapar. \n\nhttps://t.co/eCZXWkXFeP',
#  '#Covid2019 | China offers to share COVID-19 information with the world, calls for cooperation with the US. Watch the video for more details. https://t.co/fUj8MsbhRj',
#  'Posthaste: Coronavirus pandemic is pushing world growth towards zero, warns S&amp;P Global Ratings https://t.co/DiUiAu0iRq',
#  '#ALERT: Health Minister Greg Hunt gives an update on the coronavirus situation. #9News  https://t.co/IVu8YCVT6F',
#  'Sixteen teenagers harmed themselves and were admitted to one hospital’s intensive care unit in just three months during Melbourne’s coronavirus lockdown.\nhttps://t.co/jPjfDcIGJP',
#  'Saskatchewan COVID-19 cases linked to Alberta travel: authorities: https://t.co/qSOAL4nCZr',
#  '#BreakingNews | British Prime Minister Boris Johnson tests positive for #coronavirus. \n\n #CoronavirusOutbreak #CoronavirusPandemic',
#  'Nearly 100,000 children tested positive for COVID-19 in last 2 weeks of July, a 40 percent increase https://t.co/fmYbOehVct https://t.co/sT9zmsL4m5',
#  'Courts now turn to technology to combat the spread of coronavirus https://t.co/iwirM7t50j https://t.co/34kiWTux1z']

# %%
list(news_tweets.sample(25, random_state=13).merge(news_accounts, on='userId').iloc[[3,9,16,21]].content)
# Out:
# ['LOOK: Coronavirus-wary animal owners in the Philippines had their pets blessed via a drive-through ceremony on Sunday to mark World Animal Day and the feast of Saint Francis of Assisi, the patron saint of animals. 📷 Reuters\n\nFULL STORY: https://t.co/Cfnljiseh1 https://t.co/w1KTf2YVlg',
#  'Join @riatrillo for an in-depth conversation with Cabinet Secretary Karlo Nograles | Watch #TheSource here https://t.co/CaczwF9CtH\n\n• Readiness of PH in case of a coronavirus outbreak\n• Fate of the ABS-CBN franchise\n• Impact of the Visiting Forces Agreement with US https://t.co/XVGc7lsL0G',
#  'Govt took unprecedented measure for labour welfare &amp; employment generation during Covid-19 pandemic: Labour and Employment Minister\n\nhttps://t.co/xGIVXMez6Y',
#  '#Breaking | SENSATIONAL incident caught in camera in Kolkata.\n\nA COVID-19 suspect tried to escape from a hospital. \n\nDetails by Tamal Saha. https://t.co/ZLQkSgE7Uk']

# %%
comments['clen'] = comments.content.apply(lambda x: len(x))

# %%
c = pd.concat([
    comments[(comments.prevalent_emotion=='anger') & (comments.clen>100)].sample(5, random_state=13),
    comments[(comments.prevalent_emotion=='sadness') & (comments.clen>100)].sample(5, random_state=13),
    comments[(comments.prevalent_emotion=='optimism') & (comments.clen>100)].sample(5, random_state=13),
    comments[(comments.prevalent_emotion=='joy') & (comments.clen>100)].sample(5, random_state=13),
])
c
# Out:
#                tweetId  conversationId        userId  \
# 9032671   1.275978e+18    1.275967e+18  1.097999e+18
# 4635318   1.243226e+18    1.243187e+18  3.162447e+08
# 3725824   1.328131e+18    1.328123e+18  3.885075e+08
# 12829163  1.256143e+18    1.256112e+18  3.074651e+07
# 3392306   1.334096e+18    1.334043e+18  9.547578e+07
# 12229280  1.317240e+18    1.317163e+18  1.204838e+18
# 5601275   1.387506e+18    1.387497e+18  1.068931e+18
# 3207715   1.238393e+18    1.238391e+18  2.274331e+08
# 3077806   1.359245e+18    1.359116e+18  2.984031e+09
# 3974950   1.297649e+18    1.297588e+18  2.931261e+08
# 16844199  1.321995e+18    1.321981e+18  4.472898e+07
# 5601275            sadness   America  2021-04-28  2021-05-02 2021-04-01   284
# 3207715            sadness    Europe  2020-03-13  2020-03-15 2020-03-01   138
# 3077806            sadness    Europe  2021-02-09  2021-02-14 2021-02-01   145
# 3974950            sadness   America  2020-08-23  2020-08-30 2020-08-01   165
# 16844199          optimism      Asia  2020-10-30  2020-11-01 2020-10-01   255
# 4384661           optimism   America  2020-10-31  2020-11-01 2020-10-01   130
# 12138138          optimism   America  2020-04-20  2020-04-26 2020-04-01   101
# 13827817          optimism   America  2020-07-24  2020-07-26 2020-07-01   254
# 7313336           optimism   America  2021-03-17  2021-03-21 2021-03-01   124
# 7637082                joy   America  2020-05-15  2020-05-17 2020-05-01   101
# 9530496                joy   America  2020-03-18  2020-03-22 2020-03-01   180
# 734232                 joy   Oceania  2020-08-18  2020-08-23 2020-08-01   102
# 1963750                joy    Europe  2021-02-16  2021-02-21 2021-02-01   118
# 14427444               joy    Africa  2021-01-22  2021-01-24 2021-01-01   118

# %%
[str(cnt) + ' | ' + text for cnt, text in enumerate(c.content)]
# Out:
# ['0 | @ABC Because his racism, pathological lying, sexual assault and the fact he does nothing but Rage Tweet all day isn’t bad enough, +120 THOUSAND are dead, millions are unemployed, so he once again thinks if he denies something, we won’t movie the people literally dying around us 🙄',
#  '1 | @nuttysaham @CNNPolitics Left has nothing to do with dividing the country by holding up the bill to put bullshit it that has nothing to do with the crisis. Why don’t you read the two bills.',
#  '2 | @DocWadeson @BreitbartNews Yup nothing else, masks haven’t stopped COVID , the flue, heart attacks, strokes , come on people wake da fuhg up',
#  '3 | @nzherald First Amendment to the US constitution says *nothing* about “freedom of worship.” \n\nShame she didn’t read that like she didn’t read anything about epidemiology.',
#  '4 | @hannah62687 @guinness162 @BBCBreakfast End of the day like I say no vaccine has 100 percent uptake u don’t even need it to be 100 percent to get wiped out so I suggest u stop panicking so much enough people will take vaccine for it to die off unless the government have other agendas',
#  '5 | @Smurph512 @camelhumps @CNN yep, no one said just stay home and it will go away,,,\nhttps://t.co/kfPyQBgtLg',
#  '6 | @nytimes And more shocking is the fact that we are yet to reach the said "peak" in COVID cases. I dare not think about that. It\'s collapsing everywhere and nothing\'s in your hands, HELPLESS would be the word. From pleas for supplies, beds to agony of family members, reality hit hard.',
#  '7 | @BBCr4today We need to slow the virus down so people can be treated.\n\nwe now have thousands carrying the virus - the plan failed \n\n#corona',
#  '8 | @liam54344527 @jonnymain2011 @MillieWiller @BBCScotlandNews @NicolaSturgeon This point being a catastrophic number of deaths, one year on, yeah ?',
#  '9 | @t2hearn @TRUMP2TERM1 @Tuulmaker @business "Brilliance" doesn\'t give me the magic ability to, for example, know what "immune disease" is, since it\'s not a real term.',
#  '10 | @michelle_d_ong #MarketEdge Reyes: We partnered with private companies to provide each student with 10GB mobile data every month. Partnerships with lending companies/cellphone companies to  help us achieve 1:1 student to device ratio | via @michelle_d_ong',
#  '11 | @CNN Nobody should be in fear of anything but God. Forget politics and fear God!\n\nhttps://t.co/Ja6cfzWaHE\n\nhttps://t.co/sp9tm04eHa',
#  '12 | @HGiamarco @KlongName @washingtonpost There are no miracles! It’s called life! Live it ! Stop crying!',
#  '13 | @CTVNews .@CanadaPMP @HealthCareGov - Listening to the experts. Don’t be cocky; give priority to our internal developers and scientists.\n\nChina is always in the picture.\nWe must do what is the best for us 😷🤓😎 Listen.\nWe have already lost too many lives 😟',
#  '14 | @CNN No doubt, Marjorie Taylor Greene, Lauren Boebert and all those QAnon activists will be staunch supporters of this bill!',
#  "15 | @Ford_Dude6 @NBCNews @CNBC I'm old enough to remember when seniors had proms and graduated in arenas.",
#  '16 | @meganedurham @BryceT_22 @CJEradiCater @LPConstance @CBSNews So as a doctor you end up writing so much that you learn to write just barely legible but super efficient. Dope thanks😎',
#  '17 | @dailytelegraph Good on them! Wish we had a similar watermark concert here.....after the covid 19..🤣😅😂',
#  "18 | @bbc5live @StephenNolan Arise Sir Lou! He's doing an absolutely incredible job-a really inspiring, thoughtful person 👏",
#  '19 | @MinenhleSosha @JohanPi86341896 @News24 @Lwandi_N Dude thinks he’s gonna get 10K followers and suddenly be important 🤣']

# %% [markdown]
# 3 "(...) He doesn’t respect the reporters neither the people that are at the frontline fighting for this virus (...)"
# 7 "(...) so many doctors in Europe who have to decide who gets a respirator and who has to die (...)"
# 12 "(...) I do hope you and the rest of the 1743 family are well (...)"
# 17 "(...) I heard this as well via a reputable news source. You're not imagining it. :) (...)"

# %%
c['engagement'] = c[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].sum(axis=1)
c.iloc[[3,7,12,17]][['content', 'prevalent_emotion', 'emotion_score', 'country']]
# Out:
#                                                     content prevalent_emotion  \
# 12829163  @nzherald First Amendment to the US constituti...             anger
# 3207715   @BBCr4today We need to slow the virus down so ...           sadness
# 12138138  @HGiamarco @KlongName @washingtonpost There ar...          optimism
# 734232    @dailytelegraph Good on them! Wish we had a si...               joy
#
#           emotion_score country
# 12829163          0.788      NZ
# 3207715           0.818      UK
# 12138138          0.881      US
# 734232            0.963      AU

# %% [markdown]
# N/C | Content | Prevalent Emotion | Score | Theme | Subtheme | Engagement

# %% [markdown]
# # Analysis

# %%
g = comments[emotions].mean()
g
# Out:
# anger       0.538530
# sadness     0.194305
# optimism    0.143847
# joy         0.123318
# dtype: float64

# %%
c0 = comments.groupby(['country', 'theme', 'subtheme', 'news_prevalent_emotion']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c0['lift_' + col] = c0[col] / g[col]

c0[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.786345
# lift_sadness     4.760552
# lift_optimism    5.109592
# lift_joy         7.760428
# dtype: float64

# %%
c1 = comments.groupby(['country', 'theme', 'subtheme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c1['lift_' + col] = c1[col] / g[col]

c1[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.491097
# lift_sadness     3.427597
# lift_optimism    4.317084
# lift_joy         1.853006
# dtype: float64

# %%
c2 = comments.groupby(['country', 'theme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c2['lift_' + col] = c2[col] / g[col]

c2[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.119947
# lift_sadness     1.521808
# lift_optimism    1.860433
# lift_joy         1.400155
# dtype: float64

# %%
c3 = comments.groupby(['country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c3['lift_' + col] = c3[col] / g[col]

c3[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.043756
# lift_sadness     1.198348
# lift_optimism    1.596903
# lift_joy         1.185103
# dtype: float64

# %%
c31 = comments.groupby(['continent', 'country', 'dsm']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c31['lift_' + col] = c31[col] / g[col]

c31[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.185067
# lift_sadness     1.505042
# lift_optimism    2.055944
# lift_joy         1.462452
# dtype: float64

# %%
c4 = comments.groupby(['theme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c4['lift_' + col] = c4[col] / g[col]

c4[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.066736
# lift_sadness     1.199857
# lift_optimism    1.209570
# lift_joy         1.085468
# dtype: float64

# %%
c41 = comments.groupby(['theme', 'country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c41['lift_' + col] = c41[col] / g[col]

c41[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.119947
# lift_sadness     1.521808
# lift_optimism    1.860433
# lift_joy         1.400155
# dtype: float64

# %%
c42 = comments.groupby(['theme', 'dsw']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c42['lift_' + col] = c42[col] / g[col]

c42[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.203078
# lift_sadness     3.329813
# lift_optimism    2.581840
# lift_joy         2.389487
# dtype: float64

# %%
c5 = comments.groupby(['subtheme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c5['lift_' + col] = c5[col] / g[col]

c5[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.132297
# lift_sadness     1.686525
# lift_optimism    1.209570
# lift_joy         1.156571
# dtype: float64

# %%
c51 = comments.groupby(['subtheme', 'country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c51['lift_' + col] = c51[col] / g[col]

c51[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.491097
# lift_sadness     3.427597
# lift_optimism    4.317084
# lift_joy         1.853006
# dtype: float64

# %%
c52 = comments.groupby(['subtheme', 'news_prevalent_emotion']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c52['lift_' + col] = c52[col] / g[col]

c52[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.340687
# lift_sadness     1.708586
# lift_optimism    1.679799
# lift_joy         2.612611
# dtype: float64

# %%
c6 = comments.groupby(['news_prevalent_emotion']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c6['lift_' + col] = c6[col] / g[col]

c6[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.156111
# lift_sadness     1.162797
# lift_optimism    1.174983
# lift_joy         1.617622
# dtype: float64

# %%
c61 = comments.groupby(['news_prevalent_emotion', 'country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c61['lift_' + col] = c61[col] / g[col]

c61[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.188647
# lift_sadness     1.410172
# lift_optimism    1.948979
# lift_joy         2.032794
# dtype: float64

# %%
c7 = comments.groupby(['dsw']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c7['lift_' + col] = c7[col] / g[col]

c7[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.104865
# lift_sadness     1.342397
# lift_optimism    1.230990
# lift_joy         1.108797
# dtype: float64

# %%
c8 = comments.groupby(['continent']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c8['lift_' + col] = c8[col] / g[col]

c8[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.037932
# lift_sadness     1.106693
# lift_optimism    1.273738
# lift_joy         1.173479
# dtype: float64

# %%
c81 = comments.groupby(['continent', 'dsm']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c81['lift_' + col] = c81[col] / g[col]

c81[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.112780
# lift_sadness     1.418362
# lift_optimism    1.540471
# lift_joy         1.364792
# dtype: float64

# %%
c9 = comments.groupby(['continent', 'country', 'news_id']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c9['lift_' + col] = c9[col] / g[col]

c9[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.148386
# lift_sadness     2.312084
# lift_optimism    5.575365
# lift_joy         5.817188
# dtype: float64

# %%
engaged_news = news_tweets.groupby('userId').tweetId.count()
engaged_news = list(engaged_news[engaged_news > 484].index)

# %%
c91 = c9[c9.news_id.isin(engaged_news)].merge(news_accounts.drop('country',axis=1), left_on='news_id', right_on='userId', how='left')

# %%
c9 = comments.groupby(['continent', 'country', 'news_id']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c9['lift_' + col] = c9[col] / g[col]

c9[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()

engaged_news = news_tweets.groupby('userId').tweetId.count()
engaged_news = list(engaged_news[engaged_news > 484].index)

c91 = c9[c9.news_id.isin(engaged_news)].merge(news_accounts.drop('country',axis=1), left_on='news_id', right_on='userId', how='left')

# %% [markdown]
# # Conclusions

# %% [markdown]
# #### T1: joyful news reflect in more joyful comments, mainly in IE, IN and PH

# %%
c6
# Out:
#   news_prevalent_emotion     anger   sadness  optimism       joy  tweetId  \
# 0                  anger  0.622600  0.149087  0.122178  0.106134  3114617
# 1                    joy  0.470751  0.186017  0.143750  0.199482   739089
# 2               optimism  0.518070  0.182010  0.169018  0.130902  2679863
# 3                sadness  0.514258  0.225938  0.141646  0.118159  6931133
# 4              undefined  0.541251  0.184841  0.147544  0.126365  4156202
#
#    lift_anger  lift_sadness  lift_optimism  lift_joy
# 0    1.156111      0.767283       0.849361  0.860654
# 1    0.874140      0.957346       0.999328  1.617622
# 2    0.962008      0.936722       1.174983  1.061499
# 3    0.954929      1.162797       0.984699  0.958166
# 4    1.005052      0.951292       1.025698  1.024706

# %%
c6[c6.lift_joy>1.5]
# Out:
#   news_prevalent_emotion     anger   sadness  optimism       joy  tweetId  \
# 1                    joy  0.470751  0.186017   0.14375  0.199482   739089
#
#    lift_anger  lift_sadness  lift_optimism  lift_joy
# 1     0.87414      0.957346       0.999328  1.617622

# %%
c61[c61.news_prevalent_emotion=='joy'].sort_values('lift_joy')
# Out:
#    news_prevalent_emotion country     anger   sadness  optimism       joy  \
# 13                    joy      CA  0.492252  0.198934  0.146259  0.162554
# 12                    joy      AU  0.509158  0.184852  0.137281  0.168700
# 23                    joy      ZA  0.451983  0.218784  0.146514  0.182723
# 16                    joy      KE  0.423523  0.214678  0.172986  0.188811
# 22                    joy      US  0.492600  0.178055  0.135752  0.193592
# 17                    joy      MY  0.425265  0.216059  0.163382  0.195305
# 18                    joy      NG  0.431903  0.192928  0.162623  0.212556
# 19                    joy      NZ  0.441967  0.196915  0.146838  0.214294
# 21                    joy      UK  0.448647  0.194351  0.139845  0.217158
# 15                    joy      IN  0.397255  0.191865  0.174086  0.236793
# 14                    joy      IE  0.424712  0.191872  0.141574  0.241833
# 20                    joy      PH  0.312943  0.206022  0.230357  0.250680
#
#     tweetId  lift_anger  lift_sadness  lift_optimism  lift_joy
# 13    56064    0.914067      1.023821       1.016770  1.318169
# 12    22123    0.945460      0.951349       0.954353  1.368008
# 23    13690    0.839290      1.125979       1.018538  1.481721
# 16     6342    0.786443      1.104848       1.202569  1.531088
# 22   415149    0.914713      0.916367       0.943726  1.569865
# 17     2614    0.789677      1.111956       1.135802  1.583751
# 18    32514    0.802004      0.992911       1.130527  1.723644
# 19     3819    0.820691      1.013434       1.020790  1.737738
# 21   114511    0.833097      1.000236       0.972177  1.760958
# 15    43915    0.737665      0.987442       1.210215  1.920181
# 14    10330    0.788650      0.987478       0.984197  1.961049
# 20    18018    0.581105      1.060301       1.601401  2.032794

# %% [markdown]
# #### News about vaccines generate more positive feelings (optmism and joy), mainly in PH, In and NZ

# %%
c4
# Out:
#    theme     anger   sadness  optimism       joy  tweetId  lift_anger  \
#
# 28    30198    0.972922      1.013262       1.020141  1.073859
# 29     8174    0.906480      0.946312       1.148632  1.319576
# 30    13066    0.917981      1.013085       1.102862  1.217604
# 31     3160    0.914439      1.084010       1.152672  1.063247
# 32     1536    0.949890      1.168744       0.954690  1.006075
# 33     3801    0.835416      1.219098       1.033856  1.334073
# 34    68523    0.870627      1.230707       0.994179  1.208245
# 35   102086    0.965142      1.087363       0.955026  1.067041
# 36    86479    0.977553      1.077155       0.970845  1.010477
# 37    35911    1.009584      1.067143       0.869807  1.004217
# 38    43457    0.952638      1.177173       0.923574  1.016834
# 39    21588    1.046024      0.972991       0.876998  0.985041
# 40     9145    1.023514      1.038302       0.895356  0.958995
# 41     9735    1.002399      1.053570       0.927424  0.989842
# 42     6184    0.993648      1.116311       0.897905  0.963584
# 43    27781    1.001082      1.025782       0.984905  0.972262
# 44    42812    0.984665      1.073145       0.975256  0.980604
# 45    17922    0.965189      1.003272       0.989989  1.158533
# 46    13392    0.974248      1.127536       0.870936  1.061973
# 47     6039    0.946865      1.181388       0.938450  1.018093

# %% [markdown]
# Filtering the 25 Nigerian news tweets in Oct 2020 that have more prevalent anger comments (they represent 60% of anger comments)

# %%
news_tweets[news_tweets.tweetId.isin(comments[(comments.country=='NG') & (comments.dsm=='2020-10-01') & (comments.prevalent_emotion=='anger')].conversationId.value_counts(normalize=True).cumsum().head(25).index)].content.values
# Out:
# array(['The FCT Security Committee has just announced a ban on all #EndSARS street demonstrations, protests, and processions anywhere in Abuja.\n\nThe Committee accused protesters of violating COVID-19 guidelines regulating public gatherings, as well as endangering their own lives. https://t.co/rhgvTEFpPq',
#        '[BREAKING] Resumption: 181 students, staff contract COVID-19 in Lagos private school https://t.co/AxssGKbjwE',
#        '181 Students Test Positive For COVID-19 In Lekki, Lagos\nhttps://t.co/2GX2XGWAWQ https://t.co/TT2YYdltbh',
#        '#EndSARS protest: Nigeria should prepare for increase in COVID-19 cases ― FG warns https://t.co/gv0zy6sAqT',
#        '#ENDSARS protest: Nigeria should prepare for increase in COVID-19 cases — FG https://t.co/4JVbQJI7Nh',
#        'Protesters should kindly vacate the roads and allow supplies, especially food, to get to the people. The economy should not be asphyxiated, otherwise the combined effects of the protests and COVID-19 pandemic could collapse our already debilitated economy. https://t.co/Ia4zPMYFjD',
#        'Hoodlums attack warehouse, loot COVID-19 palliatives in Lagos https://t.co/zNTnj7irQa',
#        'Scores Break Into Warehouse In Lagos, Loot COVID-19 Palliatives\nhttps://t.co/CtRiUFVdC8 https://t.co/Raxw2elBka',
#        "COVID-19: FG disclaims discovered palliatives in Lagos' warehouse https://t.co/6VqwB9RDxq",
#        'Protesters burgle COVID-19 palliatives warehouse in Osun, cart away\xa0items https://t.co/mfiXCxDky4',
#        'Hoodlums loot COVID-19 palliatives warehouse in Cross River https://t.co/k2TyHu13HB https://t.co/P5bUp1sNqn',
#        'Looting: Why Osun was yet to distribute COVID-19 palliatives —Official https://t.co/9HDXMi5Coq https://t.co/q2IytwP1Nt',
weetId  lift_anger  lift_sadness  lift_optimism  lift_joy
# 7        392    0.607422      1.031750       1.358816  2.245688
# 11      1451    0.638093      1.043276       1.271331  2.195766
# 30         5    0.495794      0.343789       2.380305  2.622489
# 95        19    0.814107      1.017661       0.499434  2.370424
# 125     1379    0.604175      0.911057       1.117898  2.731156
# 133       65    0.311903      0.988770       0.867053  4.177320
# 134       35    0.594104      1.180764       0.955578  2.540935
# 156      470    0.497829      1.392359       1.460268  2.037391
# 162       55    0.747051      0.996277       0.845848  2.290753
# 174        4    0.389022      0.590566       1.883945  3.280139
# 189        4    0.049208      1.304648       0.773391  4.938454
# 193        4    0.234899      2.312084       0.543980  2.807783
# 205       87    0.632416      1.233750       1.024236  2.208197
# 206       11    0.214895      0.596063       0.355807  5.817188
# 211        9    0.466496      0.373410       1.644493  3.566211
# 214       59    0.568151      0.956646       0.593380  3.428096
# 232    14536    0.543972      1.056593       0.833412  3.096689
# 262       27    0.483209      1.336385       1.510864  2.131197
# 268        7    0.686260      0.670521       0.697169  3.242490

# %%
c9[c9.lift_optimism>2]
# Out:
#     continent country       news_id     anger   sadness  optimism       joy  \
# 30     Africa      NG  1.698798e+09  0.267000  0.066800  0.342400  0.323400
# 116      Asia      IN  9.294762e+06  0.251140  0.199962  0.307665  0.241182
# 141      Asia      IN  2.611139e+08  0.136000  0.031000  0.802000  0.031000
# 180      Asia      PH  1.764483e+07  0.264892  0.220842  0.395969  0.118279
# 188      Asia      PH  6.341162e+07  0.296483  0.187066  0.344509  0.171927
# 197      Asia      PH  8.233496e+17  0.287289  0.217422  0.329457  0.165859
#
#      tweetId  lift_anger  lift_sadness  lift_optimism  lift_joy
# 30         5    0.495794      0.343789       2.380305  2.622489
# 116      650    0.466344      1.029110       2.138831  1.955770
# 141        1    0.252539      0.159543       5.575365  0.251383
# 180     2300    0.491879      1.136574       2.752709  0.959140
# 188     1420    0.550542      0.962744       2.394968  1.394175
# 197     1782    0.533469      1.118971       2.290330  1.344967

# %%
nt = news_tweets.merge(theme_desc).merge(subtheme_desc)

# %%
nt.groupby('country').theme_desc.value_counts(normalize=True)
# Out:
# country  theme_desc
# AU       Authorities & Politics      0.353421
#          Economic impact             0.190050
#          Preventive measures         0.167764
#          Virus spreading             0.085002
#          Cases and deaths            0.079383
#                                        ...
# ZA       Cases and deaths            0.110621
#          Virus spreading             0.080259
#          People stories              0.075673
#          Vaccines and vaccination    0.050205
#          Educational impact          0.031455
# Name: theme_desc, Length: 96, dtype: float64

# %%
nt.groupby('country').subtheme_desc.value_counts(normalize=True).rename('aaa').reset_index().pivot('subtheme_desc', 'country', 'aaa')
# Out:
# country                                                   AU        CA  \
# subtheme_desc
# Authorities & Politics (default)                    0.292282  0.110746
# Cases and deaths (default)                          0.048614  0.086105
# Cases and deaths decreasing                         0.004930  0.006775
# Cases and deaths increasing                         0.025840  0.036072
# Easing restrictions                                 0.001026  0.000896
# Economic impact (default)                           0.100018  0.149587
# Economic impact over national economies and big...  0.041969  0.046806
# Economic plans to support jobs and food programs    0.048063  0.045863
# Educational impact (default)                        0.030157  0.050245
# Elections                                           0.001915  0.002119
# Family stories                                      0.002615  0.003083
# Festivities and holidays                            0.001727  0.001333
# Health authorities                                  0.012338  0.017202
# Heatlh workers                                      0.000738  0.000957
# Jail system and cops                                0.000863  0.001641
# Mental health impact                                0.000013  0.000062
# Mobility restrictions                               0.078532  0.041836
# New waves and variants                              0.004730  0.008122
# Non-pharmacological measures                        0.001977  0.001709
# Nursing homes and elderly victims                   0.001351  0.001784
# Outbreak and pandemic origins                       0.026540  0.028558
# People against restrictions or breaking rules       0.003028  0.002967
# People stories (default)                            0.048951  0.060213
# Political authorities                               0.046887  0.023861
# Preventive measures (default)                       0.071863  0.137082
# Research and treatment                              0.010624  0.014474
# Travelling protocols                                0.009610  0.010201
# Vaccines and vaccination (default)                  0.040430  0.057096
# Virus spreading (default)                           0.042369  0.052604
#
# country                                                   IE        IN  \
# subtheme_desc
# Authorities & Politics (default)                    0.100837  0.159896
# Cases and deaths (default)                          0.090389  0.082861
# Cases and deaths decreasing                         0.006934  0.005239
# Cases and deaths increasing                         0.031631  0.049211
# Easing restrictions                                 0.001140  0.000573
# Economic impact (default)                           0.132279  0.115191
# Economic impact over national economies and big...  0.052407  0.036786
# Economic plans to support jobs and food programs    0.052244  0.051222
# Educational impact (default)                        0.037371  0.028370
# Elections                                           0.001167  0.002029
# Family stories                                      0.003352  0.003725
# Festivities and holidays                            0.002768  0.000405
# Health authorities                                  0.005021  0.007360
# Heatlh workers                                      0.000719  0.000375
# Jail system and cops                                0.001086  0.001622
# Mental health impact                                0.000081  0.000021
# Mobility restrictions                               0.095925  0.086878
# New waves and variants                              0.005876  0.004878
# Non-pharmacological measures                        0.002687  0.001682
# Nursing homes and elderly victims                   0.006608  0.000232
# Outbreak and pandemic origins                       0.017586  0.014302
# People against restrictions or breaking rules       0.003691  0.001597
# People stories (default)                            0.075896  0.081865
# Political authorities                               0.018509  0.055138
# Preventive measures (default)                       0.109970  0.085360
# Research and treatment                              0.012471  0.010798
# Travelling protocols                                0.010164  0.005421
# Vaccines and vaccination (default)                  0.061458  0.074122
# Virus spreading (default)                           0.059734  0.032840
#
# country                                                   KE        MY  \
# subtheme_desc
# Authorities & Politics (default)                    0.086220  0.079733
# Cases and deaths (default)                          0.113555  0.114836
# Cases and deaths decreasing                         0.003356  0.006983
# Cases and deaths increasing                         0.063772  0.041355
# Easing restrictions                                 0.000671  0.001543
# Economic impact (default)                           0.134660  0.181699
# Economic impact over national economies and big...  0.043553  0.041923
# Economic plans to support jobs and food programs    0.059368  0.062885
# Educational impact (default)                        0.043687  0.024967
# Elections                                           0.000886  0.001935
# Family stories                                      0.004055  0.002057
# Festivities and holidays                            0.000913  0.000825
# Health authorities                                  0.002041  0.002476
# Heatlh workers                                      0.000725  0.000433
# Jail system and cops                                0.001745  0.002341
# Mental health impact                                0.000027       NaN
# Mobility restrictions                               0.046587  0.051653
# New waves and variants                              0.003705  0.005345
# Non-pharmacological measures                        0.002175  0.001516
# Nursing homes and elderly victims                   0.000081  0.000217
# Outbreak and pandemic origins                       0.012540  0.027146
# People against restrictions or breaking rules       0.003840  0.002463
# People stories (default)                            0.134499  0.065226
# Political authorities                               0.026610  0.025617
# Preventive measures (default)                       0.103834  0.105146
# Research and treatment                              0.007169  0.009581
# Travelling protocols                                0.006632  0.006387
# Vaccines and vaccination (default)                  0.043311  0.064982
# Virus spreading (default)                           0.049783  0.068731
#
# country                                                   NG        NZ  \
# subtheme_desc
# Authorities & Politics (default)                    0.084995  0.177241
# Cases and deaths (default)                          0.093139  0.086349
# Cases and deaths decreasing                         0.002951  0.003381
# Cases and deaths increasing                         0.033603  0.020366
# Easing restrictions                                 0.000700  0.000423
# Economic impact (default)                           0.236712  0.133446
# Economic impact over national economies and big...  0.039296  0.042527
# Economic plans to support jobs and food programs    0.047983  0.049157
# Educational impact (default)                        0.024475  0.031011
# Elections                                           0.000809  0.002747
# Family stories                                      0.005493  0.002985
# Festivities and holidays                            0.000892  0.001638
# Health authorities                                  0.002376  0.008505
# Heatlh workers                                      0.000375  0.000502
# Jail system and cops                                0.001234  0.001109
# Mental health impact                                0.000008  0.000026
# Mobility restrictions                               0.063613  0.092160
# New waves and variants                              0.004201  0.004649
# Non-pharmacological measures                        0.001084  0.001083
# Nursing homes and elderly victims                   0.000075  0.000053
# Outbreak and pandemic origins                       0.010312  0.018807
# People against restrictions or breaking rules       0.002701  0.001268
# People stories (default)                            0.126242  0.064900
# Political authorities                               0.019206  0.037799
# Preventive measures (default)                       0.098750  0.106635
# Research and treatment                              0.006227  0.012415
# Travelling protocols                                0.004510  0.009219
# Vaccines and vaccination (default)                  0.038363  0.031803
# Virus spreading (default)                           0.049675  0.057795
#
# country                                                   PH        UK  \
# subtheme_desc
# Authorities & Politics (default)                    0.075295  0.123200
# Cases and deaths (default)                          0.079839  0.032346
# Cases and deaths decreasing                         0.003588  0.005129
# Cases and deaths increasing                         0.040103  0.035005
# Easing restrictions                                 0.001381  0.000474
# Economic impact (default)                           0.126310  0.144731
# Economic impact over national economies and big...  0.054727  0.040443
# Economic plans to support jobs and food programs    0.069423  0.035153
# Educational impact (default)                        0.033983  0.033916
# Elections                                           0.000649  0.001504
# Family stories                                      0.003199  0.007913
# Festivities and holidays                            0.001564  0.003506
# Health authorities                                  0.003281  0.003086
# Heatlh workers                                      0.000549  0.000652
# Jail system and cops                                0.001989  0.001416
# Mental health impact                                0.000047  0.000095
# Mobility restrictions                               0.087470  0.142871
# New waves and variants                              0.004155  0.008956
# Non-pharmacological measures                        0.001889  0.002488
# Nursing homes and elderly victims                   0.000183  0.001670
# Outbreak and pandemic origins                       0.015929  0.022425
# People against restrictions or breaking rules       0.002420  0.002606
# People stories (default)                            0.074481  0.087312
# Political authorities                               0.018567  0.031931
# Preventive measures (default)                       0.168862  0.104051
# Research and treatment                              0.010098  0.015921
# Travelling protocols                                0.009254  0.007410
# Vaccines and vaccination (default)                  0.071211  0.048084
# Virus spreading (default)                           0.039554  0.055707
#
# country                                                   US        ZA
# subtheme_desc
# Authorities & Politics (default)                    0.110545  0.143534
# Cases and deaths (default)                          0.044597  0.067094
# Cases and deaths decreasing                         0.004455  0.003263
# Cases and deaths increasing                         0.030064  0.040264
# Easing restrictions                                 0.000876  0.000864
# Economic impact (default)                           0.150363  0.140656
# Economic impact over national economies and big...  0.063620  0.048459
# Economic plans to support jobs and food programs    0.062157  0.063620
# Educational impact (default)                        0.055279  0.031455
# Elections                                           0.003499  0.001267
# Family stories                                      0.005566  0.003454
# Festivities and holidays                            0.001438  0.001190
# Health authorities                                  0.011340  0.004817
# Heatlh workers                                      0.001227  0.000614
# Jail system and cops                                0.002184  0.002341
# Mental health impact                                0.000049  0.000038
# Mobility restrictions                               0.034512  0.124247
# New waves and variants                              0.004972  0.007753
# Non-pharmacological measures                        0.003305  0.001228
# Nursing homes and elderly victims                   0.002215  0.000077
# Outbreak and pandemic origins                       0.023014  0.011995
# People against restrictions or breaking rules       0.002634  0.002073
# People stories (default)                            0.072875  0.069762
# Political authorities                               0.049453  0.021706
# Preventive measures (default)                       0.116835  0.091621
# Research and treatment                              0.016569  0.012417
# Travelling protocols                                0.009167  0.006506
# Vaccines and vaccination (default)                  0.062368  0.050205
# Virus spreading (default)                           0.054822  0.047480

# %%
nt.theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.241412
# Preventive measures         0.200064
# Authorities & Politics      0.174950
# Cases and deaths            0.115796
# People stories              0.086477
# Virus spreading             0.084560
# Vaccines and vaccination    0.060233
# Educational impact          0.036508
# Name: theme_desc, dtype: float64

# %%
nt.subtheme_desc.value_counts(normalize=True)
# Out:
# Economic impact (default)                                    0.141520
# Authorities & Politics (default)                             0.128091
# Preventive measures (default)                                0.108863
# People stories (default)                                     0.079276
# Mobility restrictions                                        0.076942
# Cases and deaths (default)                                   0.072385
# Vaccines and vaccination (default)                           0.060233
# Economic plans to support jobs and food programs             0.053525
# Virus spreading (default)                                    0.047078
# Economic impact over national economies and big companies    0.046366
# Cases and deaths increasing                                  0.038521
# Political authorities                                        0.037490
# Educational impact (default)                                 0.036508
# Outbreak and pandemic origins                                0.019001
# Research and treatment                                       0.012232
# Travelling protocols                                         0.007591
# Health authorities                                           0.007442
# New waves and variants                                       0.005581
# Cases and deaths decreasing                                  0.004890
# Family stories                                               0.004315
# People against restrictions or breaking rules                0.002411
# Non-pharmacological measures                                 0.002053
# Elections                                                    0.001926
# Jail system and cops                                         0.001693
# Festivities and holidays                                     0.001373
# Nursing homes and elderly victims                            0.001152
# Easing restrictions                                          0.000830
# Heatlh workers                                               0.000669
# Mental health impact                                         0.000041
# Name: subtheme_desc, dtype: float64

# %%
c9 = comments.groupby(['continent', 'country', 'news_id']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c9['lift_' + col] = c9[col] / g[col]

c9[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.148386
# lift_sadness     2.312084
# lift_optimism    5.575365
# lift_joy         5.817188
# dtype: float64

# %%
c91.sort_values('anger').tail(5)
# Out:
#     continent country      news_id     anger   sadness  optimism       joy  \
# 218   Oceania      AU   35466620.0  0.603498  0.167500  0.116814  0.112194
# 76    America      US    2836421.0  0.604880  0.165092  0.127563  0.102465
# 107   America      US  457984599.0  0.610819  0.155204  0.119550  0.114424
# 74    America      US    1367531.0  0.618269  0.148134  0.125591  0.108006
# 85    America      US   13850422.0  0.618440  0.152102  0.126491  0.102965
#
#      tweetId  lift_anger  lift_sadness  lift_optimism  lift_joy  \
# 218    50488    1.120640      0.862044       0.812068  0.909794
# 76    635159    1.123207      0.849654       0.886793  0.830900
# 107   182224    1.134234      0.798766       0.831094  0.927881
# 74    199893    1.148069      0.762379       0.873083  0.875836
# 85    437591    1.148386      0.782802       0.879346  0.834957
#
#           username     displayname       userId  \
# 218   theheraldsun      Herald Sun   35466620.0
# 76           MSNBC           MSNBC    2836421.0
# 107  BreitbartNews  Breitbart News  457984599.0
# 74         FoxNews        Fox News    1367531.0
# 85     CNNPolitics    CNN Politics   13850422.0
#
#                                            description  \
# 218  Join the conversation on all the news from Mel...
# 76   The place for in-depth analysis, political com...
# 107  News, commentary, and destruction of the polit...
# 74   Follow America's #1 cable news network, delive...
# 85   Political news, campaign stories and Washingto...
#
#                                         rawDescription  verified  \
# 218  Join the conversation on all the news from Mel...      True
# 76   The place for in-depth analysis, political com...      True
# 107  News, commentary, and destruction of the polit...      True
# 74   Follow America's #1 cable news network, delive...      True
# 85   Political news, campaign stories and Washingto...      True
#
#                       created  followersCount  friendsCount  statusesCount  \
# 218 2009-04-26 13:44:23+00:00          331964         32214         305722
# 76  2007-03-29 13:15:41+00:00         4219331           767         248262
# 107 2012-01-08 01:50:52+00:00         1471106           110         145954
# 74  2007-03-17 19:01:26+00:00        20185319           260         425666
# 85  2008-02-23 03:12:49+00:00         4136271           344         200996
#
#      favouritesCount  listedCount  mediaCount              location  \
# 218             1420         2381       41338  Melbourne, Australia
# 76               818        28389       61955
# 107              900         9202        3886
# 74                 2        68612      138108                U.S.A.
# 85                 4        20943      152532        Washington, DC
#
#      protected                      linkUrl               linkTcourl  \
# 218      False  http://www.heraldsun.com.au   http://t.co/LhVhBJqLWx
# 76       False        http://msnbc.com/live  https://t.co/YBwtJIhwY3
# 107      False         http://breitbart.com   http://t.co/2sVbt3n6lO
# 74       False       http://www.foxnews.com   http://t.co/ZYG58XZtAC
# 85       False      http://cnn.com/politics  https://t.co/KWFMkrEjdY
#
#                                        profileImageUrl  \
# 218  https://pbs.twimg.com/profile_images/118640924...
# 76   https://pbs.twimg.com/profile_images/132108981...
# 107  https://pbs.twimg.com/profile_images/949270171...
# 74   https://pbs.twimg.com/profile_images/918480715...
# 85   https://pbs.twimg.com/profile_images/918899077...
#
#                                       profileBannerUrl    media_outlet  \
# 218  https://pbs.twimg.com/profile_banners/35466620...  The Herald Sun
# 76   https://pbs.twimg.com/profile_banners/2836421/...           MSNBC
# 107  https://pbs.twimg.com/profile_banners/45798459...  Breitbart News
# 74   https://pbs.twimg.com/profile_banners/1367531/...             Fox
# 85   https://pbs.twimg.com/profile_banners/13850422...             CNN
#
#     media_category
# 218      Newspaper
# 76      Television
# 107        Website
# 74      Television
# 85      Television

# %%
c91.sort_values('anger').tail(5).country.value_counts()
# Out:
# US    4
# AU    1
# Name: country, dtype: int64

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('anger').tail(5).username.values)].userId.values)].theme_desc.value_counts(normalize=True)
# Out:
# Authorities & Politics      0.290414
# Economic impact             0.253717
# Preventive measures         0.138414
# Virus spreading             0.085355
# People stories              0.072796
# Cases and deaths            0.068310
# Vaccines and vaccination    0.049684
# Educational impact          0.041311
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('anger').tail(5).username.values)].userId.values)].subtheme_desc.value_counts(normalize=True)
# Out:
# Authorities & Politics (default)                             0.135424
# Political authorities                                        0.129058
# Economic impact (default)                                    0.128503
# Preventive measures (default)                                0.086423
# Economic impact over national economies and big companies    0.069036
# People stories (default)                                     0.065448
# Economic plans to support jobs and food programs             0.056177
# Virus spreading (default)                                    0.050538
# Vaccines and vaccination (default)                           0.049684
# Educational impact (default)                                 0.041311
# Cases and deaths (default)                                   0.038918
# Mobility restrictions                                        0.037466
# Cases and deaths increasing                                  0.024265
# Health authorities                                           0.021104
# Outbreak and pandemic origins                                0.020164
# Research and treatment                                       0.009997
# Travelling protocols                                         0.007647
# Cases and deaths decreasing                                  0.005126
# Elections                                                    0.004827
# New waves and variants                                       0.003888
# Family stories                                               0.003802
# People against restrictions or breaking rules                0.003161
# Nursing homes and elderly victims                            0.002435
# Non-pharmacological measures                                 0.002008
# Festivities and holidays                                     0.001153
# Jail system and cops                                         0.001025
# Heatlh workers                                               0.000769
# Easing restrictions                                          0.000555
# Mental health impact                                         0.000085
# Name: subtheme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='InsidersABC'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\FC766~1.BRA\AppData\Local\Temp/ipykernel_24676/245472361.py in <module>
# ----> 1 nt[nt.userId==c91[c91.username=='InsidersABC'].userId.values[0]].theme_desc.value_counts(normalize=True)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
nt[nt.userId==c91[c91.username=='BreitbartNews'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='PnPCBC'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='FoxNews'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='CNNPolitics'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
c91.sort_values('sadness').tail(5).username

# %%
c91.sort_values('sadness').tail(5).country.value_counts()

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('sadness').tail(5).username.values)].userId.values)].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('sadness').tail(5).username.values)].userId.values)].subtheme_desc.value_counts(normalize=True)

# %%
c91.sort_values('sadness').tail(5)

# %%
c91.sort_values('sadness').tail(5).description.values

# %%
nt[nt.userId==c91[c91.username=='Oneindia'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='sunrisedailynow'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='fpjindia'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='NewIndianXpress'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='firstpost'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
c91.sort_values('optimism').tail(5).country.value_counts()

# %%
c91.sort_values('optimism').tail(5).username

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('optimism').tail(5).username.values)].userId.values)].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('optimism').tail(5).username.values)].userId.values)].subtheme_desc.value_counts(normalize=True)

# %%
c91.sort_values('optimism').tail(5).description.values

# %%
nt[nt.userId==c91[c91.username=='ANCALERTS'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='manilabulletin'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='pnagovph'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='TheManilaTimes'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='BusinessMirror'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
c91.sort_values('joy').tail(5).country.value_counts()

# %%
c91.sort_values('joy').tail(5).username

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('joy').tail(5).username.values)].userId.values)].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId.isin(c91[c91.username.isin(c91.sort_values('joy').tail(5).username.values)].userId.values)].subtheme_desc.value_counts(normalize=True)

# %%
c91.sort_values('joy').tail(5).description.values

# %%
nt[nt.userId==c91[c91.username=='DDNewslive'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='bellanaija'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='mid_day'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
nt[nt.userId==c91[c91.username=='BBCRadio4'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %% [markdown]
# # Trunk0

# %%
nt[nt.userId==c91[c91.username=='RadioCitizenFM'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\FC766~1.BRA\AppData\Local\Temp/ipykernel_22524/1201450592.py in <module>
# ----> 1 nt[nt.userId==c91[c91.username=='RadioCitizenFM'].userId.values[0]].theme_desc.value_counts(normalize=True)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
nt[nt.userId==c91[c91.username=='BBCRadio4'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
c91['politic'] = c91.description.apply(lambda x: 'politic' in x.lower())
c91['live_or_break'] = c91.description.apply(lambda x: 'live' in x.lower() or 'break' in x.lower())

# %%
c91[c91.politic].anger.mean() / c91[~c91.politic].anger.mean()

# %%
c91[c91.continent=='America'].anger.mean() / c91[~(c91.continent=='America')].anger.mean()

# %%
c91[c91.live_or_break].sadness.mean() / c91[~c91.live_or_break].sadness.mean()

# %%
c91[c91.live_or_break]

# %%
c91.sort_values('anger').tail(5).description.values

# %%
c91.sort_values('optimism')

# %%
c91.sort_values('sadness')

# %%
c91.sort_values('joy')

# %%
nt[nt.userId==23937508.0].sort_values('likeCount').tail(25).content.values

# %%
nt[nt.userId==23937508.0].sort_values('likeCount').tail(25)

# %%
nt[nt.userId==23937508.0].prevalent_emotion.value_counts(normalize=True)

# %%
c9.iloc[201,:]

# %%
news_accounts[news_accounts.userId==17644834.0]

# %%
comments.query("news_id==17644834.0").news_prevalent_emotion.value_counts()

# %%
comments.query("news_id==17644834.0").prevalent_emotion.value_counts()

# %%
news_tweets.query("userId==17644834.0 and prevalent_emotion=='optimism'").content.values

# %%
comments.query("news_id==17644834.0")

# %%
c9.iloc[234,:]

# %%
comments.query("news_id==23937508.0").news_prevalent_emotion.value_counts()

# %%
comments.query("news_id==23937508.0").prevalent_emotion.value_counts()

# %%
comments.query("news_id==23937508.0")

# %%
news_accounts[news_accounts.userId==23937508.0]

# %% [markdown]
# # Likes, replies and shares related with emotions

# %%
comments.columns

# %%
comments.groupby('prevalent_emotion')[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].mean()
# Out:
#                    replyCount  retweetCount  likeCount  quoteCount
# prevalent_emotion
# anger                0.401236      0.181391   2.172032    0.042514
# joy                  0.286419      0.186197   1.954152    0.064334
# optimism             0.466677      0.388864   2.852092    0.210058
# sadness              0.500163      0.524447   2.862427    0.143670
# undefined            0.453811      0.404617   2.665493    0.153360

# %%
comments.groupby(['news_prevalent_emotion','prevalent_emotion']).tweetId.count()
# Out:
# news_prevalent_emotion  prevalent_emotion
# anger                   anger                2030624
#                         joy                   265385
#                         optimism              223519
#                         sadness               255259
#                         undefined             339943
# joy                     anger                 346331
#                         joy                   135494
#                         optimism               67078
#                         sadness                91242
#                         undefined              98946
# optimism                anger                1402380
#                         joy                   281880
#                         optimism              317402
#                         sadness               293520
#                         undefined             384711
# sadness                 anger                3592959
#                         joy                   658633
#                         optimism              621955
#                         sadness              1141695
#                         undefined             915971
# undefined               anger                2292642
#                         joy                   425454
#                         optimism              393489
#                         sadness               476241
#                         undefined             568419
# Name: tweetId, dtype: int64

# %% [markdown]
# # Trunk

# %%
theme_desc[theme_desc.theme==4].theme_desc.values[0]

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = 1145364
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = 377531
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = 497696 
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
for _ in range(50):
    k = np.random.randint(1,news_tweets.shape[0],1)[0]
    print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k=0
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
news_tweets.iloc[k,:]

# %%
topics[topics.tweetId==1331811812828803073]

# %%
theme_desc

# %%
topics = pd.read_parquet('./news_tweets_topics2.parquet')

# %%
news_tweets[news_tweets.tweetId==1331811812828803073].content.values

# %%
news_tweets.iloc[k,:]

# %%
k

# %%
news_tweets = pd.read_parquet('./../data/raw/news_tweets_with_em_scores.parquet')
news_tweets['emotion_score'] = news_tweets[['anger','joy','optimism','sadness']].max(axis=1)
news_tweets['prevalent_emotion'] = news_tweets[['anger','joy','optimism','sadness']].idxmax(axis=1)
news_tweets['prevalent_emotion'] = np.where(news_tweets.emotion_score>0.5, news_tweets.prevalent_emotion, 'undefined')

comments = comments[comments.tweetId.isin(plain_comments.tweetId)]
topics['tweetId'] = topics.tweetId.astype('float64')
news_tweets = news_tweets[~news_tweets.conversationId.isnull()].merge(topics[['theme'] + subthemes + ['tweetId']], how='left', on='tweetId')
news_accounts = news_accounts.merge(media_list, left_on='username', right_on='account')
news_accounts['userId'] = news_accounts.userId.astype('float64')
news_tweets = news_tweets.merge(news_accounts[['userId','country']], how='left')

# Define subtheme
news_tweets['subtheme'] = news_tweets[subthemes].idxmax(axis=1)
news_tweets['subtheme'] = news_tweets.subtheme.apply(lambda x: int(x[-2:]))
news_tweets['aux'] = news_tweets[subthemes].sum(axis=1)
news_tweets.loc[news_tweets.aux==0,'subtheme'] = news_tweets.loc[news_tweets.aux==0,'theme']*10
news_tweets = news_tweets.drop(subthemes + ['aux'], axis=1)
news_tweets['ds'] = news_tweets.date.dt.date

df = comments.merge(news_tweets.rename(columns={'date':'newsDate', 'userId':'newsId'})[[
    'conversationId', 'newsDate', 'newsId', 'prevalent_emotion', 'emotion_score', 'theme', 'subtheme', 'country'
]].drop_duplicates('conversationId'))
df['ds'] = (df['newsDate'] + pd.offsets.Week(weekday=6)).dt.date

# %%
df.groupby(['country', 'theme']).theme.count().rename('count').reset_index()

# %%
# import libraries
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# load dataset
tips = sns.load_dataset("tips")

# set the figure size
plt.figure(figsize=(14, 14))

# from raw value to percentage
total = tips.groupby('day')['total_bill'].sum().reset_index()
smoker = tips[tips.smoker=='Yes'].groupby('day')['total_bill'].sum().reset_index()
smoker['total_bill'] = [i / j * 100 for i,j in zip(smoker['total_bill'], total['total_bill'])]
total['total_bill'] = [i / j * 100 for i,j in zip(total['total_bill'], total['total_bill'])]

# bar chart 1 -> top bars (group of 'smoker=No')
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="day", y="total_bill", data=smoker, color='lightblue')

# add legend
top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])

# show the graph
plt.show()

# %% [markdown]
# # Rosie UK data

# %%
comments = comments.merge(news_tweets_with_em.rename(columns={'anger':'news_anger', 'sadness':'news_sadness', 'optimism':'news_optimism', 'joy':'news_joy'}).sort_values('date').drop_duplicates('conversationId', keep='first')[['conversationId', 'news_anger', 'news_sadness', 'news_optimism', 'news_joy']], how='left')
for i, g in df3[df3.newsName.isin(['BBC News (UK)', 'Daily Mail Online', 'The Guardian'])].groupby('newsName'):
    g.to_csv('./uk_users/{}.csv'.format(i), header=True, index_label=False, index=False)

# %% [markdown]
# # Google Data Studio

# %%
c2 = comments.merge(news_tweets_with_em.rename(columns={'anger':'news_anger', 'sadness':'news_sadness', 'optimism':'news_optimism', 'joy':'news_joy'}).sort_values('date').drop_duplicates('conversationId', keep='first')[['conversationId', 'news_anger', 'news_sadness', 'news_optimism', 'news_joy']], how='left')

# %%
c2[c2.country=='UK'].merge(theme_desc).merge(subtheme_desc).merge(news_accounts[['userId', 'displayname']].rename(columns={'userId':'newsId', 'displayname':'newsName'}), how='left').drop(['theme', 'subtheme', 'newsId'], axis=1)

# %%
df3 = df[df.country=='UK'].merge(theme_desc).merge(subtheme_desc).merge(news_accounts[['userId', 'displayname']].rename(columns={'userId':'newsId', 'displayname':'newsName'}), how='left').drop(['theme', 'subtheme', 'newsId'], axis=1)

# %%
c2

# %%
comments.news_emotion_score.isnull().sum()

# %%
comments

# %%
nt = pd.read_parquet('./../data/raw/news_tweets.parquet')

# %%
news_tweets['emotion_score'] = news_tweets[['anger','joy','optimism','sadness']].max(axis=1)
news_tweets['prevalent_emotion'] = news_tweets[['anger','joy','optimism','sadness']].idxmax(axis=1)
news_tweets['prevalent_emotion'] = np.where(news_tweets.emotion_score>0.5, news_tweets.prevalent_emotion, 'undefined')

comments = comments[comments.tweetId.isin(plain_comments.tweetId)]
topics['tweetId'] = topics.tweetId.astype('float64')
news_tweets = news_tweets[~news_tweets.conversationId.isnull()].merge(topics[['theme'] + subthemes + ['tweetId']], how='left', on='tweetId')
news_accounts = news_accounts.merge(media_list, left_on='username', right_on='account')
news_accounts['userId'] = news_accounts.userId.astype('float64')
news_tweets = news_tweets.merge(news_accounts[['userId','country']], how='left')

# Define subtheme
news_tweets['subtheme'] = news_tweets[subthemes].idxmax(axis=1)
news_tweets['subtheme'] = news_tweets.subtheme.apply(lambda x: int(x[-2:]))
news_tweets['aux'] = news_tweets[subthemes].sum(axis=1)
news_tweets.loc[news_tweets.aux==0,'subtheme'] = news_tweets.loc[news_tweets.aux==0,'theme']*10
news_tweets = news_tweets.drop(subthemes + ['aux'], axis=1)
news_tweets['ds'] = news_tweets.date.dt.date

# %%
df = comments.merge(news_tweets.rename(columns={'date':'newsDate', 'userId':'newsId', 'anger':'news_anger', 'sadness':'news_sadness', 'joy':'news_joy', 'optimism':'news_optimism'})[[
    'conversationId', 'newsDate', 'newsId', 'prevalent_emotion', 'emotion_score', 'theme', 'subtheme', 'country', 'news_anger', 'news_joy', 'news_sadness', 'news_optimism'
]].drop_duplicates('conversationId'))
df['ds'] = df.newsDate.dt.date

# %%
df3 = df[df.country=='UK'].merge(theme_desc).merge(subtheme_desc).merge(news_accounts[['userId', 'displayname']].rename(columns={'userId':'newsId', 'displayname':'newsName'}), how='left').drop(['theme', 'subtheme', 'newsId'], axis=1)

# %%
for i, g in df3[df3.newsName.isin(['BBC News (UK)', 'Daily Mail Online', 'The Guardian'])].groupby('newsName'):
    g.to_csv('./uk_users/{}.csv'.format(i), header=True, index_label=False, index=False)

# %%
news_tweets.rename(columns={'userId':'newsId'})

# %%
nt = news_tweets.rename(columns={'userId':'newsId'}).groupby(['ds', 'theme', 'subtheme', 'country', 'newsId']) \
       .agg({'content':'size', 'anger':'mean', 'joy':'mean', 'optimism':'mean', 'sadness':'mean', 'replyCount':'mean', 'retweetCount':'mean', 'likeCount':'mean', 'quoteCount':'mean'}) \
       .rename(columns={'content':'count'}) \
       .reset_index()
nt = nt.merge(theme_desc).merge(subtheme_desc)
nt = nt.drop(['theme_desc', 'subtheme_desc'], axis=1)
nt['newsId'] = nt.newsId.astype('int64')
nt.to_csv('agg_news_tweets.csv', index=False)

# %%
nt.columns

# %%
for col in ['replyCount', 'retweetCount', 'likeCount','quoteCount']:
    nt[col] = nt[col].astype('int32')

# %%
nt

# %%
nt.to_csv('agg_news_tweets.csv', index=False)

# %%
df['emotion_score'] = df[['anger','joy','optimism','sadness']].max(axis=1)
df['comment_emotion'] = df[['anger','joy','optimism','sadness']].idxmax(axis=1)
df['comment_emotion'] = np.where(df.emotion_score>0.5, df.comment_emotion, 'undefined')

# %%
df2 = df.groupby(['ds', 'theme', 'subtheme', 'country', 'newsId', 'prevalent_emotion']) \
       .agg({'content':'size', 'anger':'mean', 'joy':'mean', 'optimism':'mean', 'sadness':'mean', 'replyCount':'mean', 'retweetCount':'mean', 'likeCount':'mean', 'quoteCount':'mean'}) \
       .rename(columns={'content':'count'}) \
       .reset_index()
df2 = df2.merge(theme_desc).merge(subtheme_desc)
df2 = df2.drop(['theme_desc', 'subtheme_desc'], axis=1)
df2['newsId'] = df2.newsId.astype('int64')

# %%
df2[
    ~(df2.anger.isnull()) & ~(df2.joy.isnull()) & ~(df2.optimism.isnull()) & ~(df2.sadness.isnull())
].to_csv('agg_users_tweets.csv', index=False)

# %%
news_accounts['userId'] = news_accounts.userId.astype('int64')
news_accounts[['country', 'userId', 'displayname']].to_csv('lookup_news.csv', index=False)

# %%
df2

# %%
df2.dtypes

# %%
emotion_id = pd.DataFrame({'news_emotion_id':range(5),'prevalent_emotion':list(df2.prevalent_emotion.unique())})

# %%
country_id = pd.DataFrame({'country_id':range(12),'country':list(df2.country.unique())})

# %%
df2 = df2.merge(theme_desc).merge(subtheme_desc).merge(emotion_id).merge(country_id)
df2 = df2.drop(['country', 'prevalent_emotion', 'theme_desc', 'subtheme_desc'], axis=1)

# %%
df2.to_csv('emotion_per_theme.csv', index=False)
country_id.to_csv('lookup_coutry.csv', index=False)

# %%
df2[
    ~(df2.anger.isnull()) & ~(df2.joy.isnull()) & ~(df2.optimism.isnull()) & ~(df2.sadness.isnull())
].to_csv('agg_users_tweets.csv', index=False)

# %%
df2.isnull().sum()

# %%
df2[df2.anger.isnull()]

# %%
for t in [1,2,3,4,5,6,7,8]:
#for st in [11,12,21,22,41,42,43,44,51,52,53,61,62,63,64,65,66,71,72,73,74]:
    fig, axs = plt.subplots(figsize=(15, 6))
    #df = comments[comments.conversationId.isin(news_tweets[news_tweets.tweetId.isin(topics[topics[fr"subtheme{st}"]].tweetId)].conversationId)]
    df = comments[comments.conversationId.isin(news_tweets[news_tweets.tweetId.isin(topics[topics.theme==t].tweetId)].conversationId)]
    df = df.merge(news_tweets[~news_tweets.conversationId.isnull()].rename(columns={'date':'news_date'})[['conversationId', 'news_date']].drop_duplicates('conversationId'))
    #df['ds'] = pd.to_datetime(df.date.dt.year.astype(str) + '-' + df.date.dt.month.astype(str) + '-1')
    df['ds'] = df.news_date.dt.date
    df = df[['ds', 'anger', 'joy', 'optimism', 'sadness']]
    df = df.groupby('ds')[['anger', 'joy', 'optimism', 'sadness']].mean()
    df.plot.line(ax=axs)
    axs.set_xlabel("datetime")
    axs.set_ylabel("mean score per emotion")
    fig.savefig(fr"theme_monthly_{t}.png")

# %%
df = news_tweets[news_tweets.tweetId.isin(news_tweets_topics[news_tweets_topics.theme==8].tweetId)].copy()
df['ds'] = df.date.dt.date
df = df[['ds', 'anger', 'joy', 'optimism', 'sadness']]
df = df.groupby('ds')[['anger', 'joy', 'optimism', 'sadness']].mean()
df.plot.line(figsize=(15, 6))

# %%
df

# %%
df = df[['date', 'anger', 'joy', 'optimism', 'sadness']]
df.set_index('date').plot.line()

# %%
news_tweets_topics = pd.read_parquet('./news_tweets_topics.parquet')

# %%
news_tweets_topics[news_tweets_topics.topic_11 == tweets.iloc[14,:].topic_11]

# %%
news_tweets[news_tweets.tweetId==1315975830032592896]

# %%
news_tweets_topics[news_tweets_topics.tweetId==1315975830032592896]

# %%
comments[comments.conversationId==1315975830032592896]

# %%
tweets[tweets.conversationId==1315975830032592896]

# %%
tweets[(tweets.topic_11==tweets.iloc[14,:].topic_11)].head()

# %%
tweets[~tweets.topic_0.isnull()].head()

# %%
tweets.iloc[14,:].topic_11

# %%
tweets.shape

# %%
news_tweets.userId.nunique()

# %%
topics.topic.unique()

# %%
tweets = pd.read_parquet('./../data/raw/news_tweets.parquet').sample(frac=1, random_state=3)
tweets = tweets.reset_index(drop=True)

# %%
df = pd.read_csv('tweets_topics2.csv')

# %%
tweets['topic'] = df.Dominant_Topic
