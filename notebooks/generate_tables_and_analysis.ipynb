# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from wordcloud import WordCloud
import geopandas
pd.options.display.max_columns = 100
plt.style.use(['default'])

# %% [markdown]
# # Constants

# %%
themes = [
    'Authorities & Politics', 'Cases and deaths', 'Economic impact', 'Educational impact', 'People stories',
       'Preventive measures', 'Vaccines and vaccination', 'Virus spreading'
]

subthemes = [
    'subtheme11', 'subtheme12', 'subtheme21', 'subtheme22', 'subtheme41', 'subtheme42', 'subtheme43', 
    'subtheme44', 'subtheme51', 'subtheme52', 'subtheme53', 'subtheme61', 'subtheme62', 'subtheme63', 
    'subtheme64', 'subtheme65', 'subtheme66', 'subtheme71', 'subtheme72', 'subtheme73', 'subtheme74'
]

emotions = [
    'anger', 'sadness', 'optimism', 'joy'
]

keywords = [
    'remote working', 'homeschooling', 'panic buying', 'sars-cov-2', 'wearing masks', 'ncov', 'wuhan', 
    'social distancing', 'vaccination', 'quarantine', 'outbreak', 'vaccine', 'lockdown', 'pandemic', 
    'coronavirus', 'covid'
]
keywords2 = [w.replace(' ', '_').replace('-', '_') for w in keywords]

# %% [markdown]
# # Functions

# %%
def millions(x, pos):
    'The two args are the value and tick position'
    return '%1.1fM' % (x * 1e-6)

def thousands(x, pos):
    'The two args are the value and tick position'
    return '%1.fm' % (x * 1e-3)

# %% [markdown]
# # Load and process lookup tables

# %%
# Load lookup tables
media_list = pd.read_csv('./../data/external/MediaList.csv', sep=";")
theme_desc = pd.read_csv('./../data/external/theme_desc.csv')
subtheme_desc = pd.read_csv('./../data/external/subtheme_desc.csv')
topics = pd.read_parquet('./news_tweets_topics.parquet')
news_accounts = pd.read_parquet('./../data/raw/news_accounts.parquet')
users = pd.read_parquet('./../data/raw/users.parquet')

# Process lookup tables
topics['tweetId'] = topics.tweetId.astype('float64')
news_accounts = news_accounts.merge(media_list)
news_accounts['userId'] = news_accounts.userId.astype('float64')

# %% [markdown]
# # Load and process News Tweets

# %%
# Load news tweets
news_tweets = pd.read_parquet('./../data/raw/news_tweets_with_em_scores.parquet')

# Define prevalent emotion and emotion score
news_tweets['emotion_score'] = news_tweets[['anger','joy','optimism','sadness']].max(axis=1)
news_tweets['prevalent_emotion'] = news_tweets[['anger','joy','optimism','sadness']].idxmax(axis=1)
news_tweets['prevalent_emotion'] = np.where(news_tweets.emotion_score>0.5, news_tweets.prevalent_emotion, 'undefined')

# Include country information and filter valid news accountsw
news_tweets = news_tweets.merge(news_accounts[['userId','country']])
news_tweets = news_tweets[~news_tweets[emotions].isnull().any(axis=1)]
news_tweets = news_tweets.sort_values('date').drop_duplicates('conversationId', keep='first')
news_tweets = news_tweets[news_tweets.lang=='en']
print('Number of valid news tweets:', news_tweets.shape[0])

# Include theme and subtheme
news_tweets = news_tweets[~news_tweets.conversationId.isnull()].merge(topics[['theme'] + subthemes + ['tweetId']], how='left', on='tweetId')
news_tweets['subtheme'] = news_tweets[subthemes].idxmax(axis=1)
news_tweets['subtheme'] = news_tweets.subtheme.apply(lambda x: int(x[-2:]))
news_tweets['aux'] = news_tweets[subthemes].sum(axis=1)
news_tweets.loc[news_tweets.aux==0,'subtheme'] = news_tweets.loc[news_tweets.aux==0,'theme']*10
news_tweets = news_tweets.drop(subthemes + ['aux'], axis=1)

# Include date and week features
news_tweets['ds'] = news_tweets.date.dt.date
news_tweets['dsw'] = (news_tweets['date'] + pd.offsets.Week(weekday=6)).dt.date
# Out:
# Number of valid news tweets: 1678217

# %% [markdown]
# # Load and process Comments

# %%
# Load valid comments
plain_comments = pd.read_parquet('./../data/raw/comments.parquet')
comments = pd.read_parquet('./../data/raw/user_tweets_with_em_scores.parquet')
comments = comments[comments.tweetId.isin(plain_comments.tweetId)]; del plain_comments
comments = comments[comments.conversationId.isin(news_tweets.conversationId)]
comments = comments[~comments[emotions].isnull().any(axis=1)]
comments = comments[comments.lang=='en']
print('Number of valid comments:', comments.shape[0])

# Include news tweet data
comments = comments.merge(news_tweets.rename(columns={
    'date':'news_date', 'userId':'news_id', 'prevalent_emotion':'news_prevalent_emotion', 'emotion_score':'news_emotion_score',
    'anger':'news_anger', 'sadness':'news_sadness', 'optimism':'news_optimism', 'joy':'news_joy'
})[[
    'conversationId', 'news_date', 'news_id', 'news_prevalent_emotion', 'news_emotion_score', 
    'news_anger', 'news_sadness', 'news_optimism', 'news_joy', 'theme', 'subtheme', 'country'
]], how='left')

# Define prevalent emotion and emotion score
comments['emotion_score'] = comments[['anger','joy','optimism','sadness']].max(axis=1)
comments['prevalent_emotion'] = comments[['anger','joy','optimism','sadness']].idxmax(axis=1)
comments['prevalent_emotion'] = np.where(comments.emotion_score>0.5, comments.prevalent_emotion, 'undefined')

# Define continent information
comments = comments.merge(pd.DataFrame({
    'country':['AU', 'UK', 'US', 'CA', 'NZ', 'ZA', 'KE', 'NG', 'IN', 'PH', 'MY','IE'],
    'continent':['Oceania', 'Europe', 'America', 'America', 'Oceania', 'Africa', 'Africa', 'Africa', 'Asia', 'Asia', 'Asia', 'Europe']
}))

# Include date, week and month features
comments['ds'] = comments.news_date.dt.date
comments['dsw'] = (comments['news_date'] + pd.offsets.Week(weekday=6)).dt.date
comments['dsm'] = pd.to_datetime(comments.news_date.dt.year.astype(str) + '-' + comments.news_date.dt.month.astype(str) + '-1')
# Out:
# Number of valid comments: 17620904

# %%
news_tweets.userId.nunique()
# Out:
# 275

# %% [markdown]
# # Tables

# %% [markdown]
# ### Table: News Tweets Engagement

# %%
np.round(news_tweets.groupby('prevalent_emotion')[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].mean(),1)
# Out:
#                    replyCount  retweetCount  likeCount  quoteCount
# prevalent_emotion
# anger                    20.7          36.8      113.2        11.0
# joy                       8.0          22.5       97.7         7.5
# optimism                 11.0          22.6       87.8         6.7
# sadness                   9.5          24.9       66.7         6.6
# undefined                10.6          22.4       73.0         7.2

# %% [markdown]
# ### Table: Emotion over Themes

# %%
eot = comments.groupby(['theme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    eot['lift_' + col] = np.round(eot[col] / g[col], 2)
    
eot = eot[['theme'] + ['lift_' + col for col in emotions]]
eot
# Out:
#    theme  lift_anger  lift_sadness  lift_optimism  lift_joy
# 0      1        0.94          1.17           1.02      0.96
# 1      2        1.01          0.94           1.02      1.02
# 2      3        0.96          1.05           1.01      1.08
# 3      4        0.93          1.19           0.97      1.04
# 4      5        1.08          0.87           0.93      0.93
# 5      6        1.02          0.95           0.98      1.02
# 6      7        0.98          1.05           1.01      0.99
# 7      8        0.93          0.98           1.22      1.09

# %% [markdown]
# # Tweets examples

# %%
news_tweets.sample(25, random_state=99).merge(news_accounts, on='userId')
# Out:
#          tweetId  conversationId        userId                      date  \
# 0   1.280805e+18    1.280805e+18  9.294762e+06 2020-07-08 10:06:06+00:00
# 1   1.255242e+18    1.255242e+18  1.593369e+07 2020-04-28 21:07:52+00:00
# 2   1.241605e+18    1.241605e+18  6.927127e+07 2020-03-22 05:59:10+00:00
# 3   1.288342e+18    1.288342e+18  3.739789e+08 2020-07-29 05:13:31+00:00
# 4   1.246270e+18    1.246270e+18  1.525066e+07 2020-04-04 02:53:26+00:00
# 5   1.251307e+18    1.251307e+18  1.899340e+07 2020-04-18 00:28:14+00:00
# 6   1.295416e+18    1.295416e+18  1.900003e+07 2020-08-17 17:45:01+00:00
# 7   1.256147e+18    1.256147e+18  5.392522e+06 2020-05-01 09:02:04+00:00
# 8   1.276206e+18    1.276206e+18  3.150940e+09 2020-06-25 17:30:00+00:00
# 9   1.281351e+18    1.281351e+18  1.697333e+07 2020-07-09 22:15:31+00:00
# 10  1.273790e+18    1.273790e+18  1.744662e+07 2020-06-19 01:30:05+00:00
# 11  1.278943e+18    1.278943e+18  2.995893e+07 2020-07-03 06:46:05+00:00
# 12  1.257203e+18    1.257203e+18  3.974381e+07 2020-05-04 07:00:00+00:00
# 13  1.334056e+18    1.334056e+18  1.502464e+08 2020-12-02 08:43:59+00:00
# 14  1.234581e+18    1.234581e+18  1.954403e+09 2020-03-02 20:47:33+00:00
# 15  1.244373e+18    1.244373e+18  1.954403e+09 2020-03-29 21:18:32+00:00
# 16  1.271044e+18    1.271044e+18  9.721292e+06 2020-06-11 11:39:27+00:00
# 17  1.256669e+18    1.256669e+18  4.579846e+08 2020-05-02 19:35:50+00:00
# 18  1.249748e+18    1.249748e+18  2.470088e+07 2020-04-13 17:16:19+00:00
# 19  1.332376e+18    1.332376e+18  1.587242e+07 2020-11-27 17:30:00+00:00
# 20  1.271062e+18    1.271062e+18  3.163290e+07 2020-06-11 12:50:03+00:00
# 21  1.261283e+18    1.261283e+18  5.027978e+07 2020-05-15 13:10:06+00:00
# 22  1.243906e+18    1.243906e+18  3.703448e+07 2020-03-28 14:22:59+00:00
# 23  1.272598e+18    1.272598e+18  1.066973e+18 2020-06-15 18:31:12+00:00
# 24  1.255749e+18    1.255749e+18  4.298564e+07 2020-04-30 06:40:00+00:00
#
#                                               content lang  \
# 0   Covid-19 cases continue unabated in Andhra Pra...   en
# 1   #BREAKING: Another 10 people have died after c...   en
# 2   Coronavirus: Being precautious is best https:/...   en
# 3   Nigeria discharges 829 COVID-19 patients, high...   en
# 4   Pink has become the latest Hollywood star to a...   en
# 5   "It's not just about -- as far as we know -- s...   en
# 6   The AMO has at times clashed with the provinci...   en
# 7   So, what exactly is the World Health Organizat...   en
# 8   "Breaking up the Goa Forward Party doesn’t rea...   en
# 9   Girls at risk of never going back to school in...   en
# 10  "Production on season 17 of So You Think You C...   en
# 11  ICMR aims to launch indigenous Covid-19 vaccin...   en
# 12  Over 68,000 houses, that were to be delivered ...   en
# 13  Explainer: How has a Covid-19 vaccine been app...   en
# 14  EXTRA: My team has developed treatment for #co...   en
# 15  Nigeria records 14 new cases of coronavirus — ...   en
# 16  Another grim milestone in coronavirus pandemic...   en
# 17  The NBA has set a date for league practice fac...   en
# 18  GO Transit ridership down 90% during pandemic ...   en
# 19  Tokyo's daily, monthly coronavirus infections ...   en
# 20  Have Space, Will Play: Omar Abdullah Tweets Vi...   en
# 21  #Lockdown 4.0: What to expect from May 18? A l...   en
# 22  The death toll from the coronavirus outbreak i...   en
# 23  Covid-19 fuelling mother and child mortality r...   en
# 24  New Zealand Rugby faces a 70 percent decline i...   en
#
#             sourceLabel  replyCount  retweetCount  likeCount  quoteCount  \
# 0            SocialFlow         0.0           0.0        2.0         0.0
# 1            SocialFlow        13.0          20.0       27.0         8.0
# 2         WordPress.com         0.0           2.0       13.0         0.0
# 3   Twitter for Android         4.0          16.0       76.0         1.0
# 4             TweetDeck        16.0          17.0       59.0         3.0
# 5        SocialNewsDesk         0.0           1.0        7.0         0.0
# 6                Buffer         3.0           3.0        2.0         2.0
# 7            SocialFlow        18.0          82.0      159.0         7.0
# 8             TweetDeck         4.0          27.0      110.0         2.0
# 9               Echobox         0.0          13.0       23.0         1.0
# 10           SocialFlow         3.0           8.0       25.0         7.0
# 11     cmssocialservice         6.0          54.0      258.0         8.0
# 12            TweetDeck         2.0           5.0       19.0         0.0
# 13            TweetDeck         2.0           1.0        3.0         1.0
# 14  Twitter for Android        15.0          28.0       49.0        13.0
# 15  Twitter for Android         2.0          12.0       40.0         3.0
# 16            TweetDeck        11.0           8.0       23.0         3.0
# 17           SocialFlow         8.0          11.0       43.0         2.0
# 18              Echobox         5.0           1.0        5.0         0.0
# 19            TweetDeck         0.0           2.0       18.0         2.0
# 20       Hootsuite Inc.         0.0           1.0        5.0         0.0
# 21      Twitter Web App         1.0           0.0        3.0         0.0
# 22            TweetDeck         8.0          12.0      167.0         0.0
# 23   ht-twitter-handler         0.0           0.0        0.0         0.0
# 24            TweetDeck         3.0           1.0        1.0         1.0
#
#     longitude  latitude place  anger    joy  optimism  sadness  emotion_score  \
# 0         NaN       NaN  None  0.070  0.333     0.542    0.056          0.542
# 1         NaN       NaN  None  0.053  0.015     0.028    0.903          0.903
# 2         NaN       NaN  None  0.122  0.041     0.160    0.677          0.677
# 3         NaN       NaN  None  0.144  0.454     0.314    0.088          0.454
# 4         NaN       NaN  None  0.033  0.832     0.071    0.065          0.832
# 5         NaN       NaN  None  0.052  0.014     0.863    0.071          0.863
# 6         NaN       NaN  None  0.736  0.007     0.043    0.214          0.736
# 7         NaN       NaN  None  0.545  0.023     0.207    0.224          0.545
# 8         NaN       NaN  None  0.209  0.016     0.158    0.617          0.617
# 15       thecableng                TheCable
# 16            abc15           ABC15 Arizona
# 17    BreitbartNews          Breitbart News
# 18    TheTorontoSun             Toronto Sun
# 19       ABSCBNNews            ABS-CBN News
# 20          mid_day                 Mid Day
# 21  FinancialXpress         FinancialXpress
# 22             ndtv                    NDTV
# 23   HindustanTimes         Hindustan Times
# 24          radionz                     RNZ
#
#                                           description  \
# 0   Business Daily from The Hindu group of newspap...
# 1   The first TV 📺 station in #Texas & the best pl...
# 2   Official Twitter handle of Daily Trust Newspap...
# 3   A multimedia Nigerian publication based in Abu...
# 4   Australia's number one news site. Bringing you...
# 5   #1 source for breaking news, weather, and spor...
# 6   Your source for GTA breaking, investigative & ...
# 7   News. Arts & Life. Music & more. This is NPR.\...
# 8   India's foremost independent news-site, carryi...
# 9   News, comment and features from The Independen...
# 10  The Hollywood Reporter is the premier destinat...
# 11  Latest news from all over the country brought ...
# 12  India's No. 1 Business Daily that brings you t...
# 13  Providing open access to valuable journalism |...
# 14             Nigeria's independent online newspaper
# 15             Nigeria's independent online newspaper
# 16  Your #1 source for #breaking news in Arizona. ...
# 17  News, commentary, and destruction of the polit...
# 18  Toronto's best local news, sports, entertainme...
# 19  Stories, video, and multimedia for Filipinos w...
# 20  All things #MadeinMumbai \nNews | Entertainmen...
# 21  A complete up-to-date source for biz news, #fi...
# 22  Breaking news alerts from India.\n\nInstagram:...
# 23  One of India's largest media companies. Latest...
# 24  We are NZ's public broadcaster - comprehensive...
#
#                                        rawDescription  verified  \
# 0   Business Daily from The Hindu group of newspap...      True
# 1   The first TV 📺 station in #Texas & the best pl...      True
# 2   Official Twitter handle of Daily Trust Newspap...      True
# 3   A multimedia Nigerian publication based in Abu...      True
# 4   Australia's number one news site. Bringing you...      True
# 5   #1 source for breaking news, weather, and spor...      True
# 6   Your source for GTA breaking, investigative & ...      True
# 7   News. Arts & Life. Music & more. This is NPR.\...      True
# 8   India's foremost independent news-site, carryi...      True
# 9   News, comment and features from The Independen...      True
# 10  The Hollywood Reporter is the premier destinat...      True
# 11  Latest news from all over the country brought ...      True
# 12  India's No. 1 Business Daily that brings you t...      True
# 13  Providing open access to valuable journalism |...      True
# 14             Nigeria's independent online newspaper      True
# 15             Nigeria's independent online newspaper      True
# 16  Your #1 source for #breaking news in Arizona. ...      True
# 17  News, commentary, and destruction of the polit...      True
# 18  Toronto's best local news, sports, entertainme...      True
# 19  Stories, video, and multimedia for Filipinos w...      True
# 20  All things #MadeinMumbai \nNews | Entertainmen...      True
# 21  A complete up-to-date source for biz news, #fi...      True
# 22  Breaking news alerts from India.\n\nInstagram:...      True
# 23  One of India's largest media companies. Latest...      True
# 24  We are NZ's public broadcaster - comprehensive...      True
#
#                      created  followersCount  friendsCount  statusesCount  \
# 0  2007-10-07 15:53:59+00:00           81101           753         259377
# 1  2008-08-21 17:03:55+00:00          477498          2180         241866
# 2  2009-08-27 11:58:58+00:00         1858489           839         554081
# 3  2011-09-15 14:08:13+00:00         1667280           322         298754
# 4  2008-06-27 02:03:07+00:00          559636          4225         264447
# 5  2009-01-14 20:20:22+00:00          560390         24339         405331
# 6  2009-01-14 22:47:52+00:00          614709           934         173191
# 7  2007-04-22 05:10:15+00:00         8744182         68649         215493
# 8  2015-04-12 07:32:06+00:00         1077831           287         110239
# 9  2008-10-26 00:00:29+00:00         3566294           646        1122124
# 10 2008-11-17 18:10:33+00:00         3306182          2741         440039
# 11 2009-04-09 10:36:52+00:00         1751906            22         281095
# 12 2009-05-13 12:54:58+00:00         3949429            44         516317
# 13 2010-05-31 13:08:52+00:00          666703           741         297211
# 14 2013-10-11 15:01:36+00:00          719966          4164         173858
# 15 2013-10-11 15:01:36+00:00          719966          4164         173858
# 16 2007-10-26 21:32:38+00:00          438795         59404         252735
# 17 2012-01-08 01:50:52+00:00         1471106           110         145954
# 18 2009-03-16 14:45:06+00:00          334443           586         232156
# 19 2008-08-16 10:09:33+00:00         7430246          1067         891222
# 20 2009-04-16 03:48:36+00:00          670388           150         152632
# 21 2009-06-24 11:29:19+00:00          747785            37         409304
# 22 2009-05-01 20:34:48+00:00        15619334            15         818298
# 23 2018-11-26 08:30:58+00:00           42987            12         339368
# 24 2009-05-27 22:44:26+00:00           65453           327          63771
#
#     favouritesCount  listedCount  mediaCount                       location  \
# 0              1210         1303       87187                 Chennai, India
# 1              6956         2912       63149
# 2               305         1326      139317                 Abuja, Nigeria
# 3               963         1198       14240                 Abuja, Nigeria
# 4              1905         3632       46717                      Australia
# 5              5062         4866       55001         San Francisco Bay Area
# 6              1814         4336       85153                        Toronto
# 7              2553        69037        9667
# 8               470         2286       40493
# 9                54        24941      232882                London, England
# 10             1222        20993      162412                  Hollywood, CA
# 11                0         2659         237               New Delhi, India
# 12              409         8412      109657
# 13              336         2389       55717                        Ireland
# 14             2515          680       88220                        Nigeria
# 15             2515          680       88220                        Nigeria
# 16             5448         2550       81253                    Phoenix, AZ
# 17              900         9202        3886
# 18              877         2157      145768  365 Bloor St. E., Toronto, ON
# 19             1170         7887      195655            Manila, Philippines
# 20             2562         1041       46645                  Mumbai, India
# 21               27         2290      178374               New Delhi, India
# 22                0        13347      409232                          India
# 23                9          220         228               New Delhi, India
# 24             4456          630        9068        Wellington, New Zealand
#
#     protected                                   linkUrl  \
# 0       False       http://www.thehindubusinessline.com
# 1       False                     http://www.nbcdfw.com
# 2       False                     http://dailytrust.com
# 3       False             http://www.premiumtimesng.com
# 4       False                    http://www.news.com.au
# 5       False                   http://www.abc7news.com
# 6       False                 http://www.cbc.ca/toronto
# 7       False                        http://www.npr.org
# 8       False                        https://thewire.in
# 9       False                  http://independent.co.uk
# 10      False              http://hollywoodreporter.com
# 11      False  http://timesofindia.indiatimes.com/india
# 12      False    https://www.facebook.com/EconomicTimes
# 13      False                     http://thejournal.ie/
# 14      False                    http://www.thecable.ng
# 15      False                    http://www.thecable.ng
# 16      False                      http://www.abc15.com
# 17      False                      http://breitbart.com
# 18      False                 http://www.torontosun.com
# 19      False                   http://news.abs-cbn.com
# 20      False                    http://www.mid-day.com
# 21      False           http://www.financialexpress.com
# 22      False                      http://www.ndtv.com/
# 10  https://pbs.twimg.com/profile_banners/17446621...        US
# 11  https://pbs.twimg.com/profile_banners/29958928...        IN
# 12  https://pbs.twimg.com/profile_banners/39743812...        IN
# 13  https://pbs.twimg.com/profile_banners/15024640...        IE
# 14  https://pbs.twimg.com/profile_banners/19544027...        NG
# 15  https://pbs.twimg.com/profile_banners/19544027...        NG
# 16  https://pbs.twimg.com/profile_banners/9721292/...        US
# 17  https://pbs.twimg.com/profile_banners/45798459...        US
# 18  https://pbs.twimg.com/profile_banners/24700876...        CA
# 19  https://pbs.twimg.com/profile_banners/15872418...        PH
# 20  https://pbs.twimg.com/profile_banners/31632905...        IN
# 21  https://pbs.twimg.com/profile_banners/50279781...        IN
# 22  https://pbs.twimg.com/profile_banners/37034483...        IN
# 23                                               None        IN
# 24  https://pbs.twimg.com/profile_banners/42985637...        NZ
#
#                            media_outlet media_category
# 0                             The Hindu      Newspaper
# 1                                   NBC     Television
# 2                           Daily Trust      Newspaper
# 3                         Premium Times      Newspaper
# 4                                  News        Website
# 5   ABC (American Broadcasting Company)     Television
# 6                                   CBC     Television
# 7                                   NPR          Radio
# 8                             The Hindu      Newspaper
# 9                       The Independent      Newspaper
# 10               The Hollywood Reporter        Website
# 11                   The Times Of India      Newspaper
# 12                   The Economic Times      Newspaper
# 13                          The Journal        Website
# 14                             TheCable        Website
# 15                             TheCable        Website
# 16  ABC (American Broadcasting Company)     Television
# 17                       Breitbart News        Website
# 18                          Toronto Sun      Newspaper
# 19                              ABS-CBN     Television
# 20                              Mid Day      Newspaper
# 21                   The Indian Express      Newspaper
# 22                                 NDTV     Television
# 23                      Hindustan Times      Newspaper
# 24                         RNZ National          Radio

# %%
news_tweets.columns
# Out:
# Index(['tweetId', 'conversationId', 'userId', 'date', 'content', 'lang',
#        'sourceLabel', 'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'longitude', 'latitude', 'place', 'anger', 'joy', 'optimism', 'sadness',
#        'emotion_score', 'prevalent_emotion', 'country', 'theme', 'subtheme',
#        'ds', 'dsw'],
#       dtype='object')

# %%
news_tweets.sample(25, random_state=99).merge(news_accounts, on=('userId','country')).iloc[[4,5,8,18]]
# Out:
#          tweetId  conversationId        userId                      date  \
# 4   1.246270e+18    1.246270e+18  1.525066e+07 2020-04-04 02:53:26+00:00
# 5   1.251307e+18    1.251307e+18  1.899340e+07 2020-04-18 00:28:14+00:00
# 8   1.276206e+18    1.276206e+18  3.150940e+09 2020-06-25 17:30:00+00:00
# 18  1.249748e+18    1.249748e+18  2.470088e+07 2020-04-13 17:16:19+00:00
#
#                                               content lang     sourceLabel  \
# 4   Pink has become the latest Hollywood star to a...   en       TweetDeck
# 5   "It's not just about -- as far as we know -- s...   en  SocialNewsDesk
# 8   "Breaking up the Goa Forward Party doesn’t rea...   en       TweetDeck
# 18  GO Transit ridership down 90% during pandemic ...   en         Echobox
#
#     replyCount  retweetCount  likeCount  quoteCount  longitude  latitude  \
# 4         16.0          17.0       59.0         3.0        NaN       NaN
# 5          0.0           1.0        7.0         0.0        NaN       NaN
# 8          4.0          27.0      110.0         2.0        NaN       NaN
# 18         5.0           1.0        5.0         0.0        NaN       NaN
#
#    place  anger    joy  optimism  sadness  emotion_score prevalent_emotion  \
# 4   None  0.033  0.832     0.071    0.065          0.832               joy
# 5   None  0.052  0.014     0.863    0.071          0.863          optimism
# 8   None  0.209  0.016     0.158    0.617          0.617           sadness
# 18  None  0.194  0.009     0.021    0.776          0.776           sadness
#
#    country  theme  subtheme          ds         dsw         username  \
# 4       AU      5        50  2020-04-04  2020-04-05      newscomauHQ
# 5       US      1        10  2020-04-18  2020-04-19  abc7newsbayarea
# 8       IN      4        40  2020-06-25  2020-06-28       thewire_in
# 18      CA      2        20  2020-04-13  2020-04-19    TheTorontoSun
#
#     displayname                                        description  \
# 4   news.com.au  Australia's number one news site. Bringing you...
# 5     ABC7 News  #1 source for breaking news, weather, and spor...
# 8      The Wire  India's foremost independent news-site, carryi...
# 18  Toronto Sun  Toronto's best local news, sports, entertainme...
#
#                                        rawDescription  verified  \
# 4   Australia's number one news site. Bringing you...      True
# 5   #1 source for breaking news, weather, and spor...      True
# 8   India's foremost independent news-site, carryi...      True
# 18  Toronto's best local news, sports, entertainme...      True
#
#                      created  followersCount  friendsCount  statusesCount  \
# 4  2008-06-27 02:03:07+00:00          559636          4225         264447
# 5  2009-01-14 20:20:22+00:00          560390         24339         405331
# 8  2015-04-12 07:32:06+00:00         1077831           287         110239
# 18 2009-03-16 14:45:06+00:00          334443           586         232156
#
#     favouritesCount  listedCount  mediaCount                       location  \
# 4              1905         3632       46717                      Australia
# 5              5062         4866       55001         San Francisco Bay Area
# 8               470         2286       40493
# 18              877         2157      145768  365 Bloor St. E., Toronto, ON
#
#     protected                    linkUrl               linkTcourl  \
# 4       False     http://www.news.com.au  https://t.co/2imUDGKnpC
# 5       False    http://www.abc7news.com   http://t.co/2kLV4sehau
# 8       False         https://thewire.in  https://t.co/uB40W7hztX
# 18      False  http://www.torontosun.com  https://t.co/syvPNjzI8W
#
#                                       profileImageUrl  \
# 4   https://pbs.twimg.com/profile_images/109800714...
# 5   https://pbs.twimg.com/profile_images/875793011...
# 8   https://pbs.twimg.com/profile_images/131159870...
# 18  https://pbs.twimg.com/profile_images/797145490...
#
#                                      profileBannerUrl  \
# 4   https://pbs.twimg.com/profile_banners/15250661...
# 5   https://pbs.twimg.com/profile_banners/18993395...
# 8   https://pbs.twimg.com/profile_banners/31509402...
# 18  https://pbs.twimg.com/profile_banners/24700876...
#
#                            media_outlet media_category
# 4                                  News        Website
# 5   ABC (American Broadcasting Company)     Television
# 8                             The Hindu      Newspaper
# 18                          Toronto Sun      Newspaper

# %%
n = news_tweets.sample(25, random_state=99).merge(news_accounts, on=('userId','country'))
n['engagement'] = n[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].sum(axis=1)
n.iloc[[4,5,8,18]][['content', 'theme', 'subtheme', 'country']]
# Out:
#                                               content  theme  subtheme country
# 4   Pink has become the latest Hollywood star to a...      5        50      AU
# 5   "It's not just about -- as far as we know -- s...      1        10      US
# 8   "Breaking up the Goa Forward Party doesn’t rea...      4        40      IN
# 18  GO Transit ridership down 90% during pandemic ...      2        20      CA

# %%
list(news_tweets.sample(25, random_state=99).merge(news_accounts, on='userId').content)
# Out:
# ['Covid-19 cases continue unabated in Andhra Pradesh with the detection of 1,062 new positive cases. https://t.co/mvWswPuRqa',
#  '#BREAKING: Another 10 people have died after contracting COVID-19, including a 17-year-old Lancaster girl, according to county health officials who also confirm another 135 new infections. https://t.co/eXPAJdCCN8 https://t.co/K45Dpz5l8I',
#  'Coronavirus: Being precautious is best https://t.co/xU2PKXcDCn',
#  'Nigeria discharges 829 COVID-19 patients, highest number in one day https://t.co/Ci0WkL5khy',
#  'Pink has become the latest Hollywood star to announce she has tested positive for coronavirus.\nhttps://t.co/3kpIeN8apQ',
#  '"It\'s not just about -- as far as we know -- social distancing. It\'s about taking a number of steps, implementing a number of procedures to make sure that people feel safe." - @RobertIger https://t.co/ZtLfuVaV43',
#  "The AMO has at times clashed with the provincial government during the COVID-19 pandemic, saying last month that emergency funds haven't flowed to municipalities quickly enough. https://t.co/NBuY8XZ3Pr",
#  "So, what exactly is the World Health Organization? What does it do? Why is President Trump trying to withhold funding? \n\nFrom its origins to its role today in the coronavirus pandemic, here's everything you need to know about the WHO. https://t.co/XEFS3aQLM3",
#  '"Breaking up the Goa Forward Party doesn’t really do much for the BJP, except to prove that the saffron party is cynical enough to play political hopscotch during a pandemic and an economic downturn."\n\nhttps://t.co/qbsXDzHTU9',
#  'Girls at risk of never going back to school in Africa and Asia amid coronavirus crisis https://t.co/LJkj7tWOjB',
#  '"Production on season 17 of So You Think You Can Dance will not be moving forward due to health and governmental restrictions in response to the COVID-19 pandemic," Fox said in a statement Thursday of #SYTYCD  https://t.co/QWw013jPKj',
#  'ICMR aims to launch indigenous Covid-19 vaccine by August 15 https://t.co/jiixOLYGGb',
#  'Over 68,000 houses, that were to be delivered to buyers in 2020 in the #Delhi-#NCR are unlikely to be completed due to stopped construction during lockdown and the #NGT ban in November-December \nhttps://t.co/3L5fQsVlKe',
#  'Explainer: How has a Covid-19 vaccine been approved so quickly in the UK? https://t.co/s7ymisGQax',
#  'EXTRA: My team has developed treatment for #coronavirus, says Maurice Iwu https://t.co/gd4cIyXvfH via @thecableng #COVID19 https://t.co/cdIUvO6XoH',
#  'Nigeria records 14 new cases of coronavirus — toll hits 111 https://t.co/P8MF2fkb2t via @thecableng #COVID19Nigeria #StayAtHomeAndStaySafe https://t.co/XBwF3ZQ2qa',
#  'Another grim milestone in coronavirus pandemic: 2 million confirmed cases in the US\n https://t.co/XaFnc8sIrT #abc15 https://t.co/2SyYCytp3y',
#  'The NBA has set a date for league practice facilities to re-open, however, that doesn’t mean they’re ready to start testing their asymptomatic players for the coronavirus. https://t.co/OFp6bHSvgc',
#  'GO Transit ridership down 90% during pandemic https://t.co/Irnz0ftHFy #onpoli https://t.co/yEhsJ0Umfa',
#  "Tokyo's daily, monthly coronavirus infections rise to record levels https://t.co/t8f1o5X6YL",
#  'Have Space, Will Play: Omar Abdullah Tweets Video Of People Playing Cricket Inside Quarantine Centre\n\nhttps://t.co/2zRDfajB7Z',
#  '#Lockdown 4.0: What to expect from May 18? A look at what states have in store for you\n\nhttps://t.co/wVuuGxAQJ4 https://t.co/CmaYlPnjDP',
#  'The death toll from the coronavirus outbreak in Britain has risen to 1,019: news agency AFP. \n\n#CoronavirusOutbreak #CoronavirusPandemic',
#  'Covid-19 fuelling mother and child mortality rates\nhttps://t.co/WbFuILpvtE',
#  'New Zealand Rugby faces a 70 percent decline in revenue in 2020 amid a global shutdown of sport due to the coronavirus, officials said. https://t.co/TQokJt3Kq3']

# %%
theme_desc
# Out:
#    theme                theme_desc
# 0      1          Cases and deaths
# 1      2           Economic impact
# 2      3        Educational impact
# 3      4            People stories
# 4      5    Authorities & Politics
# 5      6       Preventive measures
# 6      7           Virus spreading
# 7      8  Vaccines and vaccination

# %%
list(news_tweets.sample(25, random_state=73).merge(news_accounts, on='userId').content)
# Out:
# ["Chile's strong vaccination campaign is getting rewarded in financial markets as traders bet on a faster recovery. https://t.co/IHrrhOw7jw",
#  'South African business confidence jumps to the highest level in more than two years as further easing of lockdown restrictions spurred a resurgence in activity https://t.co/aT9ZHbifMw',
#  'Himachal Pradesh hoteliers not happy with Unlock 2.0 guidelines, they fear allowing tourists without quarantine could lead to a spike in cases. \n#HimachalPradesh #coronavirus\n(@manjeet_sehgal)\nhttps://t.co/rMkOkHSirH',
#  '11 Nigerians die of COVID-19 in South Africa https://t.co/q21wdvZ7uF https://t.co/6SsRRyoKbF',
#  'Second man dies of #coronavirus in US: health officials  (AFP) \n\n#CoronavirusOutbreak #CoronaVirusUpdate \n\nKeep following our LIVE blog: https://t.co/DCrjmPTiy9 https://t.co/rOQhow6fzY',
#  'Toronto has administered more than 923,000 vaccine doses in total. https://t.co/5flVuhTYVB',
#  'Melania Trump defends her work on the White House tennis pavilion as the coronavirus spreads https://t.co/1eLxAPPn9j https://t.co/wXspCCn4QY',
#  '#EXCLUSIVE\nCancer, heart disease and diabetes are going undiagnosed as Australians fearful of COVID-19 avoid their doctor and worryingly those most at risk are not using new telehealth solutions.',
#  'Night curfew, prohibitory orders imposed in Leh amid COVID-19 spike | via @IndiaTVNews https://t.co/HA0E0flbg8',
#  'The US Centers for Disease Control and Prevention has issued its first guidance for the holidays, including Halloween, amid the raging coronavirus pandemic in a new posting on its website Monday night. https://t.co/lke2ue8W9C',
#  'The woman posted on social media - “I don\'t believe there\'s a pandemic. It\'s a SCAMdemic. Know your rights." #9News\nhttps://t.co/Kw9xS3TXzP',
#  'Oxygen shortage continued to cripple treatment of Covid patients in both private and govt hospitals in Patna as attendants with patients ran from one hospital to another in search of the life-sustaining gas on Sunday.\n\n#COVIDEmergency2021 #OxygenCrisis \n\nhttps://t.co/o2djpCscpC',
#  '#ExpressBiz | Difficult to accurately assess economic impact of COVID-19: RBI\n\nhttps://t.co/NatwaT2dTQ',
#  'Australia’s Prime Minister Scott Morrison has urged people not to attend planned #BlackLivesMatter protests around the country this weekend, citing the risk of spreading the #coronavirus. #GeorgeFlyod \n\nhttps://t.co/5C3Y2MEaQJ via #SABCNews',
#  '#NewsAlert | India reports more than 46k Covid cases and 212 deaths in the last 24 hours. https://t.co/Xcn56BafZ9',
#  '#NewsAlert | Senior railway officer tests positive for COVID; 3rd case at Rail Bhavan. https://t.co/sRmX5gn4mv',
#  'Almost 200 second level pupils in Co Kildare have been left without a school bus service after a private bus company ceased operating the route due to social distancing requirements.\nhttps://t.co/loF4md4n6q',
#  'Nearly half of Americans delayed medical care due to the coronavirus https://t.co/ixPuSZKlb2',
#  'China’s farmers offered buy-out to grow plants instead of breeding wild species in coronavirus clampdown https://t.co/0sTMZdPYWb',
#  'REVERTING to a stricter quarantine in Metro Manila would “destroy” not just business but also the morale of business owners, Presidential Adviser for Entrepreneurship Jose Maria “Joey” Concepcion 3rd said. “[It] will really destroy not only businesses ... https://t.co/UOkGgCPYld',
#  'Coronavirus infections top 5 million worldwide https://t.co/5iGKq0QCo3',
#  'Do contact tracing apps help control the spread of coronavirus?\n\nhttps://t.co/fcUhbMATLB',
#  "Health care workers who came from around the country to help fight the coronavirus pandemic in New York will have to pay the state's income tax, New York's Gov. Andrew Cuomo said. https://t.co/4siwg2SjRL",
#  'Smashing eggs, dumping milk: Farms forced to waste food in pandemic\nhttps://t.co/yxqdtrRSzm',
#  'COVID-19 Italy: Elderly may be left to die in new protocol aimed at containing virus crisis https://t.co/XUMIIUYYjQ #COVID19 https://t.co/sFUFS0qHbP']

# %%
list(news_tweets.sample(25, random_state=13).merge(news_accounts, on='userId').iloc[[3,9,16,21]].content)
# Out:
# ['Mike Pompeo Says "Enormous Evidence" Virus Came From Wuhan Lab https://t.co/AhjvLi6Iuj',
#  'Students were informed via email that a student has contracted the coronavirus and contact tracing is underway. \n\nUCC did not specify the department the student was in.\n\n#Coronavirus\n#COVID19\n\nhttps://t.co/7sgRrL9WUX',
#  'Maureen said she has been in home quarantine for two weeks and the experience has taken a toll on her mental health. She assured, however, that she is "much better now" and she is "grateful to be alive."\n\nhttps://t.co/7kON6kpBhH',
#  'PNP Caraga to probe source of flight information of 1st COVID-19 patient https://t.co/DLJxkIRBwa https://t.co/6i4DxF17iG']

# %%
comments['clen'] = comments.content.apply(lambda x: len(x))

# %%
c = pd.concat([
    comments[(comments.prevalent_emotion=='anger') & (comments.clen>100)].sample(5, random_state=13),
    comments[(comments.prevalent_emotion=='sadness') & (comments.clen>100)].sample(5, random_state=13),
    comments[(comments.prevalent_emotion=='optimism') & (comments.clen>100)].sample(5, random_state=13),
    comments[(comments.prevalent_emotion=='joy') & (comments.clen>100)].sample(5, random_state=13),
])
c
# Out:
#                tweetId  conversationId        userId  \
# 4843470   1.275432e+18    1.275176e+18  3.188441e+09
# 15124836  1.258527e+18    1.258520e+18  1.443213e+09
# 238376    1.289478e+18    1.289427e+18  4.664260e+08
# 16093835  1.246718e+18    1.246636e+18  3.981537e+08
# 2650156   1.363747e+18    1.363746e+18  1.258519e+18
# 12161058  1.286159e+18    1.285012e+18  9.991129e+17
# 16135132  1.236284e+18    1.236128e+18  9.476119e+07
# 12161058           sadness   America  2020-07-20  2020-07-26 2020-07-01   170
# 16135132           sadness      Asia  2020-03-07  2020-03-08 2020-03-01   257
# 17616466           sadness    Europe  2020-03-23  2020-03-29 2020-03-01   307
# 3436332            sadness   America  2020-05-01  2020-05-03 2020-05-01   152
# 792617             sadness    Europe  2021-04-18  2021-04-25 2021-04-01   302
# 4585039           optimism   America  2020-05-19  2020-05-24 2020-05-01   252
# 8482250           optimism   America  2020-09-15  2020-09-20 2020-09-01   328
# 5909728           optimism   America  2020-09-15  2020-09-20 2020-09-01   181
# 13873007          optimism   America  2021-04-14  2021-04-18 2021-04-01   130
# 11161506          optimism   America  2020-11-24  2020-11-29 2020-11-01   134
# 2597172                joy    Europe  2020-06-24  2020-06-28 2020-06-01   115
# 274579                 joy   Oceania  2021-04-29  2021-05-02 2021-04-01   218
# 5486092                joy   America  2020-05-02  2020-05-03 2020-05-01   343
# 9849676                joy   America  2020-12-13  2020-12-20 2020-12-01   110
# 17062241               joy      Asia  2020-08-12  2020-08-16 2020-08-01   223

# %%
[str(cnt) + ' | ' + text for cnt, text in enumerate(c.content)]
# Out:
# ['0 | @ABC However, most people know when he\'s "joking" and when he\'s not. If the comment indicates harm to a group, he\'s saying exactly what he wants to happen. If he says he\'s going to do something positive for people or the country,  you can bet he\'s lying.',
#  '1 | @channelstv Which experts? What has they all done to make Nigeria better? These ones are just normal and random person jawe. Expert for where?',
#  "2 | @Mary__Darly @abcnews Did I argue against other approaches as well? No. I don't know why this conversation is still going on so I'll leave it here.",
#  '3 | @IndiaToday @delayedjab Who is at fault for not quarantine the youth at the airport ?Can modi answer why he lied to the world during teleconference declaring airport testing &amp;quarantining was inplace from jan 15 ?We had an OPPERTUNITY to learn from China then from italy but we missed that great chance',
#  '4 | @BBCWorld Too early, given in to the pressure of a small group of loud voices in parliament again. @BorisJohnson is so weak. Guess we will await lockdown 4.',
#  '5 | @mylesbecker @RoyThomas77 @Sheri_lp @ABC Except by the CDCs own admission 10-35 TIMES as many people have had it.  So yes, survival 99+%.  And almost zero healthy people.',
#  '6 | Two more cases, including one person from Tamil Nadu with travel history from Oman and one from Ladakh have tested positive for #coronavirus, taking the total number to 34.\n#coronavirusindia #CoronavirusOutbreak #TamilNadu\n@xpresstn \nhttps://t.co/D8mX2yduGK',
#  "7 | @STAYatHOMEfools @rtenews @SimonHarrisTD @morningireland If you have no money to pay rent or buy food then it's not shallow to be worrying about it. A lot of businesses have closed because of this and the long term financial impact will be devastating. You wouldn't make that statement to a homeless person.",
#  '8 | @maniac_angelo @2020DoOver @deidesk @CNN Do your due diligence &amp; investigate. Gui had a home in Thailand. And then vanished: https://t.co/OVMBX3Z8xn',
#  '9 | @MarkIrv64245171 @BBCScotlandNews My dad was taken into a care home in June 2020. He died of prostate cancer 3 weeks later. I visited him regularly. I was not tested once. Why? There were so few testing kits available. Your view of this needs context. Testing was not widespread till many months later.',
#  "10 | @ABC You could ask your mum to stump up a decent hourly rate, say £15 per hour and you would have a tremendous workforce turn up. Where there's a will there's a way. Unless of course you were looking for volunteers and tapping into that wartime spirit.",
#  '11 | @DigitalConTech1 @business @BharatBiotech @BillGates @FDA @CDCGlobal @KTRTRS #COVAXIN is the best bet so far in regards to #COVID vaccine, hoping @ICMRDELHI &amp; all the govt departs decentralize vaccine testing, approvals &amp; licensing @KTRTRS\n#Hyderabad : vaccine capital &amp; bulk drugs capital of the world @WHO @Reuters',
#  "12 | @CNN That news is encouraging but vaccines don't save lives vaccinations do. Trump crown wont wear a mask some of them don't believe in the virus . That means a very long road ahead",
#  '13 | @nationalpost That’s because he already has his shots and is not worried about anything while living way up there on mount Olympus',
#  '14 | @karma1246968439 @NetanelWorthy @cnnbrk Work harder not smarter. I’m cashing out soon. I can survive on bare minimum. Builds character',
#  '15 | @BBCNews Awwwww a socially distant Apprentice where candidates have to work together via Zoom would have been good.',
#  '16 | @newscomauHQ Did someone go for a swim in the sewage plant? Thank god you have been keeping me up to date with what is in our sewage system lol. I disconnected my wastewater in case the Covid came back out my toilet ;)',
#  '17 | @charles00263199 @Mingfan92868688 @Orangishly @CNN @atulgera007 @DeviSaraswat @Nimratkhaira_ @carole_awebb @TandonRaveena @TheTweetOfGod @LadyVelvet_HFQ @vidya_balan @smritiirani @sonalkalra @Riteishd @BillGates @imVkohli You only suspect but I and whole world beleive and has infinite facts that it is from dragon. Go and Enjoy your meal now.',
#  '18 | @TMZ Oh wow. Glad to know this. I try to make every decision in my life based on what Offset would do. 👍🏼 WWOD',
#  "19 | DOST Usec. for Research &amp; Devt. Dr. Rowena Guevara on their meeting with Russian manufacturers on the latter's COVID-19 vaccine: We learned they have finished Phase 1 and almost finishing Phase 2 https://t.co/R8l5svpACH"]

# %% [markdown]
# 3 "(...) He doesn’t respect the reporters neither the people that are at the frontline fighting for this virus (...)"
# 7 "(...) so many doctors in Europe who have to decide who gets a respirator and who has to die (...)"
# 12 "(...) I do hope you and the rest of the 1743 family are well (...)"
# 17 "(...) I heard this as well via a reputable news source. You're not imagining it. :) (...)"

# %%
c['engagement'] = c[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].sum(axis=1)
c.iloc[[3,7,12,17]][['content', 'prevalent_emotion', 'emotion_score', 'country']]
# Out:
#                                                     content prevalent_emotion  \
# 16093835  @IndiaToday @delayedjab Who is at fault for no...             anger
# 17616466  @STAYatHOMEfools @rtenews @SimonHarrisTD @morn...           sadness
# 5909728   @CNN That news is encouraging but vaccines don...          optimism
# 5486092   @charles00263199 @Mingfan92868688 @Orangishly ...               joy
#
#           emotion_score country
# 16093835          0.823      IN
# 17616466          0.850      IE
# 5909728           0.822      US
# 5486092           0.572      US

# %% [markdown]
# N/C | Content | Prevalent Emotion | Score | Theme | Subtheme | Engagement

# %% [markdown]
# # Analysis

# %%
g = comments[emotions].mean()
g
# Out:
# anger       0.538529
# sadness     0.194306
# optimism    0.143848
# joy         0.123318
# dtype: float64

# %%
c0 = comments.groupby(['country', 'theme', 'subtheme', 'news_prevalent_emotion']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c0['lift_' + col] = c0[col] / g[col]

c0[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.775207
# lift_sadness     4.312794
# lift_optimism    3.322962
# lift_joy         7.533361
# dtype: float64

# %%
c1 = comments.groupby(['country', 'theme', 'subtheme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c1['lift_' + col] = c1[col] / g[col]

c1[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.775207
# lift_sadness     3.427591
# lift_optimism    2.280192
# lift_joy         2.319745
# dtype: float64

# %%
c2 = comments.groupby(['country', 'theme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c2['lift_' + col] = c2[col] / g[col]

c2[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.121885
# lift_sadness     1.579353
# lift_optimism    1.735948
# lift_joy         1.445416
# dtype: float64

# %%
c3 = comments.groupby(['country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c3['lift_' + col] = c3[col] / g[col]

c3[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.043752
# lift_sadness     1.198346
# lift_optimism    1.596843
# lift_joy         1.185100
# dtype: float64

# %%
c31 = comments.groupby(['continent', 'country', 'dsm']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c31['lift_' + col] = c31[col] / g[col]

c31[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.185070
# lift_sadness     1.505039
# lift_optimism    2.055937
# lift_joy         1.462449
# dtype: float64

# %%
c4 = comments.groupby(['theme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c4['lift_' + col] = c4[col] / g[col]

c4[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.080210
# lift_sadness     1.190233
# lift_optimism    1.216322
# lift_joy         1.093226
# dtype: float64

# %%
c41 = comments.groupby(['theme', 'country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c41['lift_' + col] = c41[col] / g[col]

c41[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.121885
# lift_sadness     1.579353
# lift_optimism    1.735948
# lift_joy         1.445416
# dtype: float64

# %%
c42 = comments.groupby(['theme', 'dsw']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c42['lift_' + col] = c42[col] / g[col]

c42[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.494194
# lift_sadness     2.382523
# lift_optimism    2.875389
# lift_joy         1.566086
# dtype: float64

# %%
c5 = comments.groupby(['subtheme']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c5['lift_' + col] = c5[col] / g[col]

c5[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.145032
# lift_sadness     1.511870
# lift_optimism    1.216322
# lift_joy         1.120586
# dtype: float64

# %%
c51 = comments.groupby(['subtheme', 'country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c51['lift_' + col] = c51[col] / g[col]

c51[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.775207
# lift_sadness     3.427591
# lift_optimism    2.280192
# lift_joy         2.319745
# dtype: float64

# %%
c52 = comments.groupby(['subtheme', 'news_prevalent_emotion']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c52['lift_' + col] = c52[col] / g[col]

c52[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.217813
# lift_sadness     1.713152
# lift_optimism    1.350780
# lift_joy         7.533361
# dtype: float64

# %%
c6 = comments.groupby(['news_prevalent_emotion']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c6['lift_' + col] = c6[col] / g[col]

c6[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.156106
# lift_sadness     1.162794
# lift_optimism    1.174986
# lift_joy         1.617616
# dtype: float64

# %%
c61 = comments.groupby(['news_prevalent_emotion', 'country']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c61['lift_' + col] = c61[col] / g[col]

c61[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.188645
# lift_sadness     1.410114
# lift_optimism    1.948920
# lift_joy         2.032791
# dtype: float64

# %%
c7 = comments.groupby(['dsw']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c7['lift_' + col] = c7[col] / g[col]

c7[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.104867
# lift_sadness     1.342395
# lift_optimism    1.230986
# lift_joy         1.108795
# dtype: float64

# %%
c8 = comments.groupby(['continent']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c8['lift_' + col] = c8[col] / g[col]

c8[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.037933
# lift_sadness     1.106692
# lift_optimism    1.273735
# lift_joy         1.173476
# dtype: float64

# %%
c81 = comments.groupby(['continent', 'dsm']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c81['lift_' + col] = c81[col] / g[col]

c81[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.112782
# lift_sadness     1.418359
# lift_optimism    1.540460
# lift_joy         1.364790
# dtype: float64

# %%
c9 = comments.groupby(['continent', 'country', 'news_id']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c9['lift_' + col] = c9[col] / g[col]

c9[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.148388
# lift_sadness     2.312080
# lift_optimism    5.575347
# lift_joy         5.817179
# dtype: float64

# %%
c91 = c9[c9.tweetId>1000].merge(news_accounts.drop('country',axis=1), left_on='news_id', right_on='userId', how='left')

# %% [markdown]
# # Conclusions

# %% [markdown]
# #### T1: joyful news reflect in more joyful comments, mainly in IE, IN and PH

# %%
c6
# Out:
#   news_prevalent_emotion     anger   sadness  optimism       joy  tweetId  \
# 0                  anger  0.622596  0.149089  0.122179  0.106135  3114730
# 1                    joy  0.470750  0.186018  0.143751  0.199481   739091
# 2               optimism  0.518069  0.182010  0.169019  0.130902  2679893
# 3                sadness  0.514258  0.225937  0.141646  0.118159  6931213
# 4              undefined  0.541249  0.184842  0.147544  0.126365  4156245
#
#    lift_anger  lift_sadness  lift_optimism  lift_joy
# 0    1.156106      0.767292       0.849364  0.860664
# 1    0.874140      0.957348       0.999329  1.617616
# 2    0.962008      0.936722       1.174986  1.061496
# 3    0.954931      1.162794       0.984697  0.958165
# 4    1.005051      0.951293       1.025700  1.024707

# %%
c6[c6.lift_joy>1.5]
# Out:
#   news_prevalent_emotion    anger   sadness  optimism       joy  tweetId  \
# 1                    joy  0.47075  0.186018  0.143751  0.199481   739091
#
#    lift_anger  lift_sadness  lift_optimism  lift_joy
# 1     0.87414      0.957348       0.999329  1.617616

# %%
c61[c61.news_prevalent_emotion=='joy'].sort_values('lift_joy')
# Out:
#    news_prevalent_emotion country     anger   sadness  optimism       joy  \
# 13                    joy      CA  0.492252  0.198934  0.146259  0.162554
# 12                    joy      AU  0.509158  0.184852  0.137281  0.168700
# 23                    joy      ZA  0.451983  0.218784  0.146514  0.182723
# 16                    joy      KE  0.423523  0.214678  0.172986  0.188811
# 22                    joy      US  0.492600  0.178055  0.135752  0.193592
# 17                    joy      MY  0.425265  0.216059  0.163382  0.195305
# 18                    joy      NG  0.431903  0.192928  0.162623  0.212556
# 19                    joy      NZ  0.441800  0.197077  0.146927  0.214210
# 21                    joy      UK  0.448647  0.194351  0.139845  0.217158
# 15                    joy      IN  0.397255  0.191865  0.174086  0.236793
# 14                    joy      IE  0.424712  0.191872  0.141574  0.241833
# 20                    joy      PH  0.312943  0.206022  0.230357  0.250680
#
#     tweetId  lift_anger  lift_sadness  lift_optimism  lift_joy
# 13    56064    0.914068      1.023819       1.016767  1.318167
# 12    22123    0.945462      0.951348       0.954350  1.368006
# 23    13690    0.839292      1.125977       1.018534  1.481719
# 16     6342    0.786445      1.104846       1.202566  1.531086
# 22   415149    0.914715      0.916365       0.943723  1.569862
# 17     2614    0.789679      1.111954       1.135798  1.583748
# 18    32514    0.802006      0.992909       1.130523  1.723642
# 19     3821    0.820384      1.014261       1.021406  1.737055
# 21   114511    0.833098      1.000234       0.972174  1.760955
# 15    43915    0.737667      0.987440       1.210211  1.920178
# 14    10330    0.788651      0.987477       0.984194  1.961046
# 20    18018    0.581107      1.060298       1.601396  2.032791

# %% [markdown]
# #### News about vaccines generate more positive feelings (optmism and joy), mainly in PH, In and NZ

# %%
c4
# Out:
#    theme     anger   sadness  optimism       joy  tweetId  lift_anger  \
#
comments[(comments.country=='NG') & (comments.dsm=='2020-10-01') & (comments.prevalent_emotion=='anger')].conversationId.value_counts(normalize=True).cumsum().head(25).index
# Out:
# Float64Index([1.3166856469840773e+18, 1.3171886046077379e+18,
#                1.319231803396395e+18, 1.3193416341155226e+18,
#               1.3193295694684856e+18,  1.319997321745191e+18,
#               1.3183019495995105e+18, 1.3206771328220856e+18,
#                1.320977142126125e+18,  1.319737814427312e+18,
#               1.3195245308141322e+18,  1.319717867835822e+18,
#               1.3196266964091003e+18,  1.318750934030295e+18,
#               1.3171733915148657e+18, 1.3210016620902728e+18,
#               1.3209854470199828e+18, 1.3148242603392778e+18,
#               1.3183316844634972e+18,  1.319709058312491e+18,
#               1.3206903975517102e+18,  1.320967983154393e+18,
#               1.3209706091285463e+18,  1.319993214435197e+18,
#               1.3206377425822884e+18],
#              dtype='float64')

# %%
c31[c31.continent=='Africa']
# Out:
#    continent country        dsm     anger   sadness  optimism       joy  \
# 0     Africa      KE 2020-01-01  0.528234  0.240243  0.133353  0.098170
# 1     Africa      KE 2020-02-01  0.584330  0.206586  0.126127  0.082958
# 2     Africa      KE 2020-03-01  0.486895  0.232230  0.164273  0.116602
# 3     Africa      KE 2020-04-01  0.489843  0.224633  0.169144  0.116382
# 4     Africa      KE 2020-05-01  0.477085  0.234043  0.171259  0.117607
# 5     Africa      KE 2020-06-01  0.475983  0.224580  0.160338  0.139101
# 6     Africa      KE 2020-07-01  0.459180  0.248792  0.163743  0.128279
# 7     Africa      KE 2020-08-01  0.494500  0.234219  0.149402  0.121878
# 8     Africa      KE 2020-09-01  0.503485  0.204077  0.154163  0.138285
# 9     Africa      KE 2020-10-01  0.495175  0.247604  0.149722  0.107505
# 10    Africa      KE 2020-11-01  0.486613  0.258667  0.152436  0.102282
# 11    Africa      KE 2020-12-01  0.454735  0.257059  0.162036  0.126180
# 12    Africa      KE 2021-01-01  0.483663  0.227407  0.160374  0.128552
# 13    Africa      KE 2021-02-01  0.469981  0.222206  0.169672  0.138132
# 14    Africa      KE 2021-03-01  0.442612  0.263605  0.166313  0.127468
# 15    Africa      KE 2021-04-01  0.510266  0.214587  0.145140  0.130001
# 16    Africa      NG 2020-01-01  0.495633  0.229379  0.160715  0.114292
# 17    Africa      NG 2020-02-01  0.518756  0.190709  0.129297  0.161239
# 18    Africa      NG 2020-03-01  0.475960  0.209140  0.169453  0.145446
# 19    Africa      NG 2020-04-01  0.490315  0.207965  0.161264  0.140456
# 20    Africa      NG 2020-05-01  0.491153  0.199038  0.172167  0.137647
# 21    Africa      NG 2020-06-01  0.475651  0.209885  0.165020  0.149446
# 22    Africa      NG 2020-07-01  0.498070  0.201412  0.160126  0.140393
# 23    Africa      NG 2020-08-01  0.474431  0.198512  0.164649  0.162410
# 24    Africa      NG 2020-09-01  0.486423  0.189448  0.155250  0.168874
# 25    Africa      NG 2020-10-01  0.638194  0.153079  0.104586  0.104138
# 26    Africa      NG 2020-11-01  0.505834  0.188207  0.142325  0.163640
# 27    Africa      NG 2020-12-01  0.496310  0.191090  0.156067  0.156528
weetId  lift_anger  lift_sadness  lift_optimism  lift_joy
# 7        392    0.607423      1.031748       1.358812  2.245685
# 11      1451    0.638094      1.043274       1.271327  2.195763
# 30         5    0.495795      0.343788       2.380298  2.622485
# 95        19    0.814109      1.017659       0.499432  2.370420
# 125     1379    0.604176      0.911056       1.117895  2.731152
# 133       65    0.311904      0.988768       0.867050  4.177313
# 134       35    0.594105      1.180762       0.955575  2.540931
# 156      470    0.497830      1.392356       1.460264  2.037387
# 162       55    0.747052      0.996275       0.845845  2.290749
# 174        4    0.389023      0.590565       1.883939  3.280134
# 189        4    0.049208      1.304646       0.773388  4.938447
# 193        4    0.234899      2.312080       0.543979  2.807779
# 205       87    0.632417      1.233748       1.024233  2.208194
# 206       11    0.214895      0.596062       0.355806  5.817179
# 211        9    0.466497      0.373410       1.644488  3.566205
# 214       59    0.568152      0.956644       0.593378  3.428091
# 232    14536    0.543973      1.056591       0.833409  3.096684
# 262       27    0.483209      1.336383       1.510859  2.131194
# 268        7    0.686261      0.670520       0.697167  3.242485

# %%
c9[c9.lift_optimism>2]
# Out:
#     continent country       news_id     anger   sadness  optimism       joy  \
# 30     Africa      NG  1.698798e+09  0.267000  0.066800  0.342400  0.323400
# 116      Asia      IN  9.294762e+06  0.251140  0.199962  0.307665  0.241182
# 141      Asia      IN  2.611139e+08  0.136000  0.031000  0.802000  0.031000
# 180      Asia      PH  1.764483e+07  0.264892  0.220842  0.395969  0.118279
# 188      Asia      PH  6.341162e+07  0.296483  0.187066  0.344509  0.171927
# 197      Asia      PH  8.233496e+17  0.287268  0.217670  0.329314  0.165775
#
#      tweetId  lift_anger  lift_sadness  lift_optimism  lift_joy
# 30         5    0.495795      0.343788       2.380298  2.622485
# 116      650    0.466345      1.029109       2.138824  1.955767
# 141        1    0.252540      0.159542       5.575347  0.251382
# 180     2300    0.491880      1.136571       2.752700  0.959138
# 188     1420    0.550543      0.962742       2.394960  1.394173
# 197     1783    0.533430      1.120247       2.289327  1.344288

# %%
nt = news_tweets.merge(theme_desc)

# %%
nt.theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.196295
# Virus spreading             0.181703
# Cases and deaths            0.166808
# Preventive measures         0.143179
# Authorities & Politics      0.111972
# Educational impact          0.091092
# People stories              0.057567
# Vaccines and vaccination    0.051384
# Name: theme_desc, dtype: float64

# %%
pd.options.display.max_rows=100

# %%
nt.groupby('country').theme_desc.value_counts(normalize=True)
# Out:
# country  theme_desc
# AU       Economic impact             0.167726
#          Virus spreading             0.155865
#          Preventive measures         0.148459
#          People stories              0.144455
#          Cases and deaths            0.138862
#          Authorities & Politics      0.110512
#          Educational impact          0.094835
#          Vaccines and vaccination    0.039285
# CA       Economic impact             0.195556
#          Virus spreading             0.162582
#          Cases and deaths            0.161789
#          Authorities & Politics      0.160831
#          Educational impact          0.118326
#          Preventive measures         0.096161
#          People stories              0.056719
#          Vaccines and vaccination    0.048036
# IE       Virus spreading             0.195870
#          Economic impact             0.194974
#          Cases and deaths            0.163955
#          Preventive measures         0.155352
#          Educational impact          0.096653
#          Authorities & Politics      0.088280
#          People stories              0.053354
#          Vaccines and vaccination    0.051562
# IN       Cases and deaths            0.219124
#          Economic impact             0.175598
#          Virus spreading             0.171071
#          Preventive measures         0.140273
#          Authorities & Politics      0.118478
#          Educational impact          0.070842
#          Vaccines and vaccination    0.059932
#          People stories              0.044682
# KE       Cases and deaths            0.226384
#          Economic impact             0.196364
#          Virus spreading             0.186886
#          Preventive measures         0.125745
#          Authorities & Politics      0.084125
#          Educational impact          0.080769
#          People stories              0.061570
#          Vaccines and vaccination    0.038156
# MY       Economic impact             0.260342
#          Cases and deaths            0.210571
#          Virus spreading             0.196809
#          Preventive measures         0.105604
#          Educational impact          0.076375
#          Authorities & Politics      0.065698
#          Vaccines and vaccination    0.052585
#          People stories              0.032017
# NG       Virus spreading             0.261939
#          Economic impact             0.183765
#          Cases and deaths            0.179297
#          Preventive measures         0.150221
#          Authorities & Politics      0.080308
#          Educational impact          0.072489
#          People stories              0.038095
#          Vaccines and vaccination    0.033885
# NZ       Economic impact             0.181696
#          Cases and deaths            0.176968
#          Virus spreading             0.172187
#          Preventive measures         0.156630
#          Authorities & Politics      0.121817
#          Educational impact          0.107052
#          People stories              0.056550
#          Vaccines and vaccination    0.027100
# PH       Preventive measures         0.216476
#          Economic impact             0.203971
#          Cases and deaths            0.162280
#          Virus spreading             0.152732
#          Authorities & Politics      0.087442
#          Educational impact          0.069155
#          Vaccines and vaccination    0.061879
#          People stories              0.046064
# UK       Virus spreading             0.205498
#          Preventive measures         0.197703
#          Economic impact             0.174296
#          Educational impact          0.111485
#          Cases and deaths            0.107866
#          Authorities & Politics      0.094048
#          People stories              0.065441
#          Vaccines and vaccination    0.043663
# US       Economic impact             0.234991
#          Virus spreading             0.179839
#          Authorities & Politics      0.136592
#          Educational impact          0.118230
#          Cases and deaths            0.112298
#          Preventive measures         0.090818
#          People stories              0.072269
#          Vaccines and vaccination    0.054962
# ZA       Economic impact             0.200391
#          Preventive measures         0.184597
#          Virus spreading             0.168016
#          Cases and deaths            0.153854
#          Authorities & Politics      0.111039
#          Educational impact          0.086589
#          People stories              0.050683
#          Vaccines and vaccination    0.044830
# Name: theme_desc, dtype: float64

# %%
c9 = comments.groupby(['continent', 'country', 'news_id']) \
       .agg({'anger':'mean', 'sadness':'mean', 'optimism':'mean', 'joy':'mean', 'tweetId':'count'}) \
       .reset_index()

for col in ['anger', 'sadness', 'optimism', 'joy']:
    c9['lift_' + col] = c9[col] / g[col]

c9[['lift_'+col for col in ['anger', 'sadness', 'optimism', 'joy']]].max()
# Out:
# lift_anger       1.148388
# lift_sadness     2.312080
# lift_optimism    5.575347
# lift_joy         5.817179
# dtype: float64

# %%
c91.sort_values('anger').tail(5)
# Out:
#     continent country      news_id     anger   sadness  optimism       joy  \
# 72    America      US    2836421.0  0.604880  0.165092  0.127563  0.102465
# 103   America      US  457984599.0  0.610819  0.155204  0.119550  0.114424
# 65    America      CA  373683618.0  0.617515  0.150138  0.136400  0.095944
# 70    America      US    1367531.0  0.618269  0.148134  0.125591  0.108006
# 81    America      US   13850422.0  0.618440  0.152102  0.126491  0.102965
#
#      tweetId  lift_anger  lift_sadness  lift_optimism  lift_joy  \
# 72    635159    1.123209      0.849653       0.886790  0.830899
# 103   182224    1.134237      0.798765       0.831091  0.927880
# 65     21668    1.146670      0.772690       0.948225  0.778023
# 70    199893    1.148071      0.762378       0.873081  0.875834
# 81    437591    1.148388      0.782800       0.879344  0.834956
#
#           username       displayname       userId  \
# 72           MSNBC             MSNBC    2836421.0
# 103  BreitbartNews    Breitbart News  457984599.0
# 65          PnPCBC  Power & Politics  373683618.0
# 70         FoxNews          Fox News    1367531.0
# 81     CNNPolitics      CNN Politics   13850422.0
#
#                                            description  \
# 72   The place for in-depth analysis, political com...
# 103  News, commentary, and destruction of the polit...
# 65   Breaking news and updates from the team at CBC...
# 70   Follow America's #1 cable news network, delive...
# 81   Political news, campaign stories and Washingto...
#
#                                         rawDescription  verified  \
# 72   The place for in-depth analysis, political com...      True
# 103  News, commentary, and destruction of the polit...      True
# 65   Breaking news and updates from the team at CBC...      True
# 70   Follow America's #1 cable news network, delive...      True
# 81   Political news, campaign stories and Washingto...      True
#
#                       created  followersCount  friendsCount  statusesCount  \
# 72  2007-03-29 13:15:41+00:00         4219331           767         248262
# 103 2012-01-08 01:50:52+00:00         1471106           110         145954
# 65  2011-09-15 01:25:56+00:00          222309           475          32699
# 70  2007-03-17 19:01:26+00:00        20185319           260         425666
# 81  2008-02-23 03:12:49+00:00         4136271           344         200996
#
#      favouritesCount  listedCount  mediaCount        location  protected  \
# 72               818        28389       61955                      False
# 103              900         9202        3886                      False
# 65              1018         1793        9542          Ottawa      False
# 70                 2        68612      138108          U.S.A.      False
# 81                 4        20943      152532  Washington, DC      False
#
#                             linkUrl               linkTcourl  \
# 72            http://msnbc.com/live  https://t.co/YBwtJIhwY3
# 103            http://breitbart.com   http://t.co/2sVbt3n6lO
# 65   http://cbc.ca/powerandpolitics  https://t.co/mqaJv4m6Gx
# 70           http://www.foxnews.com   http://t.co/ZYG58XZtAC
# 81          http://cnn.com/politics  https://t.co/KWFMkrEjdY
#
#                                        profileImageUrl  \
# 72   https://pbs.twimg.com/profile_images/132108981...
# 103  https://pbs.twimg.com/profile_images/949270171...
# 65   https://pbs.twimg.com/profile_images/982295716...
# 70   https://pbs.twimg.com/profile_images/918480715...
# 81   https://pbs.twimg.com/profile_images/918899077...
#
#                                       profileBannerUrl    media_outlet  \
# 72   https://pbs.twimg.com/profile_banners/2836421/...           MSNBC
# 103  https://pbs.twimg.com/profile_banners/45798459...  Breitbart News
# 65   https://pbs.twimg.com/profile_banners/37368361...             CBC
# 70   https://pbs.twimg.com/profile_banners/1367531/...             Fox
# 81   https://pbs.twimg.com/profile_banners/13850422...             CNN
#
#     media_category
# 72      Television
# 103        Website
# 65      Television
# 70      Television
# 81      Television

# %%
nt[nt.userId==c91[c91.username.isin(c91.sort_values('anger').tail(5).username.values)].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.247222
# Authorities & Politics      0.238889
# Virus spreading             0.152778
# Preventive measures         0.122222
# Vaccines and vaccination    0.108333
# People stories              0.055556
# Educational impact          0.038889
# Cases and deaths            0.036111
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='InsidersABC'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.297297
# Authorities & Politics      0.267267
# Preventive measures         0.102102
# People stories              0.096096
# Virus spreading             0.090090
# Educational impact          0.081081
# Cases and deaths            0.036036
# Vaccines and vaccination    0.030030
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='BreitbartNews'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.235019
# Authorities & Politics      0.201020
# Virus spreading             0.178496
# Preventive measures         0.131747
# Educational impact          0.092648
# Cases and deaths            0.084998
# People stories              0.050999
# Vaccines and vaccination    0.025074
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='PnPCBC'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.247222
# Authorities & Politics      0.238889
# Virus spreading             0.152778
# Preventive measures         0.122222
# Vaccines and vaccination    0.108333
# People stories              0.055556
# Educational impact          0.038889
# Cases and deaths            0.036111
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='FoxNews'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.243740
# Authorities & Politics      0.228715
# Virus spreading             0.130217
# Educational impact          0.095159
# Preventive measures         0.093489
# Cases and deaths            0.090150
# Vaccines and vaccination    0.080134
# People stories              0.038397
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='CNNPolitics'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Authorities & Politics      0.301386
# Economic impact             0.277045
# Virus spreading             0.143847
# Preventive measures         0.072684
# Educational impact          0.069473
# Cases and deaths            0.067444
# People stories              0.036849
# Vaccines and vaccination    0.031271
# Name: theme_desc, dtype: float64

# %%
c91.sort_values('sadness').tail(5).username
# Out:
# 146         ABSCBNNews
# 48           CBCOttawa
# 126           fpjindia
# 120    NewIndianXpress
# 124          firstpost
# Name: username, dtype: object

# %%
c91.sort_values('sadness').tail(5).description.values
# Out:
# array(["Stories, video, and multimedia for Filipinos worldwide, from ABS-CBN News and Current Affairs, the Philippines' most trusted news organization.",
#        "Follow for breaking news, special reports and RTs of our journalists' latest work. Find us on Instagram.com/cbcottawanews or on Facebook.com/cbcottawa",
#        'The voice of #Mumbai. The Free Press Journal is one of the oldest English daily newspapers from Mumbai with a heritage of more than 90 years.',
#        'All the tweets for breaking news & views.\nFacebook: facebook.com/thenewindianxp…\n\nTelegram: t.me/thenewindianex…',
#        'Incisive opinions, in-depth analysis and views that matter.'],
#       dtype=object)

# %%
nt[nt.userId==c91[c91.username=='TelanganaToday'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Cases and deaths            0.257266
# Virus spreading             0.207770
# Economic impact             0.193094
# Preventive measures         0.117602
# Educational impact          0.082206
# Authorities & Politics      0.068585
# People stories              0.040096
# Vaccines and vaccination    0.033381
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='CBCOttawa'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Authorities & Politics      0.245986
# Cases and deaths            0.194381
# Preventive measures         0.148222
# Educational impact          0.122133
# Economic impact             0.121273
# Virus spreading             0.102351
# Vaccines and vaccination    0.034690
# People stories              0.030963
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='fpjindia'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Cases and deaths            0.298095
# Virus spreading             0.161655
# Economic impact             0.144752
# Preventive measures         0.141763
# Educational impact          0.086758
# Authorities & Politics      0.076111
# Vaccines and vaccination    0.052578
# People stories              0.038289
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='NewIndianXpress'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Preventive measures         0.182353
# Economic impact             0.181818
# Virus spreading             0.181016
# Cases and deaths            0.135027
# Educational impact          0.109893
# People stories              0.085027
# Authorities & Politics      0.084225
# Vaccines and vaccination    0.040642
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='firstpost'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.237861
# Cases and deaths            0.187066
# Preventive measures         0.158648
# Virus spreading             0.140971
# Authorities & Politics      0.092414
# People stories              0.079436
# Educational impact          0.059521
# Vaccines and vaccination    0.044081
# Name: theme_desc, dtype: float64

# %%
c91.sort_values('optimism').tail(5).username
# Out:
# 150         ANCALERTS
# 144    manilabulletin
# 156          pnagovph
# 153    TheManilaTimes
# 147    BusinessMirror
# Name: username, dtype: object

# %%
c91.sort_values('optimism').tail(5).description.values
# Out:
# array(['News updates & breaking news from the Philippines. Like our Facebook page:  facebook.com/ancalerts.',
#        'Breaking news and stories from different sides. RTs from our journalists. Unparalleled journalism in the Philippines since 1900. #BeFullyInformed',
#        'The official Twitter account of Philippine News Agency, the newswire service of the Philippine government.',
#        'The Manila Times is one of the leading national daily broadsheets in the Philippines. It is one of the longest running having been founded in 1898.',
#        'A broader look at today’s business'], dtype=object)

# %%
nt[nt.userId==c91[c91.username=='ANCALERTS'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.222869
# Preventive measures         0.203236
# Virus spreading             0.158960
# Cases and deaths            0.146774
# Educational impact          0.085438
# Vaccines and vaccination    0.080563
# Authorities & Politics      0.068174
# People stories              0.033986
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='manilabulletin'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Preventive measures         0.201108
# Cases and deaths            0.195007
# Economic impact             0.185962
# Virus spreading             0.174742
# Authorities & Politics      0.078466
# Vaccines and vaccination    0.067737
# Educational impact          0.063179
# People stories              0.033798
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='pnagovph'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Preventive measures         0.309050
# Economic impact             0.214069
# Virus spreading             0.126729
# Cases and deaths            0.117244
# Authorities & Politics      0.093927
# Vaccines and vaccination    0.063365
# Educational impact          0.050850
# People stories              0.024766
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='TheManilaTimes'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Preventive measures         0.271564
# Economic impact             0.252579
# Virus spreading             0.139909
# Cases and deaths            0.094305
# Authorities & Politics      0.087908
# Educational impact          0.061907
# People stories              0.056954
# Vaccines and vaccination    0.034874
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='BusinessMirror'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.326987
# Preventive measures         0.208682
# Virus spreading             0.118304
# Authorities & Politics      0.085301
# Cases and deaths            0.077177
# Educational impact          0.071846
# Vaccines and vaccination    0.057883
# People stories              0.053821
# Name: theme_desc, dtype: float64

# %%
c91.sort_values('joy').tail(5).username
# Out:
# 129    airnewsalerts
# 130       DDNewslive
# 7         bellanaija
# 112          mid_day
# 182        BBCRadio4
# Name: username, dtype: object

# %%
c91.sort_values('joy').tail(5).description.values
# Out:
# array(['Official account of News Services Division, All India Radio.\n\nहिंदी के समाचारों के लिए @AIRNewsHindi को फॉलो करें!\nFollow @AIRNewsUrdu for news updates in Urdu',
#        'Official Twitter account of DD News, the Public Broadcaster of India. हिंदी में @DDNewsHindi. Follow us on- instagram.com/ddnews_official',
#        'We LOVE Everything Fab & African - Fashion, Music, Movies & Weddings! Join us at BellaNaija.com | Twitter updates by the BN Squad.',
#        'All things #MadeinMumbai \nNews | Entertainment | Sports and much more\nSubscribe to #MiddayDigitalTabloid\n\nepaper.mid-day.com',
#        'Your friendly lockdown companion - documentaries, politics, news, comedy and drama.'],
#       dtype=object)

# %%
nt[nt.userId==c91[c91.username=='DDNewslive'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Cases and deaths            0.243374
# Authorities & Politics      0.207822
# Economic impact             0.145120
# Virus spreading             0.142211
# Preventive measures         0.129929
# Vaccines and vaccination    0.056561
# Educational impact          0.045249
# People stories              0.029735
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='bellanaija'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Economic impact             0.285523
# Authorities & Politics      0.159517
# Virus spreading             0.155496
# Educational impact          0.112601
# Preventive measures         0.109920
# Cases and deaths            0.092493
# People stories              0.075067
# Vaccines and vaccination    0.009383
# Name: theme_desc, dtype: float64

# %%
nt[nt.userId==c91[c91.username=='mid_day'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# Cases and deaths            0.206660
# Virus spreading             0.176665
# Preventive measures         0.176411
# Economic impact             0.157855
# Educational impact          0.116167
# Authorities & Politics      0.073462
# People stories              0.060244
# Vaccines and vaccination    0.032537
# Name: theme_desc, dtype: float64

# %% [markdown]
# # Trunk0

# %%
nt[nt.userId==c91[c91.username=='RadioCitizenFM'].userId.values[0]].theme_desc.value_counts(normalize=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\FC766~1.BRA\AppData\Local\Temp/ipykernel_22524/1201450592.py in <module>
# ----> 1 nt[nt.userId==c91[c91.username=='RadioCitizenFM'].userId.values[0]].theme_desc.value_counts(normalize=True)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
nt[nt.userId==c91[c91.username=='BBCRadio4'].userId.values[0]].theme_desc.value_counts(normalize=True)

# %%
c91['politic'] = c91.description.apply(lambda x: 'politic' in x.lower())
c91['live_or_break'] = c91.description.apply(lambda x: 'live' in x.lower() or 'break' in x.lower())

# %%
c91[c91.politic].anger.mean() / c91[~c91.politic].anger.mean()

# %%
c91[c91.continent=='America'].anger.mean() / c91[~(c91.continent=='America')].anger.mean()

# %%
c91[c91.live_or_break].sadness.mean() / c91[~c91.live_or_break].sadness.mean()

# %%
c91[c91.live_or_break]

# %%
c91.sort_values('anger').tail(5).description.values

# %%
c91.sort_values('optimism')

# %%
c91.sort_values('sadness')

# %%
c91.sort_values('joy')

# %%
nt[nt.userId==23937508.0].sort_values('likeCount').tail(25).content.values

# %%
nt[nt.userId==23937508.0].sort_values('likeCount').tail(25)

# %%
nt[nt.userId==23937508.0].prevalent_emotion.value_counts(normalize=True)

# %%
c9.iloc[201,:]

# %%
news_accounts[news_accounts.userId==17644834.0]

# %%
comments.query("news_id==17644834.0").news_prevalent_emotion.value_counts()

# %%
comments.query("news_id==17644834.0").prevalent_emotion.value_counts()

# %%
news_tweets.query("userId==17644834.0 and prevalent_emotion=='optimism'").content.values

# %%
comments.query("news_id==17644834.0")

# %%
c9.iloc[234,:]

# %%
comments.query("news_id==23937508.0").news_prevalent_emotion.value_counts()

# %%
comments.query("news_id==23937508.0").prevalent_emotion.value_counts()

# %%
comments.query("news_id==23937508.0")

# %%
news_accounts[news_accounts.userId==23937508.0]

# %% [markdown]
# # Likes, replies and shares related with emotions

# %%
comments.columns

# %%
comments.groupby('prevalent_emotion')[['replyCount', 'retweetCount', 'likeCount', 'quoteCount']].mean()
# Out:
#                    replyCount  retweetCount  likeCount  quoteCount
# prevalent_emotion
# anger                0.401236      0.181391   2.172032    0.042514
# joy                  0.286419      0.186197   1.954152    0.064334
# optimism             0.466677      0.388864   2.852092    0.210058
# sadness              0.500163      0.524447   2.862427    0.143670
# undefined            0.453811      0.404617   2.665493    0.153360

# %%
comments.groupby(['news_prevalent_emotion','prevalent_emotion']).tweetId.count()
# Out:
# news_prevalent_emotion  prevalent_emotion
# anger                   anger                2030624
#                         joy                   265385
#                         optimism              223519
#                         sadness               255259
#                         undefined             339943
# joy                     anger                 346331
#                         joy                   135494
#                         optimism               67078
#                         sadness                91242
#                         undefined              98946
# optimism                anger                1402380
#                         joy                   281880
#                         optimism              317402
#                         sadness               293520
#                         undefined             384711
# sadness                 anger                3592959
#                         joy                   658633
#                         optimism              621955
#                         sadness              1141695
#                         undefined             915971
# undefined               anger                2292642
#                         joy                   425454
#                         optimism              393489
#                         sadness               476241
#                         undefined             568419
# Name: tweetId, dtype: int64

# %% [markdown]
# # Trunk

# %%
theme_desc[theme_desc.theme==4].theme_desc.values[0]

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = 1145364
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = 377531
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = 497696 
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k = np.random.randint(1,news_tweets.shape[0],1)[0]
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
for _ in range(50):
    k = np.random.randint(1,news_tweets.shape[0],1)[0]
    print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
k=0
print('k:', k, '| Tweet:', news_tweets.iloc[k,:].content, '| Theme:', theme_desc[theme_desc.theme==news_tweets.iloc[k,:].theme].theme_desc.values[0])

# %%
news_tweets.iloc[k,:]

# %%
topics[topics.tweetId==1331811812828803073]

# %%
theme_desc

# %%
topics = pd.read_parquet('./news_tweets_topics2.parquet')

# %%
news_tweets[news_tweets.tweetId==1331811812828803073].content.values

# %%
news_tweets.iloc[k,:]

# %%
k

# %%
news_tweets = pd.read_parquet('./../data/raw/news_tweets_with_em_scores.parquet')
news_tweets['emotion_score'] = news_tweets[['anger','joy','optimism','sadness']].max(axis=1)
news_tweets['prevalent_emotion'] = news_tweets[['anger','joy','optimism','sadness']].idxmax(axis=1)
news_tweets['prevalent_emotion'] = np.where(news_tweets.emotion_score>0.5, news_tweets.prevalent_emotion, 'undefined')

comments = comments[comments.tweetId.isin(plain_comments.tweetId)]
topics['tweetId'] = topics.tweetId.astype('float64')
news_tweets = news_tweets[~news_tweets.conversationId.isnull()].merge(topics[['theme'] + subthemes + ['tweetId']], how='left', on='tweetId')
news_accounts = news_accounts.merge(media_list, left_on='username', right_on='account')
news_accounts['userId'] = news_accounts.userId.astype('float64')
news_tweets = news_tweets.merge(news_accounts[['userId','country']], how='left')

# Define subtheme
news_tweets['subtheme'] = news_tweets[subthemes].idxmax(axis=1)
news_tweets['subtheme'] = news_tweets.subtheme.apply(lambda x: int(x[-2:]))
news_tweets['aux'] = news_tweets[subthemes].sum(axis=1)
news_tweets.loc[news_tweets.aux==0,'subtheme'] = news_tweets.loc[news_tweets.aux==0,'theme']*10
news_tweets = news_tweets.drop(subthemes + ['aux'], axis=1)
news_tweets['ds'] = news_tweets.date.dt.date

df = comments.merge(news_tweets.rename(columns={'date':'newsDate', 'userId':'newsId'})[[
    'conversationId', 'newsDate', 'newsId', 'prevalent_emotion', 'emotion_score', 'theme', 'subtheme', 'country'
]].drop_duplicates('conversationId'))
df['ds'] = (df['newsDate'] + pd.offsets.Week(weekday=6)).dt.date

# %%
df.groupby(['country', 'theme']).theme.count().rename('count').reset_index()

# %%
# import libraries
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# load dataset
tips = sns.load_dataset("tips")

# set the figure size
plt.figure(figsize=(14, 14))

# from raw value to percentage
total = tips.groupby('day')['total_bill'].sum().reset_index()
smoker = tips[tips.smoker=='Yes'].groupby('day')['total_bill'].sum().reset_index()
smoker['total_bill'] = [i / j * 100 for i,j in zip(smoker['total_bill'], total['total_bill'])]
total['total_bill'] = [i / j * 100 for i,j in zip(total['total_bill'], total['total_bill'])]

# bar chart 1 -> top bars (group of 'smoker=No')
bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="day", y="total_bill", data=smoker, color='lightblue')

# add legend
top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
plt.legend(handles=[top_bar, bottom_bar])

# show the graph
plt.show()

# %% [markdown]
# # Rosie UK data

# %%
comments = comments.merge(news_tweets_with_em.rename(columns={'anger':'news_anger', 'sadness':'news_sadness', 'optimism':'news_optimism', 'joy':'news_joy'}).sort_values('date').drop_duplicates('conversationId', keep='first')[['conversationId', 'news_anger', 'news_sadness', 'news_optimism', 'news_joy']], how='left')
for i, g in df3[df3.newsName.isin(['BBC News (UK)', 'Daily Mail Online', 'The Guardian'])].groupby('newsName'):
    g.to_csv('./uk_users/{}.csv'.format(i), header=True, index_label=False, index=False)

# %% [markdown]
# # Google Data Studio

# %%
c2 = comments.merge(news_tweets_with_em.rename(columns={'anger':'news_anger', 'sadness':'news_sadness', 'optimism':'news_optimism', 'joy':'news_joy'}).sort_values('date').drop_duplicates('conversationId', keep='first')[['conversationId', 'news_anger', 'news_sadness', 'news_optimism', 'news_joy']], how='left')

# %%
c2[c2.country=='UK'].merge(theme_desc).merge(subtheme_desc).merge(news_accounts[['userId', 'displayname']].rename(columns={'userId':'newsId', 'displayname':'newsName'}), how='left').drop(['theme', 'subtheme', 'newsId'], axis=1)

# %%
df3 = df[df.country=='UK'].merge(theme_desc).merge(subtheme_desc).merge(news_accounts[['userId', 'displayname']].rename(columns={'userId':'newsId', 'displayname':'newsName'}), how='left').drop(['theme', 'subtheme', 'newsId'], axis=1)

# %%
c2

# %%
comments.news_emotion_score.isnull().sum()

# %%
comments

# %%
nt = pd.read_parquet('./../data/raw/news_tweets.parquet')

# %%
news_tweets['emotion_score'] = news_tweets[['anger','joy','optimism','sadness']].max(axis=1)
news_tweets['prevalent_emotion'] = news_tweets[['anger','joy','optimism','sadness']].idxmax(axis=1)
news_tweets['prevalent_emotion'] = np.where(news_tweets.emotion_score>0.5, news_tweets.prevalent_emotion, 'undefined')

comments = comments[comments.tweetId.isin(plain_comments.tweetId)]
topics['tweetId'] = topics.tweetId.astype('float64')
news_tweets = news_tweets[~news_tweets.conversationId.isnull()].merge(topics[['theme'] + subthemes + ['tweetId']], how='left', on='tweetId')
news_accounts = news_accounts.merge(media_list, left_on='username', right_on='account')
news_accounts['userId'] = news_accounts.userId.astype('float64')
news_tweets = news_tweets.merge(news_accounts[['userId','country']], how='left')

# Define subtheme
news_tweets['subtheme'] = news_tweets[subthemes].idxmax(axis=1)
news_tweets['subtheme'] = news_tweets.subtheme.apply(lambda x: int(x[-2:]))
news_tweets['aux'] = news_tweets[subthemes].sum(axis=1)
news_tweets.loc[news_tweets.aux==0,'subtheme'] = news_tweets.loc[news_tweets.aux==0,'theme']*10
news_tweets = news_tweets.drop(subthemes + ['aux'], axis=1)
news_tweets['ds'] = news_tweets.date.dt.date

# %%
df = comments.merge(news_tweets.rename(columns={'date':'newsDate', 'userId':'newsId', 'anger':'news_anger', 'sadness':'news_sadness', 'joy':'news_joy', 'optimism':'news_optimism'})[[
    'conversationId', 'newsDate', 'newsId', 'prevalent_emotion', 'emotion_score', 'theme', 'subtheme', 'country', 'news_anger', 'news_joy', 'news_sadness', 'news_optimism'
]].drop_duplicates('conversationId'))
df['ds'] = df.newsDate.dt.date

# %%
df3 = df[df.country=='UK'].merge(theme_desc).merge(subtheme_desc).merge(news_accounts[['userId', 'displayname']].rename(columns={'userId':'newsId', 'displayname':'newsName'}), how='left').drop(['theme', 'subtheme', 'newsId'], axis=1)

# %%
for i, g in df3[df3.newsName.isin(['BBC News (UK)', 'Daily Mail Online', 'The Guardian'])].groupby('newsName'):
    g.to_csv('./uk_users/{}.csv'.format(i), header=True, index_label=False, index=False)

# %%
news_tweets.rename(columns={'userId':'newsId'})

# %%
nt = news_tweets.rename(columns={'userId':'newsId'}).groupby(['ds', 'theme', 'subtheme', 'country', 'newsId']) \
       .agg({'content':'size', 'anger':'mean', 'joy':'mean', 'optimism':'mean', 'sadness':'mean', 'replyCount':'mean', 'retweetCount':'mean', 'likeCount':'mean', 'quoteCount':'mean'}) \
       .rename(columns={'content':'count'}) \
       .reset_index()
nt = nt.merge(theme_desc).merge(subtheme_desc)
nt = nt.drop(['theme_desc', 'subtheme_desc'], axis=1)
nt['newsId'] = nt.newsId.astype('int64')
nt.to_csv('agg_news_tweets.csv', index=False)

# %%
nt.columns

# %%
for col in ['replyCount', 'retweetCount', 'likeCount','quoteCount']:
    nt[col] = nt[col].astype('int32')

# %%
nt

# %%
nt.to_csv('agg_news_tweets.csv', index=False)

# %%
df['emotion_score'] = df[['anger','joy','optimism','sadness']].max(axis=1)
df['comment_emotion'] = df[['anger','joy','optimism','sadness']].idxmax(axis=1)
df['comment_emotion'] = np.where(df.emotion_score>0.5, df.comment_emotion, 'undefined')

# %%
df2 = df.groupby(['ds', 'theme', 'subtheme', 'country', 'newsId', 'prevalent_emotion']) \
       .agg({'content':'size', 'anger':'mean', 'joy':'mean', 'optimism':'mean', 'sadness':'mean', 'replyCount':'mean', 'retweetCount':'mean', 'likeCount':'mean', 'quoteCount':'mean'}) \
       .rename(columns={'content':'count'}) \
       .reset_index()
df2 = df2.merge(theme_desc).merge(subtheme_desc)
df2 = df2.drop(['theme_desc', 'subtheme_desc'], axis=1)
df2['newsId'] = df2.newsId.astype('int64')

# %%
df2[
    ~(df2.anger.isnull()) & ~(df2.joy.isnull()) & ~(df2.optimism.isnull()) & ~(df2.sadness.isnull())
].to_csv('agg_users_tweets.csv', index=False)

# %%
news_accounts['userId'] = news_accounts.userId.astype('int64')
news_accounts[['country', 'userId', 'displayname']].to_csv('lookup_news.csv', index=False)

# %%
df2

# %%
df2.dtypes

# %%
emotion_id = pd.DataFrame({'news_emotion_id':range(5),'prevalent_emotion':list(df2.prevalent_emotion.unique())})

# %%
country_id = pd.DataFrame({'country_id':range(12),'country':list(df2.country.unique())})

# %%
df2 = df2.merge(theme_desc).merge(subtheme_desc).merge(emotion_id).merge(country_id)
df2 = df2.drop(['country', 'prevalent_emotion', 'theme_desc', 'subtheme_desc'], axis=1)

# %%
df2.to_csv('emotion_per_theme.csv', index=False)
country_id.to_csv('lookup_coutry.csv', index=False)

# %%
df2[
    ~(df2.anger.isnull()) & ~(df2.joy.isnull()) & ~(df2.optimism.isnull()) & ~(df2.sadness.isnull())
].to_csv('agg_users_tweets.csv', index=False)

# %%
df2.isnull().sum()

# %%
df2[df2.anger.isnull()]

# %%
for t in [1,2,3,4,5,6,7,8]:
#for st in [11,12,21,22,41,42,43,44,51,52,53,61,62,63,64,65,66,71,72,73,74]:
    fig, axs = plt.subplots(figsize=(15, 6))
    #df = comments[comments.conversationId.isin(news_tweets[news_tweets.tweetId.isin(topics[topics[fr"subtheme{st}"]].tweetId)].conversationId)]
    df = comments[comments.conversationId.isin(news_tweets[news_tweets.tweetId.isin(topics[topics.theme==t].tweetId)].conversationId)]
    df = df.merge(news_tweets[~news_tweets.conversationId.isnull()].rename(columns={'date':'news_date'})[['conversationId', 'news_date']].drop_duplicates('conversationId'))
    #df['ds'] = pd.to_datetime(df.date.dt.year.astype(str) + '-' + df.date.dt.month.astype(str) + '-1')
    df['ds'] = df.news_date.dt.date
    df = df[['ds', 'anger', 'joy', 'optimism', 'sadness']]
    df = df.groupby('ds')[['anger', 'joy', 'optimism', 'sadness']].mean()
    df.plot.line(ax=axs)
    axs.set_xlabel("datetime")
    axs.set_ylabel("mean score per emotion")
    fig.savefig(fr"theme_monthly_{t}.png")

# %%
df = news_tweets[news_tweets.tweetId.isin(news_tweets_topics[news_tweets_topics.theme==8].tweetId)].copy()
df['ds'] = df.date.dt.date
df = df[['ds', 'anger', 'joy', 'optimism', 'sadness']]
df = df.groupby('ds')[['anger', 'joy', 'optimism', 'sadness']].mean()
df.plot.line(figsize=(15, 6))

# %%
df

# %%
df = df[['date', 'anger', 'joy', 'optimism', 'sadness']]
df.set_index('date').plot.line()

# %%
news_tweets_topics = pd.read_parquet('./news_tweets_topics.parquet')

# %%
news_tweets_topics[news_tweets_topics.topic_11 == tweets.iloc[14,:].topic_11]

# %%
news_tweets[news_tweets.tweetId==1315975830032592896]

# %%
news_tweets_topics[news_tweets_topics.tweetId==1315975830032592896]

# %%
comments[comments.conversationId==1315975830032592896]

# %%
tweets[tweets.conversationId==1315975830032592896]

# %%
tweets[(tweets.topic_11==tweets.iloc[14,:].topic_11)].head()

# %%
tweets[~tweets.topic_0.isnull()].head()

# %%
tweets.iloc[14,:].topic_11

# %%
tweets.shape

# %%
news_tweets.userId.nunique()

# %%
topics.topic.unique()

# %%
tweets = pd.read_parquet('./../data/raw/news_tweets.parquet').sample(frac=1, random_state=3)
tweets = tweets.reset_index(drop=True)

# %%
df = pd.read_csv('tweets_topics2.csv')

# %%
tweets['topic'] = df.Dominant_Topic
