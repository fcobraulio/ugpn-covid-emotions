# %%
# Libraries
from collections import Counter
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools
import math

# Functions
def get_mentioned_users(x):
    users = []
    try:
        for i in range(len(x)):
            users = users + [x[i]['username']]
    except:
        pass
    return users

# Selected locations
# Source: https://en.wikipedia.org/wiki/List_of_countries_by_English-speaking_population (>1MM native speakers)
locations = {
    'east_us': '35.672964,-79.039292,1200km',
    'central_us': '38.273120,-98.582187,1200km',
    'west_us': '39.515882,-116.853723,1100km',
    'ireland_uk': '54.521992,-3.984398,550km',
    'east_canada': '53.685485,-79.787644,1150km',
    'west_canada': '58.276278,-115.796203,1150km',
    'australia': '-25.610118, 134.354805,2100km',
    'south_africa': '-28.816624, 24.991639,1000km',
    'ireland': '52.812761,-8.703998,200km'
    'new_zeland': '-41.500083,172.834408,830km',
    'sri_lanka': '7.555494,80.713785, 265km',
    'singapore': '1.271988,103.823620,22km',
    'trinidad_tobago_loc': '10.695211,-61.168652,100km'
}

# %%
since = '2020-01-01'
until = '2021-03-01'
keywords = '(wuhan OR ncov OR coronavirus OR covid OR sars-cov-2 OR pandemic)'
loc = locations['singapore_loc']
df = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    '{} since:{} until:{} geocode:"{}"'.format(keywords, since, until, loc)).get_items(), 1000))
df['username'] = df.user.apply(lambda x: x['username'])
print('Initial referential timestamp:', df.date.min())

users = (list(itertools.chain.from_iterable(df.mentionedUsers.apply(lambda x: get_mentioned_users(x)))))
users = pd.DataFrame(Counter(users).items(), columns=['account', 'count'])
users = users[users['count']>math.ceil(df.shape[0]/1000)].sort_values('count', ascending=False).reset_index(drop=True)
print('Number of selected users:', users.shape[0])

selected_users = pd.DataFrame([], columns=[
    'username', 'cnt', 'description', 'verified', 'followersCount', 'statusesCount', 'mediaCount'])
for i in range(users.shape[0]):
    try:
        ent = sntwitter.TwitterUserScraper(users.iloc[i].account).entity
        selected_users.loc[selected_users.shape[0]] = [
            ent.username, users.iloc[i]['count'], ent.description, ent.verified, ent.followersCount, ent.statusesCount, ent.mediaCount]
        print('Got info from user:',i)
    except:
        print('Got an error from user:', i)
        pass
selected_users = selected_users[(selected_users.description.apply(lambda x: any(word in x for word in ('news', 'News')))) & (selected_users.verified)]
# Out:
# Initial referential timestamp: 2020-12-07 10:52:47+00:00

# %%
selected_users
# Out:
#       username cnt                                        description  \
# 1   googlenews   5  Google News helps you learn more about the sto...
# 23  ABSCBNNews   2  Stories, video, and multimedia for Filipinos w...
# 25     nytimes   2        News tips? Share them here: nyti.ms/2FVHq9v
# 26     SkyNews   2  We take you to the heart of the stories that s...
#
#    verified followersCount statusesCount mediaCount
# 1      True         291557           332         91
# 23     True        7359676        878670     193765
# 25     True       49830099        428799      52569
# 26     True        7080771        455410     127096

# %%
df
# Out:
#                                                    url  \
# 0    https://twitter.com/GY_Singapore/status/136596...
# 1    https://twitter.com/natmuseum_sg/status/136591...
# 2    https://twitter.com/LilHuzzyVert/status/136591...
# 3    https://twitter.com/Erindrayanti_06/status/136...
# 4    https://twitter.com/KaneBlack_/status/13658989...
# ..                                                 ...
# 995  https://twitter.com/mfosgp/status/133593498757...
# 996  https://twitter.com/mfosgp/status/133593098350...
# 997  https://twitter.com/mfosgp/status/133591876980...
# 998  https://twitter.com/basilyeo/status/1335907581...
# 999  https://twitter.com/PremaSam90/status/13359000...
#
#                          date  \
# 0   2021-02-28 09:49:48+00:00
# 1   2021-02-28 06:44:58+00:00
# 2   2021-02-28 06:35:56+00:00
# 3   2021-02-28 05:57:12+00:00
# 4   2021-02-28 05:37:48+00:00
# ..                        ...
# 995 2020-12-07 13:11:36+00:00
# 996 2020-12-07 12:55:41+00:00
# 997 2020-12-07 12:07:09+00:00
# 998 2020-12-07 11:22:42+00:00
# 999 2020-12-07 10:52:47+00:00
#
#                                                content  \
# 0    Picturing the Pandemic, A Visual Record of Cov...
# 1    #PicturingthePandemic: A Visual Record of COVI...
# 2    Covid-19 vaccination MAY CAUSE PROLONG WHAT???...
# 3    Semenjak covid gaji karyawan gak ada lagi yang...
# 4    She was Demoted, Doubted and Rejected But Now ...
# ..                                                 ...
# 995  @GeraldoRivera @realDonaldTrump @SenSchumer He...
# 996  @AndrewHGiuliani @RudyGiuliani He’s had a toug...
# 997  @briantylercohen So within a month, Rudy gets ...
# 998  Mixed feelings about having a new stadium. Loo...
# 999  For the first time in my life, I will be count...
#
#                                        renderedContent                   id  \
# 0    Picturing the Pandemic, A Visual Record of Cov...  1365962396196425731
# 1    #PicturingthePandemic: A Visual Record of COVI...  1365915883424522244
# 2    Covid-19 vaccination MAY CAUSE PROLONG WHAT???...  1365913607549067273
# 3    Semenjak covid gaji karyawan gak ada lagi yang...  1365903859508408322
# 4    She was Demoted, Doubted and Rejected But Now ...  1365898978252922884
# ..                                                 ...                  ...
# 995  @GeraldoRivera @realDonaldTrump @SenSchumer He...  1335934987573415937
# 996  @AndrewHGiuliani @RudyGiuliani He’s had a toug...  1335930983506345987
# 997  @briantylercohen So within a month, Rudy gets ...  1335918769802104833
# 998  Mixed feelings about having a new stadium. Loo...  1335907581835931650
# 999  For the first time in my life, I will be count...  1335900056696672258
#
#                                                   user  \
# 0    {'username': 'GY_Singapore', 'displayname': 'G...
# 1    {'username': 'natmuseum_sg', 'displayname': 'N...
# 2    {'username': 'LilHuzzyVert', 'displayname': '𝑇...
# 3    {'username': 'Erindrayanti_06', 'displayname':...
# 4    {'username': 'KaneBlack_', 'displayname': 'Kan...
# ..                                                 ...
# 995  {'username': 'mfosgp', 'displayname': 'Microph...
# 996  {'username': 'mfosgp', 'displayname': 'Microph...
# 997  {'username': 'mfosgp', 'displayname': 'Microph...
# 998  {'username': 'basilyeo', 'displayname': 'Basil...
# 999  {'username': 'PremaSam90', 'displayname': 'Pre...
#
#                                               outlinks  \
# 0                                                   []
# 1              [http://go.gov.Sg/PicturingthePandemic]
# 2                                                   []
# 3                                                   []
# 4    [https://www.goodnewsnetwork.org/katalin-karik...
# ..                                                 ...
# 995                                                 []
# 996                                                 []
# 997                                                 []
# 998  [https://twitter.com/MilanReports/status/13358...
# 999                                                 []
#
#                    tcooutlinks  replyCount  retweetCount  ...  \
# 0                           []           0             0  ...
# 1    [https://t.co/xme4bK2wtN]           1             3  ...
# 2                           []           0             0  ...
# 3                           []           0             0  ...
# 4    [https://t.co/3ezCoSthPC]           0             1  ...
# ..                         ...         ...           ...  ...
# 995                         []           0             0  ...
# 996                         []           0             0  ...
# 997                         []           0             0  ...
# 998  [https://t.co/vOghXFnfkz]           1             0  ...
# 999                         []           0             0  ...
#
#                                                 source  \
# 0    <a href="http://twitter.com/download/android" ...
# 1    <a href="http://twitter.com/download/iphone" r...
# 2    <a href="http://twitter.com/download/iphone" r...
# 3    <a href="http://twitter.com/download/android" ...
# 4    <a href="http://twitter.com/download/iphone" r...
# ..                                                 ...
# 995  <a href="http://twitter.com/download/iphone" r...
# 996  <a href="http://twitter.com/download/iphone" r...
# 997  <a href="http://twitter.com/download/iphone" r...
# 998  <a href="http://twitter.com/download/iphone" r...
# 999  <a href="http://twitter.com/download/android" ...
#
#                                sourceUrl          sourceLabel  \
# 0    http://twitter.com/download/android  Twitter for Android
# 1     http://twitter.com/download/iphone   Twitter for iPhone
# 2     http://twitter.com/download/iphone   Twitter for iPhone
# 3    http://twitter.com/download/android  Twitter for Android
# 4     http://twitter.com/download/iphone   Twitter for iPhone
# ..                                   ...                  ...
# 995   http://twitter.com/download/iphone   Twitter for iPhone
# 996   http://twitter.com/download/iphone   Twitter for iPhone
# 997   http://twitter.com/download/iphone   Twitter for iPhone
# 998   http://twitter.com/download/iphone   Twitter for iPhone
# 999  http://twitter.com/download/android  Twitter for Android
#
#                                                  media retweetedTweet  \
# 0    [{'previewUrl': 'https://pbs.twimg.com/media/E...           None
# 1    [{'previewUrl': 'https://pbs.twimg.com/media/E...           None
# 2    [{'previewUrl': 'https://pbs.twimg.com/media/E...           None
# 3                                                 None           None
# 4                                                 None           None
# ..                                                 ...            ...
# 995                                               None           None
# 996                                               None           None
# 997  [{'thumbnailUrl': 'https://pbs.twimg.com/tweet...           None
# 998                                               None           None
# 999                                               None           None
#
#                                            quotedTweet  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 995                                               None
# 996                                               None
# 997                                               None
# 998  {'url': 'https://twitter.com/MilanReports/stat...
# 999                                               None
#
#                                         mentionedUsers  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 995  [{'username': 'GeraldoRivera', 'displayname': ...
# 996  [{'username': 'AndrewHGiuliani', 'displayname'...
# 997  [{'username': 'briantylercohen', 'displayname'...
# 998                                               None
# 999                                               None
#
#                                            coordinates  \
# 0    {'longitude': 103.84846203917137, 'latitude': ...
# 1    {'longitude': 103.84846203917137, 'latitude': ...
# 2    {'longitude': 103.696411999967, 'latitude': 1....
# 3     {'longitude': 103.9866335, 'latitude': 1.107063}
# 4    {'longitude': 103.749959507073, 'latitude': 1....
# ..                                                 ...
# 995  {'longitude': 103.749959507073, 'latitude': 1....
# 996  {'longitude': 103.749959507073, 'latitude': 1....
# 997  {'longitude': 103.749959507073, 'latitude': 1....
# 998  {'longitude': 103.749959507073, 'latitude': 1....
# 999  {'longitude': 103.749959507073, 'latitude': 1....
#
#                             place         username
# 0    National Museum of Singapore     GY_Singapore
# 1    National Museum of Singapore     natmuseum_sg
# 2                         北区, 新加坡     LilHuzzyVert
# 3           Lubuk Baja, Indonesia  Erindrayanti_06
# 4                         中区, 新加坡       KaneBlack_
# ..                            ...              ...
# 995                       中区, 新加坡           mfosgp
# 996                       中区, 新加坡           mfosgp
# 997                       中区, 新加坡           mfosgp
# 998                       中区, 新加坡         basilyeo
# 999                       中区, 新加坡       PremaSam90
#
# [1000 rows x 24 columns]
